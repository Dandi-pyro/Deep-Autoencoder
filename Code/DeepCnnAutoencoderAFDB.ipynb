# %%
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
import wfdb
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.decomposition import PCA
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.python.ops.numpy_ops import np_config
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
# enable numpy behavior
np_config.enable_numpy_behavior()

# %%
data_path = 'mitbih-af/'

# %%
# Get the list of all record files in the folder
# List of Patients
data = ['04015','04043','04048','04126','04746','04908','04936','05091',
           '05121','05261','06426','06453','06995','07162','07859','07879',
           '07910','08215','08219','08378','08405','08434','08455']

# %%
# Creating a Empty Dataframe
symbols_df = pd.DataFrame()

# Reading all .atr files 
for pts in data:
    # Generating filepath for all .atr file names
    file = data_path + pts
    # Saving annotation object
    annotation = wfdb.rdann(file, 'atr')
    # Extracting symbols from the object
    sym = annotation.symbol
    # Saving value counts
    values, counts = np.unique(sym, return_counts=True)
    # Writing data points into dataframe
    df_sub = pd.DataFrame({'symbol':values, 'Counts':counts, 'data Number':[pts]*len(counts)})
    # Concatenating all data points  
    symbols_df = pd.concat([symbols_df, df_sub],axis = 0)

# Loop over all records and load the signal and annotations
for record_name in data:
    record_path = os.path.join(data_path, record_name)
    record = wfdb.rdrecord(record_path)
    annotation = wfdb.rdann(record_path, 'atr', shift_samps=True)
    ecg_signal = record.p_signal[:,0]
    ecg_signal = np.nan_to_num(ecg_signal)

    # Get the signal and labels
    sig = ecg_signal
    labels = np.array(annotation.symbol)

plt.figure(figsize=(12, 4))
plt.plot(sig)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('ECG Signal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import integrate, signal
from scipy.signal import resample, butter, filtfilt, find_peaks
import pywt
from scipy import integrate
import cv2

# Normalize the data
sig = (sig - np.mean(sig)) / np.std(sig)

# Resample the data to new_sampling_rate
new_sampling_rate = 250
record = {"fs": 1000}  # Define the sampling rate
sig_resampled = resample(sig, int(len(sig) * (new_sampling_rate / record["fs"])))

# Bandpass filter the data
lowcut = 5.0
highcut = 15.0
sampling_rate = new_sampling_rate

def bandpass_filter(data, lowcut, highcut, sampling_rate, order=4):
    nyq = 0.5 * sampling_rate
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    filtered_data = filtfilt(b, a, data)
    return filtered_data


sig_filtered = bandpass_filter(sig_resampled, lowcut, highcut, sampling_rate, order=4)

def wavelet_denoising(data):
    waveletname = 'db6'
    threshold = 0.04
    level = pywt.dwt_max_level(len(data), waveletname)
    coeff = pywt.wavedec(data, waveletname, level=level)
    sigma = threshold*np.median(np.abs(coeff[-level]))
    uthresh = sigma*np.sqrt(2*np.log(len(data)))
    coeff[1:] = (pywt.threshold(i, value=uthresh, mode='soft') for i in coeff[1:])
    reconstructed_signal = pywt.waverec(coeff, waveletname)
    return reconstructed_signal

sig_denoised = wavelet_denoising(sig_filtered)

# Define structuring element for morphological operations
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))

# Dilate the signal
sig_dilated = cv2.dilate(sig_filtered, kernel)

# Erode the signal
sig_eroded = cv2.erode(sig_filtered, kernel)

# Perform opening operation on the signal
sig_opened = cv2.morphologyEx(sig_filtered, cv2.MORPH_OPEN, kernel)

# Extract morphological features
def extract_morphological_features(signal):
    features = {}
    
    # Calculate mean of the signal
    features['mean'] = np.mean(signal)
    
    # Calculate standard deviation of the signal
    features['std'] = np.std(signal)
    
    # Calculate maximum value of the signal
    features['max'] = np.max(signal)
    
    # Calculate minimum value of the signal
    features['min'] = np.min(signal)
    
    # Calculate median value of the signal
    features['median'] = np.median(signal)
    
    # Calculate skewness of the signal
    features['skew'] = scipy.stats.skew(signal)
    
    # Calculate kurtosis of the signal
    features['kurtosis'] = scipy.stats.kurtosis(signal)
    
    return features

# Calculate morphological features from the signals
morphological_features_filtered = extract_morphological_features(sig_filtered)
morphological_features_dilated = extract_morphological_features(sig_dilated)
morphological_features_eroded = extract_morphological_features(sig_eroded)
morphological_features_opened = extract_morphological_features(sig_opened)

# %%
sign = sig_filtered, sig_denoised, sig_dilated, sig_eroded, sig_opened

# %%
# Inisialisasi KFold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Fungsi untuk menghitung Signal-to-Noise Ratio (SNR)
def calculate_snr(clean_data, denoised_data):
    noise = clean_data - denoised_data
    signal_power = tf.reduce_mean(tf.square(clean_data))
    noise_power = tf.reduce_mean(tf.square(noise))
    snr = 10 * tf.math.log(signal_power / noise_power) / tf.math.log(10.0)
    return snr

# %%
# Membangun model Deep CNN Autoencoder
def build_autoencoder(input_shape):
    inputs = Input(shape=input_shape)
    # Encoder
    x = Conv1D(16, 3, activation='relu', padding='same')(inputs)
    x = MaxPooling1D(2, padding='same')(x)
    x = Conv1D(8, 3, activation='relu', padding='same')(x)
    x = MaxPooling1D(2, padding='same')(x)
    # Decoder
    x = Conv1D(8, 3, activation='relu', padding='same')(x)
    x = UpSampling1D(2)(x)
    x = Conv1D(16, 3, activation='relu', padding='same')(x)
    x = UpSampling1D(2)(x)
    outputs = Conv1D(1, 3, activation='linear', padding='same')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
sign_array = np.array(sign[3])
sign = np.squeeze(sign_array)  # Reshape the array to remove the singleton dimension

# %%
result_snr = []
result_rmse = []
list_denoised_data = []
i = 1

for train, test in kfold.split(sign):
    train_data = sign[train]
    test_data = sign[test]

    # Pra-pemrosesan data
    train_data = train_data.reshape(train_data.shape[0], 1, 1)
    test_data = test_data.reshape(test_data.shape[0], 1, 1)

    # Mengecek dimensi data
    print("Dimensi data pelatihan:", train_data.shape)
    print("Dimensi data pengujian:", test_data.shape)

    # Membangun model autoencoder
    input_shape = train_data.shape[1:]
    model = build_autoencoder(input_shape)

    # Mengompilasi model dengan optimizer dan loss function yang sesuai
    optimizer = Adam(learning_rate=0.001)
    loss_function = MeanSquaredError()
    metrics = [RootMeanSquaredError()]
    model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
    
    # Menambahkan Early Stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Melatih model menggunakan data pelatihan
    model.fit(train_data, train_data, batch_size=128, epochs=100, verbose=1, validation_data=(test_data, test_data), callbacks=[early_stopping])

    # Menguji model menggunakan data pengujian
    denoised_data = model.predict(test_data)

    # Menghitung SNR dan RMSE
    snr = calculate_snr(test_data, denoised_data)
    rmse = model.evaluate(test_data, test_data)[1]

    # Tampilkan hasil SNR dan RMSE
    print(f'Signal to Noise Ratio (SNR) fold-{i}:', snr)
    print(f'Root Mean Squared Error (RMSE) fold-{i}:', rmse)

    result_snr.append(snr)
    result_rmse.append(rmse)
    list_denoised_data.append(denoised_data)
    i += 1
# Out:
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 14384/14384 [==============================] - 30s 2ms/step - loss: 3.9620e-04 - root_mean_squared_error: 0.0199 - val_loss: 9.0091e-08 - val_root_mean_squared_error: 3.0015e-04
# Epoch 2/100
# 14384/14384 [==============================] - 29s 2ms/step - loss: 5.8727e-06 - root_mean_squared_error: 0.0024 - val_loss: 1.0451e-07 - val_root_mean_squared_error: 3.2329e-04
# Epoch 3/100
# 14384/14384 [==============================] - 29s 2ms/step - loss: 5.2300e-06 - root_mean_squared_error: 0.0023 - val_loss: 1.3713e-06 - val_root_mean_squared_error: 0.0012
# Epoch 4/100
# 14384/14384 [==============================] - 29s 2ms/step - loss: 3.6325e-06 - root_mean_squared_error: 0.0019 - val_loss: 3.2198e-06 - val_root_mean_squared_error: 0.0018
# Epoch 5/100
# 14384/14384 [==============================] - 43s 3ms/step - loss: 5.2905e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.1620e-07 - val_root_mean_squared_error: 4.6498e-04
# Epoch 6/100
# 14384/14384 [==============================] - 34s 2ms/step - loss: 3.4049e-06 - root_mean_squared_error: 0.0018 - val_loss: 3.0411e-08 - val_root_mean_squared_error: 1.7439e-04
# Epoch 7/100
# 14384/14384 [==============================] - 33s 2ms/step - loss: 2.9541e-06 - root_mean_squared_error: 0.0017 - val_loss: 1.4315e-07 - val_root_mean_squared_error: 3.7835e-04
# Epoch 8/100
# 14384/14384 [==============================] - 48s 3ms/step - loss: 2.9013e-06 - root_mean_squared_error: 0.0017 - val_loss: 5.6518e-08 - val_root_mean_squared_error: 2.3774e-04
# Epoch 9/100
# 14384/14384 [==============================] - 29s 2ms/step - loss: 3.4415e-06 - root_mean_squared_error: 0.0019 - val_loss: 6.1175e-07 - val_root_mean_squared_error: 7.8214e-04
# Epoch 10/100
# 14384/14384 [==============================] - 41s 3ms/step - loss: 2.0739e-06 - root_mean_squared_error: 0.0014 - val_loss: 1.3134e-07 - val_root_mean_squared_error: 3.6241e-04
# Epoch 11/100
# 14384/14384 [==============================] - 41s 3ms/step - loss: 3.1822e-06 - root_mean_squared_error: 0.0018 - val_loss: 2.1978e-07 - val_root_mean_squared_error: 4.6880e-04
# Epoch 12/100
# 14384/14384 [==============================] - 30s 2ms/step - loss: 2.4036e-06 - root_mean_squared_error: 0.0016 - val_loss: 4.4741e-06 - val_root_mean_squared_error: 0.0021
# Epoch 13/100
# 14384/14384 [==============================] - 49s 3ms/step - loss: 2.0048e-06 - root_mean_squared_error: 0.0014 - val_loss: 1.7892e-08 - val_root_mean_squared_error: 1.3376e-04
# Epoch 14/100
# 14384/14384 [==============================] - 34s 2ms/step - loss: 1.1147e-06 - root_mean_squared_error: 0.0011 - val_loss: 5.6194e-09 - val_root_mean_squared_error: 7.4963e-05
# Epoch 15/100
# 14384/14384 [==============================] - 41s 3ms/step - loss: 2.7498e-06 - root_mean_squared_error: 0.0017 - val_loss: 5.4992e-09 - val_root_mean_squared_error: 7.4157e-05
# Epoch 16/100
# 14384/14384 [==============================] - 44s 3ms/step - loss: 1.8334e-06 - root_mean_squared_error: 0.0014 - val_loss: 6.3165e-09 - val_root_mean_squared_error: 7.9477e-05
# Epoch 17/100
# 14384/14384 [==============================] - 30s 2ms/step - loss: 1.1207e-06 - root_mean_squared_error: 0.0011 - val_loss: 1.6136e-07 - val_root_mean_squared_error: 4.0170e-04
# Epoch 18/100
# 14384/14384 [==============================] - 49s 3ms/step - loss: 2.0012e-06 - root_mean_squared_error: 0.0014 - val_loss: 6.5816e-09 - val_root_mean_squared_error: 8.1127e-05
# Epoch 19/100
# 14384/14384 [==============================] - 37s 3ms/step - loss: 1.1696e-06 - root_mean_squared_error: 0.0011 - val_loss: 3.7565e-09 - val_root_mean_squared_error: 6.1291e-05
# Epoch 20/100
# 14384/14384 [==============================] - 37s 3ms/step - loss: 1.1018e-06 - root_mean_squared_error: 0.0010 - val_loss: 5.2112e-09 - val_root_mean_squared_error: 7.2188e-05
# Epoch 21/100
# 14384/14384 [==============================] - 48s 3ms/step - loss: 1.2722e-06 - root_mean_squared_error: 0.0011 - val_loss: 5.2600e-09 - val_root_mean_squared_error: 7.2526e-05
# Epoch 22/100
# 14384/14384 [==============================] - 30s 2ms/step - loss: 1.3096e-06 - root_mean_squared_error: 0.0011 - val_loss: 2.7726e-08 - val_root_mean_squared_error: 1.6651e-04
# Epoch 23/100
# 14384/14384 [==============================] - 45s 3ms/step - loss: 1.2030e-06 - root_mean_squared_error: 0.0011 - val_loss: 2.4352e-07 - val_root_mean_squared_error: 4.9348e-04
# Epoch 24/100
# 14384/14384 [==============================] - 41s 3ms/step - loss: 1.2416e-06 - root_mean_squared_error: 0.0011 - val_loss: 2.4195e-07 - val_root_mean_squared_error: 4.9188e-04
# Epoch 25/100
# 14384/14384 [==============================] - 34s 2ms/step - loss: 6.1385e-07 - root_mean_squared_error: 7.8349e-04 - val_loss: 9.0638e-09 - val_root_mean_squared_error: 9.5204e-05
# Epoch 26/100
# 14384/14384 [==============================] - 51s 4ms/step - loss: 8.8840e-07 - root_mean_squared_error: 9.4255e-04 - val_loss: 1.3440e-08 - val_root_mean_squared_error: 1.1593e-04
# Epoch 27/100
# 14384/14384 [==============================] - 30s 2ms/step - loss: 8.8322e-07 - root_mean_squared_error: 9.3980e-04 - val_loss: 5.5336e-08 - val_root_mean_squared_error: 2.3524e-04
# Epoch 28/100
# 14384/14384 [==============================] - 46s 3ms/step - loss: 6.5693e-07 - root_mean_squared_error: 8.1051e-04 - val_loss: 3.5588e-07 - val_root_mean_squared_error: 5.9655e-04
# Epoch 29/100
# 14384/14384 [==============================] - 41s 3ms/step - loss: 9.3209e-07 - root_mean_squared_error: 9.6545e-04 - val_loss: 1.6770e-07 - val_root_mean_squared_error: 4.0952e-04
# 14384/14384 [==============================] - 12s 808us/step
# 14384/14384 [==============================] - 14s 975us/step - loss: 3.7565e-09 - root_mean_squared_error: 6.1291e-05
# Signal to Noise Ratio (SNR) fold-1: tf.Tensor(71.60642316174597, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-1: 6.129060056991875e-05
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 14384/14384 [==============================] - 49s 3ms/step - loss: 2.8062e-04 - root_mean_squared_error: 0.0168 - val_loss: 1.2422e-07 - val_root_mean_squared_error: 3.5245e-04
# Epoch 2/100
# 14384/14384 [==============================] - 39s 3ms/step - loss: 3.9354e-06 - root_mean_squared_error: 0.0020 - val_loss: 1.7664e-06 - val_root_mean_squared_error: 0.0013
# Epoch 3/100
# 14384/14384 [==============================] - 37s 3ms/step - loss: 2.4252e-06 - root_mean_squared_error: 0.0016 - val_loss: 1.2257e-06 - val_root_mean_squared_error: 0.0011
# Epoch 4/100
# 14384/14384 [==============================] - 53s 4ms/step - loss: 2.7750e-06 - root_mean_squared_error: 0.0017 - val_loss: 1.9123e-07 - val_root_mean_squared_error: 4.3730e-04
# Epoch 5/100
# 14384/14384 [==============================] - 31s 2ms/step - loss: 2.0881e-06 - root_mean_squared_error: 0.0014 - val_loss: 1.4822e-06 - val_root_mean_squared_error: 0.0012
# Epoch 6/100
# 14384/14384 [==============================] - 47s 3ms/step - loss: 3.3233e-06 - root_mean_squared_error: 0.0018 - val_loss: 3.2707e-09 - val_root_mean_squared_error: 5.7190e-05
# Epoch 7/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 1.8549e-06 - root_mean_squared_error: 0.0014 - val_loss: 5.6316e-08 - val_root_mean_squared_error: 2.3731e-04
# Epoch 8/100
# 14384/14384 [==============================] - 38s 3ms/step - loss: 2.0276e-06 - root_mean_squared_error: 0.0014 - val_loss: 5.4263e-09 - val_root_mean_squared_error: 7.3663e-05
# Epoch 9/100
# 14384/14384 [==============================] - 48s 3ms/step - loss: 1.6589e-06 - root_mean_squared_error: 0.0013 - val_loss: 2.6949e-07 - val_root_mean_squared_error: 5.1913e-04
# Epoch 10/100
# 14384/14384 [==============================] - 30s 2ms/step - loss: 1.7710e-06 - root_mean_squared_error: 0.0013 - val_loss: 3.8704e-07 - val_root_mean_squared_error: 6.2213e-04
# Epoch 11/100
# 14384/14384 [==============================] - 49s 3ms/step - loss: 1.6978e-06 - root_mean_squared_error: 0.0013 - val_loss: 1.0714e-09 - val_root_mean_squared_error: 3.2732e-05
# Epoch 12/100
# 14384/14384 [==============================] - 38s 3ms/step - loss: 1.4730e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.6227e-09 - val_root_mean_squared_error: 4.0283e-05
# Epoch 13/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 1.3595e-06 - root_mean_squared_error: 0.0012 - val_loss: 3.1476e-09 - val_root_mean_squared_error: 5.6103e-05
# Epoch 14/100
# 14384/14384 [==============================] - 49s 3ms/step - loss: 2.3147e-06 - root_mean_squared_error: 0.0015 - val_loss: 4.5091e-07 - val_root_mean_squared_error: 6.7149e-04
# Epoch 15/100
# 14384/14384 [==============================] - 31s 2ms/step - loss: 1.8113e-06 - root_mean_squared_error: 0.0013 - val_loss: 1.4364e-08 - val_root_mean_squared_error: 1.1985e-04
# Epoch 16/100
# 14384/14384 [==============================] - 49s 3ms/step - loss: 1.6694e-06 - root_mean_squared_error: 0.0013 - val_loss: 1.8731e-09 - val_root_mean_squared_error: 4.3279e-05
# Epoch 17/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 1.4199e-06 - root_mean_squared_error: 0.0012 - val_loss: 2.9206e-08 - val_root_mean_squared_error: 1.7090e-04
# Epoch 18/100
# 14384/14384 [==============================] - 39s 3ms/step - loss: 1.3588e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.4558e-08 - val_root_mean_squared_error: 1.2065e-04
# Epoch 19/100
# 14384/14384 [==============================] - 48s 3ms/step - loss: 1.7248e-06 - root_mean_squared_error: 0.0013 - val_loss: 2.3774e-09 - val_root_mean_squared_error: 4.8758e-05
# Epoch 20/100
# 14384/14384 [==============================] - 31s 2ms/step - loss: 9.8004e-07 - root_mean_squared_error: 9.8997e-04 - val_loss: 1.3214e-09 - val_root_mean_squared_error: 3.6350e-05
# Epoch 21/100
# 14384/14384 [==============================] - 51s 4ms/step - loss: 1.0947e-06 - root_mean_squared_error: 0.0010 - val_loss: 1.6451e-08 - val_root_mean_squared_error: 1.2826e-04
# 14384/14384 [==============================] - 17s 1ms/step
# 14384/14384 [==============================] - 14s 998us/step - loss: 1.0714e-09 - root_mean_squared_error: 3.2731e-05
# Signal to Noise Ratio (SNR) fold-2: tf.Tensor(77.13130717678793, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-2: 3.273149923188612e-05
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 14384/14384 [==============================] - 43s 3ms/step - loss: 6.4924e-04 - root_mean_squared_error: 0.0255 - val_loss: 4.5124e-05 - val_root_mean_squared_error: 0.0067
# Epoch 2/100
# 14384/14384 [==============================] - 46s 3ms/step - loss: 3.5863e-05 - root_mean_squared_error: 0.0060 - val_loss: 2.5832e-05 - val_root_mean_squared_error: 0.0051
# Epoch 3/100
# 14384/14384 [==============================] - 30s 2ms/step - loss: 2.6511e-05 - root_mean_squared_error: 0.0051 - val_loss: 2.4196e-05 - val_root_mean_squared_error: 0.0049
# Epoch 4/100
# 14384/14384 [==============================] - 51s 4ms/step - loss: 2.2688e-05 - root_mean_squared_error: 0.0048 - val_loss: 6.3442e-05 - val_root_mean_squared_error: 0.0080
# Epoch 5/100
# 14384/14384 [==============================] - 37s 3ms/step - loss: 2.2087e-05 - root_mean_squared_error: 0.0047 - val_loss: 1.2723e-05 - val_root_mean_squared_error: 0.0036
# Epoch 6/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 1.7371e-05 - root_mean_squared_error: 0.0042 - val_loss: 3.9451e-06 - val_root_mean_squared_error: 0.0020
# Epoch 7/100
# 14384/14384 [==============================] - 45s 3ms/step - loss: 1.5412e-05 - root_mean_squared_error: 0.0039 - val_loss: 1.8977e-05 - val_root_mean_squared_error: 0.0044
# Epoch 8/100
# 14384/14384 [==============================] - 30s 2ms/step - loss: 1.5257e-05 - root_mean_squared_error: 0.0039 - val_loss: 3.5062e-05 - val_root_mean_squared_error: 0.0059
# Epoch 9/100
# 14384/14384 [==============================] - 50s 4ms/step - loss: 1.5497e-05 - root_mean_squared_error: 0.0039 - val_loss: 6.1941e-05 - val_root_mean_squared_error: 0.0079
# Epoch 10/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 1.5216e-05 - root_mean_squared_error: 0.0039 - val_loss: 1.6542e-05 - val_root_mean_squared_error: 0.0041
# Epoch 11/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 1.3604e-05 - root_mean_squared_error: 0.0037 - val_loss: 1.0256e-05 - val_root_mean_squared_error: 0.0032
# Epoch 12/100
# 14384/14384 [==============================] - 49s 3ms/step - loss: 1.4805e-05 - root_mean_squared_error: 0.0038 - val_loss: 1.4551e-06 - val_root_mean_squared_error: 0.0012
# Epoch 13/100
# 14384/14384 [==============================] - 30s 2ms/step - loss: 1.2856e-05 - root_mean_squared_error: 0.0036 - val_loss: 4.6333e-06 - val_root_mean_squared_error: 0.0022
# Epoch 14/100
# 14384/14384 [==============================] - 48s 3ms/step - loss: 1.3208e-05 - root_mean_squared_error: 0.0036 - val_loss: 2.4755e-05 - val_root_mean_squared_error: 0.0050
# Epoch 15/100
# 14384/14384 [==============================] - 42s 3ms/step - loss: 1.3407e-05 - root_mean_squared_error: 0.0037 - val_loss: 3.0117e-05 - val_root_mean_squared_error: 0.0055
# Epoch 16/100
# 14384/14384 [==============================] - 37s 3ms/step - loss: 1.2782e-05 - root_mean_squared_error: 0.0036 - val_loss: 2.8850e-06 - val_root_mean_squared_error: 0.0017
# Epoch 17/100
# 14384/14384 [==============================] - 51s 4ms/step - loss: 1.2206e-05 - root_mean_squared_error: 0.0035 - val_loss: 1.0133e-05 - val_root_mean_squared_error: 0.0032
# Epoch 18/100
# 14384/14384 [==============================] - 31s 2ms/step - loss: 1.3521e-05 - root_mean_squared_error: 0.0037 - val_loss: 1.5929e-04 - val_root_mean_squared_error: 0.0126
# Epoch 19/100
# 14384/14384 [==============================] - 49s 3ms/step - loss: 1.2731e-05 - root_mean_squared_error: 0.0036 - val_loss: 2.0656e-06 - val_root_mean_squared_error: 0.0014
# Epoch 20/100
# 14384/14384 [==============================] - 42s 3ms/step - loss: 1.0828e-05 - root_mean_squared_error: 0.0033 - val_loss: 6.7986e-07 - val_root_mean_squared_error: 8.2454e-04
# Epoch 21/100
# 14384/14384 [==============================] - 38s 3ms/step - loss: 1.2303e-05 - root_mean_squared_error: 0.0035 - val_loss: 1.1234e-06 - val_root_mean_squared_error: 0.0011
# Epoch 22/100
# 14384/14384 [==============================] - 52s 4ms/step - loss: 1.0781e-05 - root_mean_squared_error: 0.0033 - val_loss: 4.9977e-06 - val_root_mean_squared_error: 0.0022
# Epoch 23/100
# 14384/14384 [==============================] - 31s 2ms/step - loss: 1.1414e-05 - root_mean_squared_error: 0.0034 - val_loss: 6.0705e-06 - val_root_mean_squared_error: 0.0025
# Epoch 24/100
# 14384/14384 [==============================] - 48s 3ms/step - loss: 1.0411e-05 - root_mean_squared_error: 0.0032 - val_loss: 2.4731e-06 - val_root_mean_squared_error: 0.0016
# Epoch 25/100
# 14384/14384 [==============================] - 43s 3ms/step - loss: 1.1868e-05 - root_mean_squared_error: 0.0034 - val_loss: 6.1635e-07 - val_root_mean_squared_error: 7.8508e-04
# Epoch 26/100
# 14384/14384 [==============================] - 36s 2ms/step - loss: 1.0759e-05 - root_mean_squared_error: 0.0033 - val_loss: 2.3308e-05 - val_root_mean_squared_error: 0.0048
# Epoch 27/100
# 14384/14384 [==============================] - 52s 4ms/step - loss: 1.0059e-05 - root_mean_squared_error: 0.0032 - val_loss: 1.4469e-06 - val_root_mean_squared_error: 0.0012
# Epoch 28/100
# 14384/14384 [==============================] - 33s 2ms/step - loss: 1.0797e-05 - root_mean_squared_error: 0.0033 - val_loss: 1.7258e-05 - val_root_mean_squared_error: 0.0042
# Epoch 29/100
# 14384/14384 [==============================] - 47s 3ms/step - loss: 1.1799e-05 - root_mean_squared_error: 0.0034 - val_loss: 4.9773e-06 - val_root_mean_squared_error: 0.0022
# Epoch 30/100
# 14384/14384 [==============================] - 46s 3ms/step - loss: 1.0659e-05 - root_mean_squared_error: 0.0033 - val_loss: 2.5835e-06 - val_root_mean_squared_error: 0.0016
# Epoch 31/100
# 14384/14384 [==============================] - 35s 2ms/step - loss: 1.0223e-05 - root_mean_squared_error: 0.0032 - val_loss: 6.1341e-07 - val_root_mean_squared_error: 7.8320e-04
# Epoch 32/100
# 14384/14384 [==============================] - 52s 4ms/step - loss: 1.0681e-05 - root_mean_squared_error: 0.0033 - val_loss: 1.6687e-06 - val_root_mean_squared_error: 0.0013
# Epoch 33/100
# 14384/14384 [==============================] - 34s 2ms/step - loss: 1.0952e-05 - root_mean_squared_error: 0.0033 - val_loss: 1.6172e-05 - val_root_mean_squared_error: 0.0040
# Epoch 34/100
# 14384/14384 [==============================] - 44s 3ms/step - loss: 1.0536e-05 - root_mean_squared_error: 0.0032 - val_loss: 1.7575e-04 - val_root_mean_squared_error: 0.0133
# Epoch 35/100
# 14384/14384 [==============================] - 46s 3ms/step - loss: 1.0022e-05 - root_mean_squared_error: 0.0032 - val_loss: 1.1806e-06 - val_root_mean_squared_error: 0.0011
# Epoch 36/100
# 14384/14384 [==============================] - 33s 2ms/step - loss: 9.7754e-06 - root_mean_squared_error: 0.0031 - val_loss: 2.5125e-06 - val_root_mean_squared_error: 0.0016
# Epoch 37/100
# 14384/14384 [==============================] - 52s 4ms/step - loss: 9.7401e-06 - root_mean_squared_error: 0.0031 - val_loss: 9.8686e-06 - val_root_mean_squared_error: 0.0031
# Epoch 38/100
# 14384/14384 [==============================] - 39s 3ms/step - loss: 9.6258e-06 - root_mean_squared_error: 0.0031 - val_loss: 3.6824e-05 - val_root_mean_squared_error: 0.0061
# Epoch 39/100
# 14384/14384 [==============================] - 42s 3ms/step - loss: 9.8558e-06 - root_mean_squared_error: 0.0031 - val_loss: 3.9122e-06 - val_root_mean_squared_error: 0.0020
# Epoch 40/100
# 14384/14384 [==============================] - 51s 4ms/step - loss: 1.0498e-05 - root_mean_squared_error: 0.0032 - val_loss: 2.4881e-07 - val_root_mean_squared_error: 4.9880e-04
# Epoch 41/100
# 14384/14384 [==============================] - 32s 2ms/step - loss: 9.3003e-06 - root_mean_squared_error: 0.0030 - val_loss: 3.7729e-05 - val_root_mean_squared_error: 0.0061
# Epoch 42/100
# 14384/14384 [==============================] - 48s 3ms/step - loss: 9.0708e-06 - root_mean_squared_error: 0.0030 - val_loss: 3.9333e-06 - val_root_mean_squared_error: 0.0020
# Epoch 43/100
# 14384/14384 [==============================] - 50s 3ms/step - loss: 9.6880e-06 - root_mean_squared_error: 0.0031 - val_loss: 1.8790e-05 - val_root_mean_squared_error: 0.0043
# Epoch 44/100
# 14384/14384 [==============================] - 33s 2ms/step - loss: 9.8379e-06 - root_mean_squared_error: 0.0031 - val_loss: 4.0243e-07 - val_root_mean_squared_error: 6.3437e-04
# Epoch 45/100
# 14384/14384 [==============================] - 52s 4ms/step - loss: 8.5748e-06 - root_mean_squared_error: 0.0029 - val_loss: 2.9729e-06 - val_root_mean_squared_error: 0.0017
# Epoch 46/100
# 14384/14384 [==============================] - 42s 3ms/step - loss: 9.3544e-06 - root_mean_squared_error: 0.0031 - val_loss: 6.4922e-07 - val_root_mean_squared_error: 8.0574e-04
# Epoch 47/100
# 14384/14384 [==============================] - 39s 3ms/step - loss: 8.9127e-06 - root_mean_squared_error: 0.0030 - val_loss: 9.7741e-07 - val_root_mean_squared_error: 9.8864e-04
# Epoch 48/100
# 14384/14384 [==============================] - 52s 4ms/step - loss: 7.1259e-06 - root_mean_squared_error: 0.0027 - val_loss: 2.9089e-06 - val_root_mean_squared_error: 0.0017
# Epoch 49/100
# 14384/14384 [==============================] - 37s 3ms/step - loss: 9.0414e-06 - root_mean_squared_error: 0.0030 - val_loss: 1.3096e-06 - val_root_mean_squared_error: 0.0011
# Epoch 50/100
# 14384/14384 [==============================] - 44s 3ms/step - loss: 7.9725e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.9190e-06 - val_root_mean_squared_error: 0.0020
# 14384/14384 [==============================] - 20s 1ms/step
# 14384/14384 [==============================] - 19s 1ms/step - loss: 2.4881e-07 - root_mean_squared_error: 4.9881e-04
# Signal to Noise Ratio (SNR) fold-3: tf.Tensor(53.458917104077216, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-3: 0.0004988051950931549
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 14384/14384 [==============================] - 39s 3ms/step - loss: 2.6033e-04 - root_mean_squared_error: 0.0161 - val_loss: 9.0084e-08 - val_root_mean_squared_error: 3.0014e-04
# Epoch 2/100
# 14384/14384 [==============================] - 56s 4ms/step - loss: 6.0007e-06 - root_mean_squared_error: 0.0024 - val_loss: 1.5071e-07 - val_root_mean_squared_error: 3.8821e-04
# Epoch 3/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 2.4144e-06 - root_mean_squared_error: 0.0016 - val_loss: 1.0920e-06 - val_root_mean_squared_error: 0.0010
# Epoch 4/100
# 14384/14384 [==============================] - 51s 4ms/step - loss: 2.9525e-06 - root_mean_squared_error: 0.0017 - val_loss: 3.9105e-08 - val_root_mean_squared_error: 1.9775e-04
# Epoch 5/100
# 14384/14384 [==============================] - 56s 4ms/step - loss: 3.2864e-06 - root_mean_squared_error: 0.0018 - val_loss: 3.2625e-08 - val_root_mean_squared_error: 1.8062e-04
# Epoch 6/100
# 14384/14384 [==============================] - 36s 2ms/step - loss: 3.9899e-06 - root_mean_squared_error: 0.0020 - val_loss: 1.7623e-06 - val_root_mean_squared_error: 0.0013
# Epoch 7/100
# 14384/14384 [==============================] - 56s 4ms/step - loss: 2.2764e-06 - root_mean_squared_error: 0.0015 - val_loss: 6.3944e-09 - val_root_mean_squared_error: 7.9965e-05
# Epoch 8/100
# 14384/14384 [==============================] - 43s 3ms/step - loss: 1.8444e-06 - root_mean_squared_error: 0.0014 - val_loss: 9.6698e-09 - val_root_mean_squared_error: 9.8335e-05
# Epoch 9/100
# 14384/14384 [==============================] - 48s 3ms/step - loss: 1.4300e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.3240e-08 - val_root_mean_squared_error: 1.1507e-04
# Epoch 10/100
# 14384/14384 [==============================] - 55s 4ms/step - loss: 2.3543e-06 - root_mean_squared_error: 0.0015 - val_loss: 2.1905e-06 - val_root_mean_squared_error: 0.0015
# Epoch 11/100
# 14384/14384 [==============================] - 35s 2ms/step - loss: 2.4886e-06 - root_mean_squared_error: 0.0016 - val_loss: 1.4562e-07 - val_root_mean_squared_error: 3.8160e-04
# Epoch 12/100
# 14384/14384 [==============================] - 56s 4ms/step - loss: 1.6593e-06 - root_mean_squared_error: 0.0013 - val_loss: 6.7230e-08 - val_root_mean_squared_error: 2.5929e-04
# Epoch 13/100
# 14384/14384 [==============================] - 44s 3ms/step - loss: 2.3933e-06 - root_mean_squared_error: 0.0015 - val_loss: 8.9506e-09 - val_root_mean_squared_error: 9.4608e-05
# Epoch 14/100
# 14384/14384 [==============================] - 45s 3ms/step - loss: 1.5100e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.7999e-07 - val_root_mean_squared_error: 4.2425e-04
# Epoch 15/100
# 14384/14384 [==============================] - 56s 4ms/step - loss: 1.3333e-06 - root_mean_squared_error: 0.0012 - val_loss: 9.3933e-09 - val_root_mean_squared_error: 9.6919e-05
# Epoch 16/100
# 14384/14384 [==============================] - 33s 2ms/step - loss: 1.0425e-06 - root_mean_squared_error: 0.0010 - val_loss: 1.7214e-09 - val_root_mean_squared_error: 4.1489e-05
# Epoch 17/100
# 14384/14384 [==============================] - 56s 4ms/step - loss: 2.0422e-06 - root_mean_squared_error: 0.0014 - val_loss: 6.2091e-07 - val_root_mean_squared_error: 7.8798e-04
# Epoch 18/100
# 14384/14384 [==============================] - 49s 3ms/step - loss: 9.4530e-07 - root_mean_squared_error: 9.7226e-04 - val_loss: 1.7782e-07 - val_root_mean_squared_error: 4.2169e-04
# Epoch 19/100
# 14384/14384 [==============================] - 43s 3ms/step - loss: 1.5337e-06 - root_mean_squared_error: 0.0012 - val_loss: 2.8918e-08 - val_root_mean_squared_error: 1.7005e-04
# Epoch 20/100
# 14384/14384 [==============================] - 55s 4ms/step - loss: 9.4633e-07 - root_mean_squared_error: 9.7280e-04 - val_loss: 4.5528e-07 - val_root_mean_squared_error: 6.7475e-04
# Epoch 21/100
# 14384/14384 [==============================] - 35s 2ms/step - loss: 2.5264e-06 - root_mean_squared_error: 0.0016 - val_loss: 2.5919e-08 - val_root_mean_squared_error: 1.6099e-04
# Epoch 22/100
# 14384/14384 [==============================] - 56s 4ms/step - loss: 1.0855e-06 - root_mean_squared_error: 0.0010 - val_loss: 1.5288e-08 - val_root_mean_squared_error: 1.2365e-04
# Epoch 23/100
# 14384/14384 [==============================] - 42s 3ms/step - loss: 1.5823e-06 - root_mean_squared_error: 0.0013 - val_loss: 4.3293e-07 - val_root_mean_squared_error: 6.5797e-04
# Epoch 24/100
# 14384/14384 [==============================] - 46s 3ms/step - loss: 9.0624e-07 - root_mean_squared_error: 9.5197e-04 - val_loss: 4.2498e-09 - val_root_mean_squared_error: 6.5190e-05
# Epoch 25/100
# 14384/14384 [==============================] - 52s 4ms/step - loss: 1.1707e-06 - root_mean_squared_error: 0.0011 - val_loss: 4.7119e-09 - val_root_mean_squared_error: 6.8643e-05
# Epoch 26/100
# 14384/14384 [==============================] - 32s 2ms/step - loss: 1.2414e-06 - root_mean_squared_error: 0.0011 - val_loss: 3.3311e-08 - val_root_mean_squared_error: 1.8251e-04
# 14384/14384 [==============================] - 20s 1ms/step
# 14384/14384 [==============================] - 24s 2ms/step - loss: 1.7214e-09 - root_mean_squared_error: 4.1489e-05
# Signal to Noise Ratio (SNR) fold-4: tf.Tensor(75.09812143710079, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-4: 4.148934021941386e-05
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 14384/14384 [==============================] - 42s 3ms/step - loss: 2.4800e-04 - root_mean_squared_error: 0.0157 - val_loss: 4.6369e-07 - val_root_mean_squared_error: 6.8095e-04
# Epoch 2/100
# 14384/14384 [==============================] - 46s 3ms/step - loss: 3.7918e-06 - root_mean_squared_error: 0.0019 - val_loss: 1.1495e-06 - val_root_mean_squared_error: 0.0011
# Epoch 3/100
# 14384/14384 [==============================] - 54s 4ms/step - loss: 3.0286e-06 - root_mean_squared_error: 0.0017 - val_loss: 1.0027e-06 - val_root_mean_squared_error: 0.0010
# Epoch 4/100
# 14384/14384 [==============================] - 32s 2ms/step - loss: 2.1356e-06 - root_mean_squared_error: 0.0015 - val_loss: 1.5817e-07 - val_root_mean_squared_error: 3.9771e-04
# Epoch 5/100
# 14384/14384 [==============================] - 54s 4ms/step - loss: 3.5294e-06 - root_mean_squared_error: 0.0019 - val_loss: 7.2437e-08 - val_root_mean_squared_error: 2.6914e-04
# Epoch 6/100
# 14384/14384 [==============================] - 44s 3ms/step - loss: 2.4384e-06 - root_mean_squared_error: 0.0016 - val_loss: 9.6629e-07 - val_root_mean_squared_error: 9.8300e-04
# Epoch 7/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 2.9863e-06 - root_mean_squared_error: 0.0017 - val_loss: 2.3926e-08 - val_root_mean_squared_error: 1.5468e-04
# Epoch 8/100
# 14384/14384 [==============================] - 53s 4ms/step - loss: 2.0119e-06 - root_mean_squared_error: 0.0014 - val_loss: 5.7337e-07 - val_root_mean_squared_error: 7.5721e-04
# Epoch 9/100
# 14384/14384 [==============================] - 34s 2ms/step - loss: 1.9989e-06 - root_mean_squared_error: 0.0014 - val_loss: 9.5618e-08 - val_root_mean_squared_error: 3.0922e-04
# Epoch 10/100
# 14384/14384 [==============================] - 51s 4ms/step - loss: 2.0241e-06 - root_mean_squared_error: 0.0014 - val_loss: 2.4987e-08 - val_root_mean_squared_error: 1.5807e-04
# Epoch 11/100
# 14384/14384 [==============================] - 48s 3ms/step - loss: 1.4894e-06 - root_mean_squared_error: 0.0012 - val_loss: 7.3389e-08 - val_root_mean_squared_error: 2.7090e-04
# Epoch 12/100
# 14384/14384 [==============================] - 37s 3ms/step - loss: 1.3865e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.6137e-06 - val_root_mean_squared_error: 0.0013
# Epoch 13/100
# 14384/14384 [==============================] - 54s 4ms/step - loss: 9.9694e-07 - root_mean_squared_error: 9.9847e-04 - val_loss: 1.5190e-08 - val_root_mean_squared_error: 1.2325e-04
# Epoch 14/100
# 14384/14384 [==============================] - 37s 3ms/step - loss: 1.3148e-06 - root_mean_squared_error: 0.0011 - val_loss: 4.6882e-07 - val_root_mean_squared_error: 6.8470e-04
# Epoch 15/100
# 14384/14384 [==============================] - 47s 3ms/step - loss: 1.7112e-06 - root_mean_squared_error: 0.0013 - val_loss: 2.7653e-07 - val_root_mean_squared_error: 5.2586e-04
# Epoch 16/100
# 14384/14384 [==============================] - 51s 4ms/step - loss: 7.9735e-07 - root_mean_squared_error: 8.9295e-04 - val_loss: 3.3419e-09 - val_root_mean_squared_error: 5.7809e-05
# Epoch 17/100
# 14384/14384 [==============================] - 35s 2ms/step - loss: 9.2249e-07 - root_mean_squared_error: 9.6047e-04 - val_loss: 9.6857e-09 - val_root_mean_squared_error: 9.8416e-05
# Epoch 18/100
# 14384/14384 [==============================] - 54s 4ms/step - loss: 9.5441e-07 - root_mean_squared_error: 9.7694e-04 - val_loss: 4.4953e-09 - val_root_mean_squared_error: 6.7047e-05
# Epoch 19/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 8.7357e-07 - root_mean_squared_error: 9.3465e-04 - val_loss: 6.1146e-08 - val_root_mean_squared_error: 2.4728e-04
# Epoch 20/100
# 14384/14384 [==============================] - 46s 3ms/step - loss: 7.9699e-07 - root_mean_squared_error: 8.9274e-04 - val_loss: 4.4086e-09 - val_root_mean_squared_error: 6.6398e-05
# Epoch 21/100
# 14384/14384 [==============================] - 53s 4ms/step - loss: 9.6020e-07 - root_mean_squared_error: 9.7990e-04 - val_loss: 1.0021e-06 - val_root_mean_squared_error: 0.0010
# Epoch 22/100
# 14384/14384 [==============================] - 32s 2ms/step - loss: 8.7648e-07 - root_mean_squared_error: 9.3620e-04 - val_loss: 9.0924e-10 - val_root_mean_squared_error: 3.0154e-05
# Epoch 23/100
# 14384/14384 [==============================] - 54s 4ms/step - loss: 1.1233e-06 - root_mean_squared_error: 0.0011 - val_loss: 8.2845e-08 - val_root_mean_squared_error: 2.8783e-04
# Epoch 24/100
# 14384/14384 [==============================] - 45s 3ms/step - loss: 1.0648e-06 - root_mean_squared_error: 0.0010 - val_loss: 1.0516e-06 - val_root_mean_squared_error: 0.0010
# Epoch 25/100
# 14384/14384 [==============================] - 41s 3ms/step - loss: 1.5556e-06 - root_mean_squared_error: 0.0012 - val_loss: 6.7279e-09 - val_root_mean_squared_error: 8.2024e-05
# Epoch 26/100
# 14384/14384 [==============================] - 55s 4ms/step - loss: 9.7998e-07 - root_mean_squared_error: 9.8994e-04 - val_loss: 6.3271e-07 - val_root_mean_squared_error: 7.9543e-04
# Epoch 27/100
# 14384/14384 [==============================] - 33s 2ms/step - loss: 8.4264e-07 - root_mean_squared_error: 9.1795e-04 - val_loss: 3.4808e-08 - val_root_mean_squared_error: 1.8657e-04
# Epoch 28/100
# 14384/14384 [==============================] - 53s 4ms/step - loss: 6.7235e-07 - root_mean_squared_error: 8.1997e-04 - val_loss: 4.1464e-09 - val_root_mean_squared_error: 6.4393e-05
# Epoch 29/100
# 14384/14384 [==============================] - 47s 3ms/step - loss: 6.6454e-07 - root_mean_squared_error: 8.1519e-04 - val_loss: 6.0036e-09 - val_root_mean_squared_error: 7.7483e-05
# Epoch 30/100
# 14384/14384 [==============================] - 40s 3ms/step - loss: 8.2183e-07 - root_mean_squared_error: 9.0655e-04 - val_loss: 3.3110e-08 - val_root_mean_squared_error: 1.8196e-04
# Epoch 31/100
# 14384/14384 [==============================] - 54s 4ms/step - loss: 6.5382e-07 - root_mean_squared_error: 8.0859e-04 - val_loss: 9.8781e-07 - val_root_mean_squared_error: 9.9389e-04
# Epoch 32/100
# 14384/14384 [==============================] - 35s 2ms/step - loss: 8.8066e-07 - root_mean_squared_error: 9.3843e-04 - val_loss: 5.4137e-08 - val_root_mean_squared_error: 2.3267e-04
# 14384/14384 [==============================] - 17s 1ms/step
# 14384/14384 [==============================] - 24s 2ms/step - loss: 9.0924e-10 - root_mean_squared_error: 3.0154e-05
# Signal to Noise Ratio (SNR) fold-5: tf.Tensor(77.80434082244291, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-5: 3.015360198332928e-05

# %%
k = 1
for i in range(len(result_snr)):
    print(f"Hasil SNR ke-{k}:", np.float64(result_snr[i].numpy()))
    k += 1
# Out:
# Hasil SNR ke-1: 71.60642316174597
# Hasil SNR ke-2: 77.13130717678793
# Hasil SNR ke-3: 53.458917104077216
# Hasil SNR ke-4: 75.09812143710079
# Hasil SNR ke-5: 77.80434082244291

# %%
k = 1
for i in range(len(result_rmse)):
    print(f"Hasil rmse ke-{k}:", result_rmse[i])
    k += 1
# Out:
# Hasil rmse ke-1: 6.129060056991875e-05
# Hasil rmse ke-2: 3.273149923188612e-05
# Hasil rmse ke-3: 0.0004988051950931549
# Hasil rmse ke-4: 4.148934021941386e-05
# Hasil rmse ke-5: 3.015360198332928e-05

# %%
import matplotlib.pyplot as plt

# Memilih salah satu fold
fold_index = 0

# Mendapatkan sinyal asli dan sinyal yang telah didenoising dari fold yang dipilih
asli = np.max(test_data, axis=1)


# Menampilkan plot sinyal asli
plt.figure(figsize=(10, 6))
plt.plot(asli[0:101], label='Sinyal Asli')
plt.xlabel('Indeks')
plt.ylabel('Amplitudo')
plt.title('Sinyal Asli')
plt.legend()
plt.show()

k = 1
for i in range(len(list_denoised_data)):
    denoised = np.max(list_denoised_data[i], axis=1)
    # Menampilkan plot sinyal yang telah didenoising
    plt.figure(figsize=(10, 6))
    plt.plot(denoised[0:101], label='Sinyal Didenoising')
    plt.xlabel('Indeks')
    plt.ylabel('Amplitudo')
    plt.title(f'Sinyal Didenoising ke-{k}')
    plt.legend()
    plt.show()
    k += 1

# %%
import matplotlib.pyplot as plt

# Memilih salah satu fold
fold_index = 0

# Mendapatkan sinyal asli dan sinyal yang telah didenoising dari fold yang dipilih
asli = np.max(test_data, axis=1)


# Menampilkan plot sinyal asli
plt.figure(figsize=(10, 6))
plt.plot(asli, label='Sinyal Asli')
plt.xlabel('Indeks')
plt.ylabel('Amplitudo')
plt.title('Sinyal Asli')
plt.legend()
plt.show()

k = 1
for i in range(len(list_denoised_data)):
    denoised = np.max(list_denoised_data[i], axis=1)
    # Menampilkan plot sinyal yang telah didenoising
    plt.figure(figsize=(10, 6))
    plt.plot(denoised, label='Sinyal Didenoising')
    plt.xlabel('Indeks')
    plt.ylabel('Amplitudo')
    plt.title(f'Sinyal Didenoising ke-{k}')
    plt.legend()
    plt.show()
    k += 1
