# %%
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
import wfdb
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.decomposition import PCA
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.python.ops.numpy_ops import np_config
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
# enable numpy behavior
np_config.enable_numpy_behavior()

# %%
data_path = 'mitbih-af/'

# %%
# Get the list of all record files in the folder
# List of Patients
data = ['04015','04043','04048','04126','04746','04908','04936','05091',
           '05121','05261','06426','06453','06995','07162','07859','07879',
           '07910','08215','08219','08378','08405','08434','08455']

# %%
# Creating a Empty Dataframe
symbols_df = pd.DataFrame()

# Reading all .atr files 
for pts in data:
    # Generating filepath for all .atr file names
    file = data_path + pts
    # Saving annotation object
    annotation = wfdb.rdann(file, 'atr')
    # Extracting symbols from the object
    sym = annotation.symbol
    # Saving value counts
    values, counts = np.unique(sym, return_counts=True)
    # Writing data points into dataframe
    df_sub = pd.DataFrame({'symbol':values, 'Counts':counts, 'data Number':[pts]*len(counts)})
    # Concatenating all data points  
    symbols_df = pd.concat([symbols_df, df_sub],axis = 0)

# Loop over all records and load the signal and annotations
for record_name in data:
    record_path = os.path.join(data_path, record_name)
    record = wfdb.rdrecord(record_path)
    annotation = wfdb.rdann(record_path, 'atr', shift_samps=True)
    ecg_signal = record.p_signal[:,0]
    ecg_signal = np.nan_to_num(ecg_signal)

    # Get the signal and labels
    sig = ecg_signal
    labels = np.array(annotation.symbol)

plt.figure(figsize=(12, 4))
plt.plot(sig)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('ECG Signal')
plt.show()

# %%
import numpy as np

# Menghitung kekuatan sinyal (Signal Power)
signal_power = np.var(sig)  # sig adalah sinyal asli

# Menghitung kekuatan noise (Noise Power)
# Untuk data EKG, noise seringkali dianggap sebagai seluruh sinyal karena noise dalam data EKG bervariasi
# Anda dapat menggunakan seluruh sinyal sebagai noise
noise_power = np.var(sig)

# Menghitung SNR
snr = 10 * np.log10(signal_power / noise_power)

print("SNR:", snr)
# Out:
# SNR: 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import integrate, signal
from scipy.signal import resample, butter, filtfilt, find_peaks
import pywt
from scipy import integrate
import cv2

# Normalize the data
sig = (sig - np.mean(sig)) / np.std(sig)

# Resample the data to new_sampling_rate
new_sampling_rate = 250
record = {"fs": 1000}  # Define the sampling rate
sig_resampled = resample(sig, int(len(sig) * (new_sampling_rate / record["fs"])))

# Bandpass filter the data
lowcut = 5.0
highcut = 15.0
sampling_rate = new_sampling_rate

def bandpass_filter(data, lowcut, highcut, sampling_rate, order=4):
    nyq = 0.5 * sampling_rate
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    filtered_data = filtfilt(b, a, data)
    return filtered_data


sig_filtered = bandpass_filter(sig_resampled, lowcut, highcut, sampling_rate, order=4)

def wavelet_denoising(data):
    waveletname = 'db6'
    threshold = 0.04
    level = pywt.dwt_max_level(len(data), waveletname)
    coeff = pywt.wavedec(data, waveletname, level=level)
    sigma = threshold*np.median(np.abs(coeff[-level]))
    uthresh = sigma*np.sqrt(2*np.log(len(data)))
    coeff[1:] = (pywt.threshold(i, value=uthresh, mode='soft') for i in coeff[1:])
    reconstructed_signal = pywt.waverec(coeff, waveletname)
    return reconstructed_signal

sig_denoised = wavelet_denoising(sig_filtered)

# Define structuring element for morphological operations
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))

# Dilate the signal
sig_dilated = cv2.dilate(sig_filtered, kernel)

# Erode the signal
sig_eroded = cv2.erode(sig_filtered, kernel)

# Perform opening operation on the signal
sig_opened = cv2.morphologyEx(sig_filtered, cv2.MORPH_OPEN, kernel)

# Extract morphological features
def extract_morphological_features(signal):
    features = {}
    
    # Calculate mean of the signal
    features['mean'] = np.mean(signal)
    
    # Calculate standard deviation of the signal
    features['std'] = np.std(signal)
    
    # Calculate maximum value of the signal
    features['max'] = np.max(signal)
    
    # Calculate minimum value of the signal
    features['min'] = np.min(signal)
    
    # Calculate median value of the signal
    features['median'] = np.median(signal)
    
    # Calculate skewness of the signal
    features['skew'] = scipy.stats.skew(signal)
    
    # Calculate kurtosis of the signal
    features['kurtosis'] = scipy.stats.kurtosis(signal)
    
    return features

# Calculate morphological features from the signals
morphological_features_filtered = extract_morphological_features(sig_filtered)
morphological_features_dilated = extract_morphological_features(sig_dilated)
morphological_features_eroded = extract_morphological_features(sig_eroded)
morphological_features_opened = extract_morphological_features(sig_opened)

# %%
sign = sig_filtered, sig_denoised, sig_dilated, sig_eroded, sig_opened

# %%
# Inisialisasi KFold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Fungsi untuk menghitung Signal-to-Noise Ratio (SNR)
def calculate_snr(clean_data, denoised_data):
    noise = clean_data - denoised_data
    signal_power = tf.reduce_mean(tf.square(clean_data))
    noise_power = tf.reduce_mean(tf.square(noise))
    snr = 10 * tf.math.log(signal_power / noise_power) / tf.math.log(10.0)
    return snr

# %%
# Membangun model Deep CNN Autoencoder
def build_autoencoder(input_shape):
    inputs = Input(shape=input_shape)
    # Encoder
    x = Conv1D(16, 3, activation='relu', padding='same')(inputs)
    x = MaxPooling1D(2, padding='same')(x)
    x = Conv1D(8, 3, activation='relu', padding='same')(x)
    x = MaxPooling1D(2, padding='same')(x)
    # Decoder
    x = Conv1D(8, 3, activation='relu', padding='same')(x)
    x = UpSampling1D(2)(x)
    x = Conv1D(16, 3, activation='relu', padding='same')(x)
    x = UpSampling1D(2)(x)
    outputs = Conv1D(1, 3, activation='linear', padding='same')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
sign_array = np.array(sign[3])
sign = np.squeeze(sign_array)  # Reshape the array to remove the singleton dimension

# %%
import matplotlib.pyplot as plt

result_snr = []
result_rmse = []
list_denoised_data = []
i = 1

for train, test in kfold.split(sign):
    train_data = sign[train]
    test_data = sign[test]

    # Pra-pemrosesan data
    train_data = train_data.reshape(train_data.shape[0], 1, 1)
    test_data = test_data.reshape(test_data.shape[0], 1, 1)

    # Mengecek dimensi data
    print("Dimensi data pelatihan:", train_data.shape)
    print("Dimensi data pengujian:", test_data.shape)

    # Membangun model autoencoder
    input_shape = train_data.shape[1:]
    model = build_autoencoder(input_shape)

    # Mengompilasi model dengan optimizer dan loss function yang sesuai
    optimizer = Adam(learning_rate=0.001)
    loss_function = MeanSquaredError()
    metrics = [RootMeanSquaredError()]
    model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
    
    # Menambahkan Early Stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Melatih model menggunakan data pelatihan
    history = model.fit(train_data, train_data, batch_size=128, epochs=100, verbose=1, validation_data=(test_data, test_data), callbacks=[early_stopping])

    # Plot RMSE per epoch
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['root_mean_squared_error'], label='Training RMSE')
    plt.plot(history.history['val_root_mean_squared_error'], label='Validation RMSE')
    plt.xlabel('Epoch')
    plt.ylabel('RMSE')
    plt.title(f'RMSE per Epoch - Fold {i}')
    plt.legend()
    plt.grid()
    plt.show()
    
    # Menguji model menggunakan data pengujian
    denoised_data = model.predict(test_data)

    # Menghitung SNR dan RMSE
    snr = calculate_snr(test_data, denoised_data)
    rmse = model.evaluate(test_data, test_data)[1]

    # Tampilkan hasil SNR dan RMSE
    print(f'Signal to Noise Ratio (SNR) fold-{i}:', snr)
    print(f'Root Mean Squared Error (RMSE) fold-{i}:', rmse)

    result_snr.append(snr)
    result_rmse.append(rmse)
    list_denoised_data.append(denoised_data)
    i += 1
# Out:
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 9.6029e-04 - root_mean_squared_error: 0.0310 - val_loss: 4.6854e-06 - val_root_mean_squared_error: 0.0022
# Epoch 2/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 2.6812e-06 - root_mean_squared_error: 0.0016 - val_loss: 1.4072e-06 - val_root_mean_squared_error: 0.0012
# Epoch 3/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 2.0877e-06 - root_mean_squared_error: 0.0014 - val_loss: 2.7764e-08 - val_root_mean_squared_error: 1.6662e-04
# Epoch 4/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.3970e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.6076e-08 - val_root_mean_squared_error: 1.2679e-04
# Epoch 5/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.6361e-06 - root_mean_squared_error: 0.0013 - val_loss: 3.8664e-07 - val_root_mean_squared_error: 6.2181e-04
# Epoch 6/100
# 3596/3596 [==============================] - 34s 9ms/step - loss: 1.2799e-06 - root_mean_squared_error: 0.0011 - val_loss: 8.0372e-08 - val_root_mean_squared_error: 2.8350e-04
# Epoch 7/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.2446e-06 - root_mean_squared_error: 0.0011 - val_loss: 1.2467e-08 - val_root_mean_squared_error: 1.1165e-04
# Epoch 8/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.4423e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.5678e-08 - val_root_mean_squared_error: 1.2521e-04
# Epoch 9/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 8.9563e-07 - root_mean_squared_error: 9.4638e-04 - val_loss: 1.4343e-07 - val_root_mean_squared_error: 3.7872e-04
# Epoch 10/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.0380e-06 - root_mean_squared_error: 0.0010 - val_loss: 1.9660e-08 - val_root_mean_squared_error: 1.4021e-04
# Epoch 11/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 9.7775e-07 - root_mean_squared_error: 9.8881e-04 - val_loss: 1.4278e-08 - val_root_mean_squared_error: 1.1949e-04
# Epoch 12/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 9.0288e-07 - root_mean_squared_error: 9.5020e-04 - val_loss: 1.7763e-07 - val_root_mean_squared_error: 4.2147e-04
# Epoch 13/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 7.9269e-07 - root_mean_squared_error: 8.9033e-04 - val_loss: 7.7398e-07 - val_root_mean_squared_error: 8.7976e-04
# Epoch 14/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.1672e-06 - root_mean_squared_error: 0.0011 - val_loss: 2.5603e-08 - val_root_mean_squared_error: 1.6001e-04
# Epoch 15/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 8.7662e-07 - root_mean_squared_error: 9.3628e-04 - val_loss: 9.1850e-07 - val_root_mean_squared_error: 9.5838e-04
# Epoch 16/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 7.8165e-07 - root_mean_squared_error: 8.8411e-04 - val_loss: 1.2240e-08 - val_root_mean_squared_error: 1.1063e-04
# Epoch 17/100
# 3596/3596 [==============================] - 31s 8ms/step - loss: 9.6387e-07 - root_mean_squared_error: 9.8177e-04 - val_loss: 2.4449e-06 - val_root_mean_squared_error: 0.0016
# Epoch 18/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 6.1934e-07 - root_mean_squared_error: 7.8698e-04 - val_loss: 3.2575e-08 - val_root_mean_squared_error: 1.8049e-04
# Epoch 19/100
# 3596/3596 [==============================] - 29s 8ms/step - loss: 8.5478e-07 - root_mean_squared_error: 9.2454e-04 - val_loss: 6.7470e-08 - val_root_mean_squared_error: 2.5975e-04
# Epoch 20/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 9.9807e-07 - root_mean_squared_error: 9.9904e-04 - val_loss: 2.6223e-08 - val_root_mean_squared_error: 1.6194e-04
# Epoch 21/100
# 3596/3596 [==============================] - 29s 8ms/step - loss: 6.8900e-07 - root_mean_squared_error: 8.3006e-04 - val_loss: 5.7839e-08 - val_root_mean_squared_error: 2.4050e-04
# Epoch 22/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 6.8095e-07 - root_mean_squared_error: 8.2520e-04 - val_loss: 1.7212e-07 - val_root_mean_squared_error: 4.1488e-04
# Epoch 23/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 8.7275e-07 - root_mean_squared_error: 9.3421e-04 - val_loss: 1.0316e-08 - val_root_mean_squared_error: 1.0157e-04
# Epoch 24/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 5.6370e-07 - root_mean_squared_error: 7.5080e-04 - val_loss: 9.1550e-10 - val_root_mean_squared_error: 3.0257e-05
# Epoch 25/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.0234e-06 - root_mean_squared_error: 0.0010 - val_loss: 5.4900e-07 - val_root_mean_squared_error: 7.4095e-04
# Epoch 26/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 6.3294e-07 - root_mean_squared_error: 7.9557e-04 - val_loss: 7.2832e-09 - val_root_mean_squared_error: 8.5342e-05
# Epoch 27/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 5.6190e-07 - root_mean_squared_error: 7.4960e-04 - val_loss: 4.4181e-09 - val_root_mean_squared_error: 6.6469e-05
# Epoch 28/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 6.3709e-07 - root_mean_squared_error: 7.9818e-04 - val_loss: 1.5595e-08 - val_root_mean_squared_error: 1.2488e-04
# Epoch 29/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 5.5486e-07 - root_mean_squared_error: 7.4489e-04 - val_loss: 4.7268e-09 - val_root_mean_squared_error: 6.8752e-05
# Epoch 30/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 5.6868e-07 - root_mean_squared_error: 7.5411e-04 - val_loss: 3.0740e-09 - val_root_mean_squared_error: 5.5444e-05
# Epoch 31/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 5.4942e-07 - root_mean_squared_error: 7.4123e-04 - val_loss: 4.4530e-08 - val_root_mean_squared_error: 2.1102e-04
# Epoch 32/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 6.1700e-07 - root_mean_squared_error: 7.8549e-04 - val_loss: 2.3925e-07 - val_root_mean_squared_error: 4.8913e-04
# Epoch 33/100
# 3596/3596 [==============================] - 29s 8ms/step - loss: 8.3808e-07 - root_mean_squared_error: 9.1547e-04 - val_loss: 4.4571e-08 - val_root_mean_squared_error: 2.1112e-04
# Epoch 34/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 5.6711e-07 - root_mean_squared_error: 7.5307e-04 - val_loss: 1.2260e-07 - val_root_mean_squared_error: 3.5015e-04
# 14384/14384 [==============================] - 29s 2ms/step
# 14384/14384 [==============================] - 35s 2ms/step - loss: 9.1550e-10 - root_mean_squared_error: 3.0257e-05
# Signal to Noise Ratio (SNR) fold-1: tf.Tensor(77.73770774230177, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-1: 3.025729165528901e-05
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 3596/3596 [==============================] - 37s 9ms/step - loss: 0.0015 - root_mean_squared_error: 0.0390 - val_loss: 4.5594e-07 - val_root_mean_squared_error: 6.7523e-04
# Epoch 2/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 2.3198e-06 - root_mean_squared_error: 0.0015 - val_loss: 2.3916e-06 - val_root_mean_squared_error: 0.0015
# Epoch 3/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 2.4758e-06 - root_mean_squared_error: 0.0016 - val_loss: 1.6031e-07 - val_root_mean_squared_error: 4.0039e-04
# Epoch 4/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 2.1839e-06 - root_mean_squared_error: 0.0015 - val_loss: 3.0277e-05 - val_root_mean_squared_error: 0.0055
# Epoch 5/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 2.5811e-06 - root_mean_squared_error: 0.0016 - val_loss: 2.0820e-07 - val_root_mean_squared_error: 4.5629e-04
# Epoch 6/100
# 3596/3596 [==============================] - 42s 12ms/step - loss: 1.7342e-06 - root_mean_squared_error: 0.0013 - val_loss: 3.1335e-06 - val_root_mean_squared_error: 0.0018
# Epoch 7/100
# 3596/3596 [==============================] - 34s 9ms/step - loss: 3.3994e-06 - root_mean_squared_error: 0.0018 - val_loss: 5.7116e-07 - val_root_mean_squared_error: 7.5575e-04
# Epoch 8/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.8234e-06 - root_mean_squared_error: 0.0014 - val_loss: 2.3033e-08 - val_root_mean_squared_error: 1.5177e-04
# Epoch 9/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.8743e-06 - root_mean_squared_error: 0.0014 - val_loss: 1.2771e-07 - val_root_mean_squared_error: 3.5737e-04
# Epoch 10/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.6050e-06 - root_mean_squared_error: 0.0013 - val_loss: 1.1987e-08 - val_root_mean_squared_error: 1.0949e-04
# Epoch 11/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.6747e-06 - root_mean_squared_error: 0.0013 - val_loss: 4.6214e-08 - val_root_mean_squared_error: 2.1497e-04
# Epoch 12/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 2.4555e-06 - root_mean_squared_error: 0.0016 - val_loss: 1.4529e-06 - val_root_mean_squared_error: 0.0012
# Epoch 13/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.4565e-06 - root_mean_squared_error: 0.0012 - val_loss: 5.3736e-07 - val_root_mean_squared_error: 7.3305e-04
# Epoch 14/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.4386e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.8116e-06 - val_root_mean_squared_error: 0.0013
# Epoch 15/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.3275e-06 - root_mean_squared_error: 0.0012 - val_loss: 4.1925e-06 - val_root_mean_squared_error: 0.0020
# Epoch 16/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.3484e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.6202e-08 - val_root_mean_squared_error: 1.2729e-04
# Epoch 17/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.3833e-06 - root_mean_squared_error: 0.0012 - val_loss: 9.6261e-09 - val_root_mean_squared_error: 9.8112e-05
# Epoch 18/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.3469e-06 - root_mean_squared_error: 0.0012 - val_loss: 2.3501e-07 - val_root_mean_squared_error: 4.8478e-04
# Epoch 19/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.3958e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.5030e-08 - val_root_mean_squared_error: 1.2260e-04
# Epoch 20/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.2126e-06 - root_mean_squared_error: 0.0011 - val_loss: 3.8764e-08 - val_root_mean_squared_error: 1.9689e-04
# Epoch 21/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.1366e-06 - root_mean_squared_error: 0.0011 - val_loss: 1.0780e-08 - val_root_mean_squared_error: 1.0383e-04
# Epoch 22/100
# 3596/3596 [==============================] - 34s 9ms/step - loss: 1.0944e-06 - root_mean_squared_error: 0.0010 - val_loss: 1.8112e-07 - val_root_mean_squared_error: 4.2558e-04
# Epoch 23/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.0330e-06 - root_mean_squared_error: 0.0010 - val_loss: 4.1790e-09 - val_root_mean_squared_error: 6.4645e-05
# Epoch 24/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.0583e-06 - root_mean_squared_error: 0.0010 - val_loss: 4.6769e-06 - val_root_mean_squared_error: 0.0022
# Epoch 25/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.2580e-06 - root_mean_squared_error: 0.0011 - val_loss: 4.8512e-08 - val_root_mean_squared_error: 2.2025e-04
# Epoch 26/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.7477e-06 - root_mean_squared_error: 0.0013 - val_loss: 9.6732e-08 - val_root_mean_squared_error: 3.1102e-04
# Epoch 27/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 7.0849e-07 - root_mean_squared_error: 8.4172e-04 - val_loss: 3.0396e-07 - val_root_mean_squared_error: 5.5133e-04
# Epoch 28/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.0955e-06 - root_mean_squared_error: 0.0010 - val_loss: 3.4506e-09 - val_root_mean_squared_error: 5.8742e-05
# Epoch 29/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 8.4823e-07 - root_mean_squared_error: 9.2100e-04 - val_loss: 7.5437e-07 - val_root_mean_squared_error: 8.6854e-04
# Epoch 30/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 9.8560e-07 - root_mean_squared_error: 9.9277e-04 - val_loss: 6.6604e-09 - val_root_mean_squared_error: 8.1611e-05
# Epoch 31/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 8.2521e-07 - root_mean_squared_error: 9.0841e-04 - val_loss: 3.4346e-07 - val_root_mean_squared_error: 5.8606e-04
# Epoch 32/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.1509e-06 - root_mean_squared_error: 0.0011 - val_loss: 2.9258e-08 - val_root_mean_squared_error: 1.7105e-04
# Epoch 33/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 9.4389e-07 - root_mean_squared_error: 9.7154e-04 - val_loss: 7.7726e-09 - val_root_mean_squared_error: 8.8163e-05
# Epoch 34/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 9.7812e-07 - root_mean_squared_error: 9.8900e-04 - val_loss: 5.0920e-06 - val_root_mean_squared_error: 0.0023
# Epoch 35/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 8.9061e-07 - root_mean_squared_error: 9.4372e-04 - val_loss: 8.6614e-09 - val_root_mean_squared_error: 9.3066e-05
# Epoch 36/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.3010e-06 - root_mean_squared_error: 0.0011 - val_loss: 9.1967e-07 - val_root_mean_squared_error: 9.5899e-04
# Epoch 37/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.0903e-06 - root_mean_squared_error: 0.0010 - val_loss: 9.4363e-07 - val_root_mean_squared_error: 9.7141e-04
# Epoch 38/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 1.1403e-06 - root_mean_squared_error: 0.0011 - val_loss: 7.1139e-08 - val_root_mean_squared_error: 2.6672e-04
# 14384/14384 [==============================] - 29s 2ms/step
# 14384/14384 [==============================] - 35s 2ms/step - loss: 3.4506e-09 - root_mean_squared_error: 5.8742e-05
# Signal to Noise Ratio (SNR) fold-2: tf.Tensor(72.05165992855859, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-2: 5.8741999964695424e-05
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 3596/3596 [==============================] - 35s 9ms/step - loss: 8.8702e-04 - root_mean_squared_error: 0.0298 - val_loss: 7.4137e-07 - val_root_mean_squared_error: 8.6103e-04
# Epoch 2/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.8998e-06 - root_mean_squared_error: 0.0014 - val_loss: 1.3920e-07 - val_root_mean_squared_error: 3.7310e-04
# Epoch 3/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.7148e-06 - root_mean_squared_error: 0.0013 - val_loss: 1.3335e-07 - val_root_mean_squared_error: 3.6517e-04
# Epoch 4/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.5077e-06 - root_mean_squared_error: 0.0012 - val_loss: 8.5951e-08 - val_root_mean_squared_error: 2.9317e-04
# Epoch 5/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.2997e-06 - root_mean_squared_error: 0.0011 - val_loss: 8.0270e-09 - val_root_mean_squared_error: 8.9594e-05
# Epoch 6/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.2733e-06 - root_mean_squared_error: 0.0011 - val_loss: 5.7408e-09 - val_root_mean_squared_error: 7.5768e-05
# Epoch 7/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.2580e-06 - root_mean_squared_error: 0.0011 - val_loss: 2.0932e-07 - val_root_mean_squared_error: 4.5751e-04
# Epoch 8/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 9.8867e-07 - root_mean_squared_error: 9.9432e-04 - val_loss: 2.1480e-08 - val_root_mean_squared_error: 1.4656e-04
# Epoch 9/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 9.3743e-07 - root_mean_squared_error: 9.6821e-04 - val_loss: 1.7507e-08 - val_root_mean_squared_error: 1.3232e-04
# Epoch 10/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 8.6572e-07 - root_mean_squared_error: 9.3044e-04 - val_loss: 6.7321e-06 - val_root_mean_squared_error: 0.0026
# Epoch 11/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 8.0400e-07 - root_mean_squared_error: 8.9666e-04 - val_loss: 1.2187e-07 - val_root_mean_squared_error: 3.4910e-04
# Epoch 12/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 8.3629e-07 - root_mean_squared_error: 9.1449e-04 - val_loss: 7.3163e-06 - val_root_mean_squared_error: 0.0027
# Epoch 13/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 7.8550e-07 - root_mean_squared_error: 8.8628e-04 - val_loss: 4.3654e-09 - val_root_mean_squared_error: 6.6071e-05
# Epoch 14/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 6.8551e-07 - root_mean_squared_error: 8.2796e-04 - val_loss: 5.8742e-09 - val_root_mean_squared_error: 7.6643e-05
# Epoch 15/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 7.3600e-07 - root_mean_squared_error: 8.5791e-04 - val_loss: 5.3178e-09 - val_root_mean_squared_error: 7.2923e-05
# Epoch 16/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 6.9565e-07 - root_mean_squared_error: 8.3406e-04 - val_loss: 2.9515e-09 - val_root_mean_squared_error: 5.4328e-05
# Epoch 17/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 6.0352e-07 - root_mean_squared_error: 7.7687e-04 - val_loss: 1.9085e-08 - val_root_mean_squared_error: 1.3815e-04
# Epoch 18/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 7.1821e-07 - root_mean_squared_error: 8.4747e-04 - val_loss: 4.9088e-08 - val_root_mean_squared_error: 2.2156e-04
# Epoch 19/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 6.2639e-07 - root_mean_squared_error: 7.9145e-04 - val_loss: 5.2197e-09 - val_root_mean_squared_error: 7.2248e-05
# Epoch 20/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 5.1982e-07 - root_mean_squared_error: 7.2099e-04 - val_loss: 8.0559e-09 - val_root_mean_squared_error: 8.9755e-05
# Epoch 21/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 5.0430e-07 - root_mean_squared_error: 7.1014e-04 - val_loss: 2.5767e-08 - val_root_mean_squared_error: 1.6052e-04
# Epoch 22/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 6.7595e-07 - root_mean_squared_error: 8.2216e-04 - val_loss: 1.2392e-07 - val_root_mean_squared_error: 3.5203e-04
# Epoch 23/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 5.8308e-07 - root_mean_squared_error: 7.6360e-04 - val_loss: 5.6172e-07 - val_root_mean_squared_error: 7.4948e-04
# Epoch 24/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 6.2901e-07 - root_mean_squared_error: 7.9310e-04 - val_loss: 2.3277e-07 - val_root_mean_squared_error: 4.8247e-04
# Epoch 25/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 5.0924e-07 - root_mean_squared_error: 7.1361e-04 - val_loss: 1.1260e-09 - val_root_mean_squared_error: 3.3557e-05
# Epoch 26/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 6.0673e-07 - root_mean_squared_error: 7.7893e-04 - val_loss: 3.3887e-08 - val_root_mean_squared_error: 1.8409e-04
# Epoch 27/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 5.0839e-07 - root_mean_squared_error: 7.1302e-04 - val_loss: 4.1277e-08 - val_root_mean_squared_error: 2.0317e-04
# Epoch 28/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 4.7043e-07 - root_mean_squared_error: 6.8588e-04 - val_loss: 3.8842e-09 - val_root_mean_squared_error: 6.2323e-05
# Epoch 29/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 5.1713e-07 - root_mean_squared_error: 7.1912e-04 - val_loss: 4.6489e-08 - val_root_mean_squared_error: 2.1561e-04
# Epoch 30/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 4.3271e-07 - root_mean_squared_error: 6.5781e-04 - val_loss: 6.9590e-10 - val_root_mean_squared_error: 2.6380e-05
# Epoch 31/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 4.5242e-07 - root_mean_squared_error: 6.7263e-04 - val_loss: 8.8918e-10 - val_root_mean_squared_error: 2.9819e-05
# Epoch 32/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 6.4175e-07 - root_mean_squared_error: 8.0109e-04 - val_loss: 2.4567e-08 - val_root_mean_squared_error: 1.5674e-04
# Epoch 33/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 6.4678e-07 - root_mean_squared_error: 8.0423e-04 - val_loss: 2.9330e-08 - val_root_mean_squared_error: 1.7126e-04
# Epoch 34/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 4.5147e-07 - root_mean_squared_error: 6.7192e-04 - val_loss: 8.5190e-07 - val_root_mean_squared_error: 9.2299e-04
# Epoch 35/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 4.2646e-07 - root_mean_squared_error: 6.5304e-04 - val_loss: 6.8773e-08 - val_root_mean_squared_error: 2.6225e-04
# Epoch 36/100
# 3596/3596 [==============================] - 33s 9ms/step - loss: 4.4976e-07 - root_mean_squared_error: 6.7064e-04 - val_loss: 2.2019e-09 - val_root_mean_squared_error: 4.6925e-05
# Epoch 37/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 5.2937e-07 - root_mean_squared_error: 7.2758e-04 - val_loss: 1.2459e-07 - val_root_mean_squared_error: 3.5297e-04
# Epoch 38/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 3.9155e-07 - root_mean_squared_error: 6.2574e-04 - val_loss: 4.1497e-10 - val_root_mean_squared_error: 2.0371e-05
# Epoch 39/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 4.0679e-07 - root_mean_squared_error: 6.3780e-04 - val_loss: 3.2613e-07 - val_root_mean_squared_error: 5.7108e-04
# Epoch 40/100
# 3596/3596 [==============================] - 29s 8ms/step - loss: 5.3876e-07 - root_mean_squared_error: 7.3400e-04 - val_loss: 3.1879e-10 - val_root_mean_squared_error: 1.7855e-05
# Epoch 41/100
# 3596/3596 [==============================] - 31s 8ms/step - loss: 3.6808e-07 - root_mean_squared_error: 6.0670e-04 - val_loss: 1.7308e-08 - val_root_mean_squared_error: 1.3156e-04
# Epoch 42/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 3.2579e-07 - root_mean_squared_error: 5.7078e-04 - val_loss: 8.9559e-08 - val_root_mean_squared_error: 2.9926e-04
# Epoch 43/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 5.7257e-07 - root_mean_squared_error: 7.5668e-04 - val_loss: 9.4290e-10 - val_root_mean_squared_error: 3.0707e-05
# Epoch 44/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 3.5941e-07 - root_mean_squared_error: 5.9951e-04 - val_loss: 4.3180e-10 - val_root_mean_squared_error: 2.0780e-05
# Epoch 45/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 3.5101e-07 - root_mean_squared_error: 5.9246e-04 - val_loss: 1.9092e-07 - val_root_mean_squared_error: 4.3694e-04
# Epoch 46/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 5.5373e-07 - root_mean_squared_error: 7.4413e-04 - val_loss: 2.5690e-06 - val_root_mean_squared_error: 0.0016
# Epoch 47/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 4.1618e-07 - root_mean_squared_error: 6.4512e-04 - val_loss: 3.6026e-09 - val_root_mean_squared_error: 6.0022e-05
# Epoch 48/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 2.8955e-07 - root_mean_squared_error: 5.3810e-04 - val_loss: 3.1108e-08 - val_root_mean_squared_error: 1.7638e-04
# Epoch 49/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 5.4824e-07 - root_mean_squared_error: 7.4043e-04 - val_loss: 7.5207e-08 - val_root_mean_squared_error: 2.7424e-04
# Epoch 50/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 2.9845e-07 - root_mean_squared_error: 5.4630e-04 - val_loss: 4.5658e-08 - val_root_mean_squared_error: 2.1368e-04
# 14384/14384 [==============================] - 28s 2ms/step
# 14384/14384 [==============================] - 35s 2ms/step - loss: 3.1879e-10 - root_mean_squared_error: 1.7855e-05
# Signal to Noise Ratio (SNR) fold-3: tf.Tensor(82.38244120988593, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-3: 1.785470340109896e-05
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 3596/3596 [==============================] - 34s 9ms/step - loss: 7.7766e-04 - root_mean_squared_error: 0.0279 - val_loss: 1.2825e-06 - val_root_mean_squared_error: 0.0011
# Epoch 2/100
# 3596/3596 [==============================] - 31s 8ms/step - loss: 2.2248e-06 - root_mean_squared_error: 0.0015 - val_loss: 6.1641e-07 - val_root_mean_squared_error: 7.8512e-04
# Epoch 3/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 2.0887e-06 - root_mean_squared_error: 0.0014 - val_loss: 9.7568e-07 - val_root_mean_squared_error: 9.8776e-04
# Epoch 4/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.6466e-06 - root_mean_squared_error: 0.0013 - val_loss: 1.6202e-06 - val_root_mean_squared_error: 0.0013
# Epoch 5/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.4870e-06 - root_mean_squared_error: 0.0012 - val_loss: 9.1491e-09 - val_root_mean_squared_error: 9.5651e-05
# Epoch 6/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.4599e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.3827e-08 - val_root_mean_squared_error: 1.1759e-04
# Epoch 7/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.2972e-06 - root_mean_squared_error: 0.0011 - val_loss: 7.2582e-07 - val_root_mean_squared_error: 8.5195e-04
# Epoch 8/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.3004e-06 - root_mean_squared_error: 0.0011 - val_loss: 1.8430e-07 - val_root_mean_squared_error: 4.2930e-04
# Epoch 9/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.3666e-06 - root_mean_squared_error: 0.0012 - val_loss: 8.9848e-09 - val_root_mean_squared_error: 9.4788e-05
# Epoch 10/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.5162e-06 - root_mean_squared_error: 0.0012 - val_loss: 1.0285e-06 - val_root_mean_squared_error: 0.0010
# Epoch 11/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 1.1421e-06 - root_mean_squared_error: 0.0011 - val_loss: 6.0353e-09 - val_root_mean_squared_error: 7.7687e-05
# Epoch 12/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 9.4465e-07 - root_mean_squared_error: 9.7193e-04 - val_loss: 2.4861e-08 - val_root_mean_squared_error: 1.5767e-04
# Epoch 13/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.0361e-06 - root_mean_squared_error: 0.0010 - val_loss: 2.1603e-07 - val_root_mean_squared_error: 4.6478e-04
# Epoch 14/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 1.0495e-06 - root_mean_squared_error: 0.0010 - val_loss: 8.3124e-06 - val_root_mean_squared_error: 0.0029
# Epoch 15/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 7.6486e-07 - root_mean_squared_error: 8.7456e-04 - val_loss: 9.5231e-08 - val_root_mean_squared_error: 3.0859e-04
# Epoch 16/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 9.2480e-07 - root_mean_squared_error: 9.6167e-04 - val_loss: 6.4981e-09 - val_root_mean_squared_error: 8.0611e-05
# Epoch 17/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 7.2446e-07 - root_mean_squared_error: 8.5115e-04 - val_loss: 7.4168e-08 - val_root_mean_squared_error: 2.7234e-04
# Epoch 18/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 7.1991e-07 - root_mean_squared_error: 8.4848e-04 - val_loss: 4.0961e-07 - val_root_mean_squared_error: 6.4001e-04
# Epoch 19/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 6.5142e-07 - root_mean_squared_error: 8.0711e-04 - val_loss: 9.4490e-08 - val_root_mean_squared_error: 3.0739e-04
# Epoch 20/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 7.6380e-07 - root_mean_squared_error: 8.7396e-04 - val_loss: 1.1650e-06 - val_root_mean_squared_error: 0.0011
# Epoch 21/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 7.1187e-07 - root_mean_squared_error: 8.4373e-04 - val_loss: 5.4365e-09 - val_root_mean_squared_error: 7.3732e-05
# Epoch 22/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 6.0556e-07 - root_mean_squared_error: 7.7818e-04 - val_loss: 7.7310e-07 - val_root_mean_squared_error: 8.7926e-04
# Epoch 23/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 5.2172e-07 - root_mean_squared_error: 7.2230e-04 - val_loss: 3.0195e-08 - val_root_mean_squared_error: 1.7377e-04
# Epoch 24/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 6.4392e-07 - root_mean_squared_error: 8.0245e-04 - val_loss: 2.2777e-08 - val_root_mean_squared_error: 1.5092e-04
# Epoch 25/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 5.9863e-07 - root_mean_squared_error: 7.7371e-04 - val_loss: 1.7966e-09 - val_root_mean_squared_error: 4.2386e-05
# Epoch 26/100
# 3596/3596 [==============================] - 29s 8ms/step - loss: 5.5797e-07 - root_mean_squared_error: 7.4697e-04 - val_loss: 1.0979e-08 - val_root_mean_squared_error: 1.0478e-04
# Epoch 27/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 5.5566e-07 - root_mean_squared_error: 7.4542e-04 - val_loss: 6.3667e-09 - val_root_mean_squared_error: 7.9792e-05
# Epoch 28/100
# 3596/3596 [==============================] - 29s 8ms/step - loss: 6.0359e-07 - root_mean_squared_error: 7.7691e-04 - val_loss: 5.6296e-07 - val_root_mean_squared_error: 7.5030e-04
# Epoch 29/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 6.1639e-07 - root_mean_squared_error: 7.8511e-04 - val_loss: 1.5715e-09 - val_root_mean_squared_error: 3.9643e-05
# Epoch 30/100
# 3596/3596 [==============================] - 29s 8ms/step - loss: 4.7688e-07 - root_mean_squared_error: 6.9057e-04 - val_loss: 2.1380e-09 - val_root_mean_squared_error: 4.6239e-05
# Epoch 31/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 7.9403e-07 - root_mean_squared_error: 8.9109e-04 - val_loss: 1.3529e-09 - val_root_mean_squared_error: 3.6781e-05
# Epoch 32/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 4.8272e-07 - root_mean_squared_error: 6.9478e-04 - val_loss: 1.8156e-09 - val_root_mean_squared_error: 4.2610e-05
# Epoch 33/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 7.1773e-07 - root_mean_squared_error: 8.4719e-04 - val_loss: 3.1613e-09 - val_root_mean_squared_error: 5.6225e-05
# Epoch 34/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 3.8668e-07 - root_mean_squared_error: 6.2184e-04 - val_loss: 6.4194e-09 - val_root_mean_squared_error: 8.0121e-05
# Epoch 35/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 5.1929e-07 - root_mean_squared_error: 7.2062e-04 - val_loss: 3.3231e-09 - val_root_mean_squared_error: 5.7646e-05
# Epoch 36/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 4.8132e-07 - root_mean_squared_error: 6.9377e-04 - val_loss: 6.8831e-10 - val_root_mean_squared_error: 2.6236e-05
# Epoch 37/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 4.1339e-07 - root_mean_squared_error: 6.4295e-04 - val_loss: 1.0768e-06 - val_root_mean_squared_error: 0.0010
# Epoch 38/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 3.5339e-07 - root_mean_squared_error: 5.9446e-04 - val_loss: 6.7068e-08 - val_root_mean_squared_error: 2.5897e-04
# Epoch 39/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 3.4485e-07 - root_mean_squared_error: 5.8724e-04 - val_loss: 9.8461e-08 - val_root_mean_squared_error: 3.1379e-04
# Epoch 40/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 3.2357e-07 - root_mean_squared_error: 5.6883e-04 - val_loss: 2.4397e-08 - val_root_mean_squared_error: 1.5620e-04
# Epoch 41/100
# 3596/3596 [==============================] - 31s 9ms/step - loss: 4.2809e-07 - root_mean_squared_error: 6.5429e-04 - val_loss: 1.6840e-09 - val_root_mean_squared_error: 4.1037e-05
# Epoch 42/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 3.3672e-07 - root_mean_squared_error: 5.8028e-04 - val_loss: 6.1379e-10 - val_root_mean_squared_error: 2.4775e-05
# Epoch 43/100
# 3596/3596 [==============================] - 32s 9ms/step - loss: 4.0068e-07 - root_mean_squared_error: 6.3300e-04 - val_loss: 1.3364e-09 - val_root_mean_squared_error: 3.6557e-05
# Epoch 44/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 4.3518e-07 - root_mean_squared_error: 6.5968e-04 - val_loss: 1.1783e-09 - val_root_mean_squared_error: 3.4327e-05
# Epoch 45/100
# 3596/3596 [==============================] - 30s 8ms/step - loss: 4.1006e-07 - root_mean_squared_error: 6.4036e-04 - val_loss: 6.9221e-09 - val_root_mean_squared_error: 8.3199e-05
# Epoch 46/100
# 3596/3596 [==============================] - 28s 8ms/step - loss: 3.7612e-07 - root_mean_squared_error: 6.1329e-04 - val_loss: 1.2510e-09 - val_root_mean_squared_error: 3.5369e-05
# Epoch 47/100
# 3596/3596 [==============================] - 28s 8ms/step - loss: 2.7329e-07 - root_mean_squared_error: 5.2277e-04 - val_loss: 3.4900e-07 - val_root_mean_squared_error: 5.9076e-04
# Epoch 48/100
# 3596/3596 [==============================] - 26s 7ms/step - loss: 3.9488e-07 - root_mean_squared_error: 6.2839e-04 - val_loss: 6.1837e-09 - val_root_mean_squared_error: 7.8637e-05
# Epoch 49/100
# 3596/3596 [==============================] - 25s 7ms/step - loss: 5.0815e-07 - root_mean_squared_error: 7.1285e-04 - val_loss: 4.4957e-09 - val_root_mean_squared_error: 6.7050e-05
# Epoch 50/100
# 3596/3596 [==============================] - 26s 7ms/step - loss: 3.2857e-07 - root_mean_squared_error: 5.7321e-04 - val_loss: 1.1021e-09 - val_root_mean_squared_error: 3.3198e-05
# Epoch 51/100
# 3596/3596 [==============================] - 24s 7ms/step - loss: 2.9959e-07 - root_mean_squared_error: 5.4735e-04 - val_loss: 2.7286e-07 - val_root_mean_squared_error: 5.2236e-04
# Epoch 52/100
# 3596/3596 [==============================] - 23s 6ms/step - loss: 3.6257e-07 - root_mean_squared_error: 6.0214e-04 - val_loss: 2.2709e-09 - val_root_mean_squared_error: 4.7654e-05
# 14384/14384 [==============================] - 19s 1ms/step
# 14384/14384 [==============================] - 24s 2ms/step - loss: 6.1379e-10 - root_mean_squared_error: 2.4775e-05
# Signal to Noise Ratio (SNR) fold-4: tf.Tensor(79.57664086382736, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-4: 2.4774713892838918e-05
# Dimensi data pelatihan: (1841152, 1, 1)
# Dimensi data pengujian: (460288, 1, 1)
# Epoch 1/100
# 3596/3596 [==============================] - 29s 8ms/step - loss: 9.5130e-04 - root_mean_squared_error: 0.0308 - val_loss: 4.1131e-07 - val_root_mean_squared_error: 6.4134e-04
# Epoch 2/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 1.6273e-06 - root_mean_squared_error: 0.0013 - val_loss: 4.7936e-07 - val_root_mean_squared_error: 6.9236e-04
# Epoch 3/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 1.2357e-06 - root_mean_squared_error: 0.0011 - val_loss: 2.2748e-05 - val_root_mean_squared_error: 0.0048
# Epoch 4/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 1.1325e-06 - root_mean_squared_error: 0.0011 - val_loss: 4.4353e-08 - val_root_mean_squared_error: 2.1060e-04
# Epoch 5/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 1.1139e-06 - root_mean_squared_error: 0.0011 - val_loss: 5.7634e-08 - val_root_mean_squared_error: 2.4007e-04
# Epoch 6/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 9.6758e-07 - root_mean_squared_error: 9.8365e-04 - val_loss: 3.0640e-08 - val_root_mean_squared_error: 1.7504e-04
# Epoch 7/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 9.0926e-07 - root_mean_squared_error: 9.5355e-04 - val_loss: 6.9267e-07 - val_root_mean_squared_error: 8.3227e-04
# Epoch 8/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 7.8612e-07 - root_mean_squared_error: 8.8663e-04 - val_loss: 6.4158e-06 - val_root_mean_squared_error: 0.0025
# Epoch 9/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 8.0364e-07 - root_mean_squared_error: 8.9646e-04 - val_loss: 2.0340e-07 - val_root_mean_squared_error: 4.5099e-04
# Epoch 10/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 8.0800e-07 - root_mean_squared_error: 8.9889e-04 - val_loss: 1.0042e-08 - val_root_mean_squared_error: 1.0021e-04
# Epoch 11/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 8.3569e-07 - root_mean_squared_error: 9.1416e-04 - val_loss: 6.7481e-09 - val_root_mean_squared_error: 8.2147e-05
# Epoch 12/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 7.2908e-07 - root_mean_squared_error: 8.5386e-04 - val_loss: 9.6988e-09 - val_root_mean_squared_error: 9.8483e-05
# Epoch 13/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 6.7503e-07 - root_mean_squared_error: 8.2160e-04 - val_loss: 8.2692e-09 - val_root_mean_squared_error: 9.0935e-05
# Epoch 14/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 6.3852e-07 - root_mean_squared_error: 7.9907e-04 - val_loss: 3.6387e-06 - val_root_mean_squared_error: 0.0019
# Epoch 15/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 5.8575e-07 - root_mean_squared_error: 7.6534e-04 - val_loss: 2.7496e-09 - val_root_mean_squared_error: 5.2436e-05
# Epoch 16/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 6.8269e-07 - root_mean_squared_error: 8.2625e-04 - val_loss: 1.2763e-06 - val_root_mean_squared_error: 0.0011
# Epoch 17/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 7.2553e-07 - root_mean_squared_error: 8.5178e-04 - val_loss: 3.7597e-09 - val_root_mean_squared_error: 6.1317e-05
# Epoch 18/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 6.7294e-07 - root_mean_squared_error: 8.2033e-04 - val_loss: 9.2557e-08 - val_root_mean_squared_error: 3.0423e-04
# Epoch 19/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 6.5866e-07 - root_mean_squared_error: 8.1158e-04 - val_loss: 7.4499e-09 - val_root_mean_squared_error: 8.6313e-05
# Epoch 20/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 6.1179e-07 - root_mean_squared_error: 7.8217e-04 - val_loss: 8.2815e-07 - val_root_mean_squared_error: 9.1003e-04
# Epoch 21/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 5.8258e-07 - root_mean_squared_error: 7.6327e-04 - val_loss: 5.6338e-07 - val_root_mean_squared_error: 7.5059e-04
# Epoch 22/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 6.7237e-07 - root_mean_squared_error: 8.1998e-04 - val_loss: 3.4115e-09 - val_root_mean_squared_error: 5.8408e-05
# Epoch 23/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 5.1416e-07 - root_mean_squared_error: 7.1705e-04 - val_loss: 9.0512e-09 - val_root_mean_squared_error: 9.5138e-05
# Epoch 24/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 5.5360e-07 - root_mean_squared_error: 7.4405e-04 - val_loss: 2.9201e-05 - val_root_mean_squared_error: 0.0054
# Epoch 25/100
# 3596/3596 [==============================] - 39s 11ms/step - loss: 6.0956e-07 - root_mean_squared_error: 7.8074e-04 - val_loss: 2.8669e-09 - val_root_mean_squared_error: 5.3544e-05
# 14384/14384 [==============================] - 18s 1ms/step
# 14384/14384 [==============================] - 13s 909us/step - loss: 2.7496e-09 - root_mean_squared_error: 5.2436e-05
# Signal to Noise Ratio (SNR) fold-5: tf.Tensor(72.99853521331531, shape=(), dtype=float64)
# Root Mean Squared Error (RMSE) fold-5: 5.243636769591831e-05

# %%
# Menambahkan rata-rata dari hasil SNR
average_snr = np.mean(result_snr)

# Mencetak hasil SNR dan rata-rata
k = 1
for snr_value in result_snr:
    print(f"Hasil SNR ke-{k}: {snr_value}")
    k += 1

# Mencetak rata-rata SNR
print(f"Rata-rata SNR: {average_snr}")
# Out:
# Hasil SNR ke-1: 77.73770774230177
# Hasil SNR ke-2: 72.05165992855859
# Hasil SNR ke-3: 82.38244120988593
# Hasil SNR ke-4: 79.57664086382736
# Hasil SNR ke-5: 72.99853521331531
# Rata-rata SNR: 76.9493969915778

# %%
# Menambahkan rata-rata dari hasil RMSE
average_rmse = np.mean(result_rmse)

# Mencetak hasil RMSE dan rata-rata
k = 1
for rmse_value in result_rmse:
    print(f"Hasil RMSE ke-{k}: {rmse_value}")
    k += 1

# Mencetak rata-rata RMSE
print(f"Rata-rata RMSE: {average_rmse}")
# Out:
# Hasil RMSE ke-1: 3.025729165528901e-05
# Hasil RMSE ke-2: 5.8741999964695424e-05
# Hasil RMSE ke-3: 1.785470340109896e-05
# Hasil RMSE ke-4: 2.4774713892838918e-05
# Hasil RMSE ke-5: 5.243636769591831e-05
# Rata-rata RMSE: 3.681301532196812e-05
