# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import wfdb
import os
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from keras.layers import LSTM, RepeatVector, TimeDistributed, Dense
from tensorflow.keras.models import Model
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score
import neurokit2 as nk

# %%
data_path = 'Af-Mitdb/'

# %%
# Get the list of all record files in the folder
# List of Patients
data = ['100','101','102','103','104','105','106','107',
           '108','109','111','112','113','114','115','116',
           '117','118','119','121','122','123','124','200',
           '201','202','203','205','207','208','209','210',
           '212','213','214','215','217','219','220','221',
           '222','223','228','230','231','232','233','234',
            '04015', '04043', '04048', '04126', '04746',
            '04908', '04936', '05091', '05121', '05261',
            '06426', '06453', '06995', '07162', '07859',
            '07879', '07910', '08215', '08219', '08378',
            '08405', '08434', '08455']

# %%
# Creating a Empty Dataframe
symbols_df = pd.DataFrame()

# Reading all .atr files 
for pts in data:
    # Generating filepath for all .atr file names
    file = data_path + pts
    # Saving annotation object
    annotation = wfdb.rdann(file, 'atr')
    # Extracting symbols from the object
    sym = annotation.symbol
    # Saving value counts
    values, counts = np.unique(sym, return_counts=True)
    # Writing data points into dataframe
    df_sub = pd.DataFrame({'symbol':values, 'Counts':counts, 'data Number':[pts]*len(counts)})
    # Concatenating all data points  
    symbols_df = pd.concat([symbols_df, df_sub],axis = 0)

# Loop over all records and load the signal and annotations
for record_name in data:
    record_path = os.path.join(data_path, record_name)
    record = wfdb.rdrecord(record_path)
    annotation = wfdb.rdann(record_path, 'atr', shift_samps=True)
    ecg_signal = record.p_signal[:,0]
    ecg_signal = np.nan_to_num(ecg_signal)

    # Get the signal and labels
    sig = ecg_signal
    labels = np.array(annotation.symbol)

plt.figure(figsize=(12, 4))
plt.plot(sig)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('ECG Signal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import resample, butter, filtfilt, find_peaks
import pywt
from scipy import integrate
import cv2

# Normalize the data
sig = (sig - np.mean(sig)) / np.std(sig)

# Resample the data to new_sampling_rate
new_sampling_rate = 250
record = {"fs": 1000}  # Define the sampling rate
sig_resampled = resample(sig, int(len(sig) * (new_sampling_rate / record["fs"])))

# Bandpass filter the data
lowcut = 5.0
highcut = 15.0
sampling_rate = new_sampling_rate

def bandpass_filter(data, lowcut, highcut, sampling_rate, order=4):
    nyq = 0.5 * sampling_rate
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    filtered_data = filtfilt(b, a, data)
    return filtered_data


sig_filtered = bandpass_filter(sig_resampled, lowcut, highcut, sampling_rate, order=4)

# detect R-peaks
r_peaks, _ = find_peaks(sig_filtered, height=0.5, distance=100)

# create array for marking detected peaks
peaks = np.zeros_like(sig_filtered)

# mark R-peaks
peaks[r_peaks] = sig_filtered[r_peaks]

# detect P-peaks
p_peaks, _ = find_peaks(sig_filtered[:r_peaks[0]], height=0.1, distance=50)

p_peak = p_peaks[-1] if len(p_peaks) > 0 else None

# detect Q-peaks
if p_peak is not None:
    q_peaks, _ = find_peaks(-sig_filtered[p_peak:r_peaks[0]], height=-0.2, distance=50)
    q_peak = p_peak + q_peaks[-1] if len(q_peaks) > 0 else None
else:
    q_peak = None

# detect S-peaks
s_peaks, _ = find_peaks(-sig_filtered[r_peaks[0]:r_peaks[1]], height=-0.2, distance=50)
s_peak = r_peaks[0] + s_peaks[0] if len(s_peaks) > 0 else None

# detect T-peaks
t_peaks, _ = find_peaks(sig_filtered[r_peaks[1]:], height=0.1, distance=50)
t_peak = r_peaks[1] + t_peaks[0] if len(t_peaks) > 0 else None


# modify conditional statements
if p_peak is not None and len(p_peaks) > 0:
    q_peaks, _ = find_peaks(-sig_filtered[p_peak:r_peaks[0]], height=-0.2, distance=50)
    q_peak = p_peak + q_peaks[-1]
else:
    q_peak = None

if len(s_peaks) > 0:
    s_peak = r_peaks[0] + s_peaks[0]
else:
    s_peak = None

if len(t_peaks) > 0:
    t_peak = r_peaks[1] + t_peaks[0]
else:
    t_peak = None



def wavelet_denoising(data):
    waveletname = 'db6'
    threshold = 0.04
    level = pywt.dwt_max_level(len(data), waveletname)
    coeff = pywt.wavedec(data, waveletname, level=level)
    sigma = threshold*np.median(np.abs(coeff[-level]))
    uthresh = sigma*np.sqrt(2*np.log(len(data)))
    coeff[1:] = (pywt.threshold(i, value=uthresh, mode='soft') for i in coeff[1:])
    reconstructed_signal = pywt.waverec(coeff, waveletname)
    return reconstructed_signal

sig_denoised = wavelet_denoising(sig_filtered)

# Define signal parameters
fs = 1000  # Sampling frequency
f = 500  # ECG frequency
duration = 10  # Signal duration (in seconds)

# Generate time vector
t = np.arange(0, duration, 1/fs)

# Generate ECG signal
sig = integrate.cumulative_trapezoid(np.sin(2*np.pi*f*t), t, initial=0)


# Print the shape of the signal and labels
print("Signal shape:", sig_denoised.shape)
print("Labels shape:", labels.shape)

# plot ECG signal with R-peaks
plt.figure(figsize=(15, 5))
plt.plot(sig_filtered, label='ECG')
plt.plot(r_peaks, peaks[r_peaks], 'or', markersize=10, label='R-Peaks', linestyle='None')

# plot P, Q, S, T peaks
if p_peak is not None:
  plt.plot(p_peak, sig_filtered[p_peak], 'og', markersize=10, label='P-Peak', linestyle='None')
if q_peak is not None:
  plt.plot(q_peak, sig_filtered[q_peak], 'ob', markersize=10, label='Q-Peak', linestyle='None')
if s_peak is not None:
  plt.plot(s_peak, sig_filtered[s_peak], 'ok', markersize=10, label='S-Peak', linestyle='None')
if t_peak is not None:
  plt.plot(t_peak, sig_filtered[t_peak], 'oy', markersize=10, label='T-Peak', linestyle='None')

plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('ECG with R-peaks, P, Q, S, T peaks')
plt.legend()
plt.show()
# Out:
# Signal shape: (2301440,)
# Labels shape: (4,)

# %%
#show label
wfdb.io.show_ann_labels()
wfdb.io.show_ann_classes()
# Out:
#     label_store symbol                                    description
# 0             0                              Not an actual annotation
# 1             1      N                                    Normal beat
# 2             2      L                  Left bundle branch block beat
# 3             3      R                 Right bundle branch block beat
# 4             4      a                Aberrated atrial premature beat
# 5             5      V              Premature ventricular contraction
# 6             6      F          Fusion of ventricular and normal beat
# 7             7      J              Nodal (junctional) premature beat
# 8             8      A                   Atrial premature contraction
# 9             9      S     Premature or ectopic supraventricular beat
# 10           10      E                        Ventricular escape beat
# 11           11      j                 Nodal (junctional) escape beat
# 12           12      /                                     Paced beat
# 13           13      Q                            Unclassifiable beat
# 14           14      ~                          Signal quality change
# 16           16      |                     Isolated QRS-like artifact
# 18           18      s                                      ST change
# 19           19      T                                  T-wave change
# 20           20      *                                        Systole
# 21           21      D                                       Diastole
# 22           22      "                             Comment annotation
# 23           23      =                         Measurement annotation
# 24           24      p                                    P-wave peak
# 25           25      B              Left or right bundle branch block
# 26           26      ^                      Non-conducted pacer spike
# 27           27      t                                    T-wave peak
# 28           28      +                                  Rhythm change
# 29           29      u                                    U-wave peak
# 30           30      ?                                       Learning
# 31           31      !                       Ventricular flutter wave
# 32           32      [      Start of ventricular flutter/fibrillation
# 33           33      ]        End of ventricular flutter/fibrillation
# 34           34      e                             Atrial escape beat
# 35           35      n                   Supraventricular escape beat
# 36           36      @  Link to external data (aux_note contains URL)
# 37           37      x             Non-conducted P-wave (blocked APB)
# 38           38      f                Fusion of paced and normal beat
# 39           39      (                                 Waveform onset
# 40           40      )                                   Waveform end
# 41           41      r       R-on-T premature ventricular contraction
#      extension                        description  human_reviewed
# atr        atr          Reference ECG annotations            True
# blh        blh         Human reviewed beat labels            True
# blm        blm                Machine beat labels           False
# alh        alh              Human reviewed alarms            True
# alm        alm                     Machine alarms           False
# qrsc      qrsc      Human reviewed QRS detections            True
# qrs        qrs             Machine QRS detections           False
# bph        bph  Human reviewed BP beat detections            True
# bpm        bpm         Machine BP beat detections           False

# %%
# Symbols Dataframe
symbols_df
# Out:
#    symbol  Counts data Number
# 0       +       1         100
# 1       A      33         100
# 2       N    2239         100
# 3       V       1         100
# 0       +       1         101
# ..    ...     ...         ...
# 0       +      79       08219
# 0       +      17       08378
# 0       +       4       08405
# 0       +       7       08434
# 0       +       4       08455
#
# [306 rows x 3 columns]

# %%
# Value Counts of Different symbols in data
symbols_df.groupby('symbol').Counts.sum().sort_values(ascending = False)
# Out:
# symbol
# N    75052
# L     8075
# R     7259
# V     7130
# /     7028
# A     2546
# +     1896
# f      982
# F      803
# ~      616
# !      472
# "      437
# j      229
# x      193
# a      150
# |      132
# E      106
# J       83
# Q       33
# e       16
# [        6
# ]        6
# S        2
# Name: Counts, dtype: int64

# %%
# Abnormal Beat Symbols
AF = ['f']
PAC = ['A']
PVC = ['V']

abnormal_category = AF + PAC + PVC

# Classifying abnormal beats into more specific categories
symbols_df.loc[symbols_df.symbol.isin(AF), 'abnormal_category'] = "AF"
symbols_df.loc[symbols_df.symbol.isin(PAC), 'abnormal_category'] = "PAC"
symbols_df.loc[symbols_df.symbol.isin(PVC), 'abnormal_category'] = "PVC"

# Value counts of different categories
symbols_df.groupby('abnormal_category').Counts.sum()
# Out:
# abnormal_category
# AF      982
# PAC    2546
# PVC    7130
# Name: Counts, dtype: int64

# %%
def load_ecg(file):
    # load the ecg
    record = wfdb.rdrecord(file)
    # load the annotation
    annotation = wfdb.rdann(file, 'atr')

    # extracting the signal
    p_signal = record.p_signal

    # extracting symbols and annotation index
    atr_sym = annotation.symbol
    atr_sample = annotation.sample

    return p_signal, atr_sym, atr_sample

# %%
# Accessing the ecg points for
file = data_path + data[8]

# %%
# Accessing the load ECG function and getting annotation.symbol, annotation.sample, signals
p_signal, atr_sym, atr_sample = load_ecg(file)

# %%
# Analysing annotations value counts for a single record
values, counts = np.unique(sym, return_counts=True)
for v,c in zip(values, counts):
    print(v,c)
# Out:
# + 4

# %%
# get abnormal beat index
ab_index = [b for a,b in zip(atr_sym,atr_sample) if a in abnormal_category][:10]
ab_index
# Out:
# [4105, 10876, 83824, 107330, 180041, 193553, 205731, 221206, 263192, 268697]

# %%
# Generating evenly spaced values
x = np.arange(len(p_signal))

left = ab_index[5]-20000
right = ab_index[5]+20000

plt.figure(figsize=(20,8))
plt.plot(x[left:right],p_signal[left:right,0],'-',label='ecg',)
plt.plot(x[atr_sample],p_signal[atr_sample,0],'go',label ='normal')
plt.plot(x[ab_index],p_signal[ab_index,0],'ro',label='abnormal')

plt.xlim(left,right)
plt.ylim(p_signal[left:right].min()-0.05,p_signal[left:right,0].max()+0.05)
plt.xlabel('time index')
plt.ylabel('ECG signal')
plt.legend(bbox_to_anchor = (1.04,1), loc = 'upper left')
plt.show()

# %%
def make_dataset(record_patients, num_sec, fs, abnormal_category):

    # initialize numpy arrays
    num_cols = 2*num_sec * fs
    X_all = np.zeros((1,num_cols))
    Y_all = np.zeros((1,len(abnormal_category)))
    sym_all = []

    # list to keep track of number of beats across patients
    max_rows = []

    for pt in data:
        file = data_path + pt

        p_signal, atr_sym, atr_sample = load_ecg(file)

        # grab the first signal
        p_signal = p_signal[:,0]

        # make df to exclude the nonbeats
        df_ann = pd.DataFrame({'atr_sym':atr_sym,
                              'atr_sample':atr_sample})
        df_ann = df_ann.loc[df_ann.atr_sym.isin(abnormal_category)]

        num_rows = len(df_ann)

        X = np.zeros((num_rows, num_cols))
        Y = np.zeros((num_rows, len(abnormal_category)))
        sym = []

        # keep track of rows
        max_row = 0

        for atr_sample, atr_sym in zip(df_ann.atr_sample.values,df_ann.atr_sym.values):

            left = max([0,(atr_sample - num_sec*fs) ])
            right = min([len(p_signal),(atr_sample + num_sec*fs) ])
            x = p_signal[left: right]
            if len(x) == num_cols:
                X[max_row,:] = x
                Y[max_row, abnormal_category.index(atr_sym)] = 1
                sym.append(atr_sym)
                max_row += 1
        X = X[:max_row,:]
        Y = Y[:max_row,:]

        sym_all = sym_all+sym
        max_rows.append(X.shape[0])
        X_all = np.append(X_all,X,axis = 0)
        Y_all = np.append(Y_all,Y,axis = 0)

    # drop the first zero row
    X_all = X_all[1:,:]
    Y_all = Y_all[1:,:]

    return X_all, Y_all, sym_all

# %%
import seaborn as sns
# Value counts of different categories
counts_df = symbols_df.groupby('abnormal_category')['Counts'].sum().reset_index()
print(counts_df)

# Visualize the number of subjects in each abnormal_category:
sns.barplot(x='abnormal_category', y='Counts', data=counts_df)
plt.show()
# Out:
#   abnormal_category  Counts
# 0                AF     982
# 1               PAC    2546
# 2               PVC    7130

# %%
import numpy as np
from scipy.stats import kurtosis, skew
from scipy.fft import fft

def extract_features(rr_intervals):
    features = {}

    # RR Interval Features
    rr_mean = np.mean(rr_intervals)
    rr_std = np.std(rr_intervals)
    rr_min = np.min(rr_intervals)
    rr_max = np.max(rr_intervals)
    rr_range = rr_max - rr_min
    rr_median = np.median(rr_intervals)
    rr_diff = np.diff(rr_intervals)
    rr_fft = np.abs(fft(rr_intervals))
    rr_skewness = skew(rr_intervals)
    rr_kurtosis = kurtosis(rr_intervals)

    features['RR Mean'] = rr_mean
    features['RR Std'] = rr_std
    features['RR Min'] = rr_min
    features['RR Max'] = rr_max
    features['RR Range'] = rr_range
    features['RR Median'] = rr_median
    features['RR Skewness'] = rr_skewness
    features['RR Kurtosis'] = rr_kurtosis

    features['mean_rr_diff'] = np.mean(rr_diff)
    features['std_rr_diff'] = np.std(rr_diff)
    features['min_rr_diff'] = np.min(rr_diff)
    features['max_rr_diff'] = np.max(rr_diff)
    features['median_rr_diff'] = np.median(rr_diff)
    features['range_rr_diff'] = np.ptp(rr_diff)

    features['RR FFT Mean'] = np.mean(rr_fft)
    features['RR FFT Std'] = np.std(rr_fft)
    features['RR FFT Max'] = np.max(rr_fft)

    rr_variance = np.var(rr_intervals)
    rr_coefficient_of_variation = np.mean(rr_intervals) / np.std(rr_intervals)

    features['RR Variance'] = rr_variance
    features['RR Coefficient of Variation'] = rr_coefficient_of_variation

    # Additional Statistical Features
    features['RR 5th Percentile'] = np.percentile(rr_intervals, 5)
    features['RR 95th Percentile'] = np.percentile(rr_intervals, 95)
    features['RR Interquartile Range'] = np.percentile(rr_intervals, 75) - np.percentile(rr_intervals, 25)

    # Additional Dynamic Features
    rr_diff_mean = np.mean(rr_diff)
    rr_diff_std = np.std(rr_diff)
    rr_diff_min = np.min(rr_diff)
    rr_diff_max = np.max(rr_diff)
    rr_diff_median = np.median(rr_diff)
    rr_diff_range = np.ptp(rr_diff)

    features['mean_rr_diff'] = rr_diff_mean
    features['std_rr_diff'] = rr_diff_std
    features['min_rr_diff'] = rr_diff_min
    features['max_rr_diff'] = rr_diff_max
    features['median_rr_diff'] = rr_diff_median
    features['range_rr_diff'] = rr_diff_range


    return features

# %%
import matplotlib.pyplot as plt

# Set the parameters
num_sec = 3
fs = 360

# Accessing the function and creating a dataset with ECG digital points
X_all, Y_all, sym_all = make_dataset(data, num_sec, fs, abnormal_category)

# Mengambil segmen RR interval
rr_intervals = X_all[:, fs * num_sec:]

features = []
for rr in rr_intervals:
    feature = extract_features(rr)
    features.append(feature)

# Convert the features list to a dataframe
df_features = pd.DataFrame(features)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

r_peaks, _ = find_peaks(sig_denoised[:len(rr_intervals[0])], prominence=0.4)

# Plot the QRS complexes with R, Q, and S peaks
plt.figure(figsize=(10, 5))
plt.plot(sig_denoised[:len(rr_intervals[0])], color='blue', label='RR Interval')
plt.plot(r_peaks, sig_denoised[r_peaks], 'ro', markersize=4, label='R Peaks')

plt.title('RR Interval')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import numpy as np
from keras.utils import to_categorical
import pandas as pd
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
from sklearn.preprocessing import LabelEncoder, Normalizer
from sklearn.metrics import classification_report
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# Jumlah lipatan pada K-Fold
num_folds = 5

# Inisialisasi array untuk menyimpan hasil evaluasi
accuracies = []
conf_matrices = []

# Inisialisasi K-Fold Cross Validation
kfold = KFold(n_splits=num_folds, shuffle=True)

for train_index, test_index in kfold.split(df_features):
    X_train, X_val = df_features.iloc[train_index[:-50]], df_features.iloc[train_index[-50:]]
    Y_train, Y_val = Y_all[train_index[:-50]], Y_all[train_index[-50:]]
    X_test, Y_test = df_features.iloc[test_index], Y_all[test_index]

    # Standarisasi fitur input
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    # Reshape fitur input untuk CNN
    X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
    X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)
    X_test_reshaped = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

    # Number of classes for multi-label classification
    num_classes = 3

    # Build the RNN model
    model = Sequential()
    model.add(LSTM(units=64, input_shape=(X_train.shape[1], 1), return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64))
    model.add(Dropout(0.2))
    model.add(Dense(units=num_classes, activation='softmax'))

    # Menentukan EarlyStopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Mengompilasi dan melatih model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X_train_reshaped, Y_train, epochs=100, batch_size=128, validation_data=(X_val_reshaped, Y_val), callbacks=[early_stopping])

    # Evaluasi model pada data pengujian
    loss, accuracy = model.evaluate(X_test_reshaped, Y_test)
    accuracies.append(accuracy)

    # Prediksi kelas pada data pengujian
    Y_pred = model.predict(X_test_reshaped)
    Y_pred_labels = np.argmax(Y_pred, axis=1)
    Y_true_labels = np.argmax(Y_test, axis=1)

    # Matriks konfusi
    conf_matrix = confusion_matrix(Y_true_labels, Y_pred_labels, labels=np.arange(len(abnormal_category)))
    conf_matrices.append(conf_matrix)

# Rata-rata akurasi dan matriks konfusi pada semua lipatan
mean_accuracy = np.mean(accuracies)
mean_conf_matrix = np.sum(conf_matrices, axis=0)

print("Mean Accuracy:", mean_accuracy)
print("Mean Confusion Matrix:")
print(mean_conf_matrix)

# Classification report
print("Classification Report:")
print(classification_report(Y_true_labels, Y_pred_labels, labels=np.arange(len(abnormal_category)), target_names=abnormal_category))

# Menghitung sensitivity untuk setiap kelas abnormal
sensitivities = []
for i in range(len(abnormal_category)):
    true_positives = mean_conf_matrix[i, i]
    false_negatives = np.sum(mean_conf_matrix[i, :]) - true_positives
    sensitivity = true_positives / (true_positives + false_negatives)
    sensitivities.append(sensitivity)

# Menampilkan sensitivities
for i in range(len(abnormal_category)):
    print(f"Sensitivity ({abnormal_category[i]}): {sensitivities[i]}")

print('')

sensitivities = []
for conf_matrix in conf_matrices:
    tp = conf_matrix[1, 1]  # True positives
    fn = conf_matrix[1, 0]  # False negatives
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

mean_sensitivity = np.mean(sensitivities)
print("Mean Sensitivity:", mean_sensitivity)

print('')
print('==================================================================')
print('')

# Menghitung specificities untuk setiap kelas abnormal
specificities = []
for i in range(len(abnormal_category)):
    true_negatives = np.sum(mean_conf_matrix) - np.sum(mean_conf_matrix[i, :]) - np.sum(mean_conf_matrix[:, i]) + mean_conf_matrix[i, i]
    false_positives = np.sum(mean_conf_matrix[:, i]) - mean_conf_matrix[i, i]
    specificity = true_negatives / (true_negatives + false_positives)
    specificities.append(specificity)

# Menampilkan specificities
for i in range(len(abnormal_category)):
    print(f"Specificity ({abnormal_category[i]}): {specificities[i]}")

print('')

specificities = []
for conf_matrix in conf_matrices:
    tn = conf_matrix[0, 0]  # True negatives
    fp = conf_matrix[0, 1]  # False positives
    specificity = tn / (tn + fp)
    specificities.append(specificity)

mean_specificity = np.mean(specificities)
print("Mean Specificity:", mean_specificity)
# Out:
# Epoch 1/100
# 67/67 [==============================] - 8s 59ms/step - loss: 0.7285 - accuracy: 0.7525 - val_loss: 0.2621 - val_accuracy: 0.9800
# Epoch 2/100
# 67/67 [==============================] - 3s 44ms/step - loss: 0.5630 - accuracy: 0.7826 - val_loss: 0.1694 - val_accuracy: 0.9800
# Epoch 3/100
# 67/67 [==============================] - 3s 43ms/step - loss: 0.4655 - accuracy: 0.8298 - val_loss: 0.1710 - val_accuracy: 0.9800
# Epoch 4/100
# 67/67 [==============================] - 4s 64ms/step - loss: 0.4099 - accuracy: 0.8525 - val_loss: 0.1516 - val_accuracy: 0.9800
# Epoch 5/100
# 67/67 [==============================] - 5s 74ms/step - loss: 0.3722 - accuracy: 0.8713 - val_loss: 0.1630 - val_accuracy: 0.9600
# Epoch 6/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.3390 - accuracy: 0.8866 - val_loss: 0.1680 - val_accuracy: 0.9600
# Epoch 7/100
# 67/67 [==============================] - 5s 75ms/step - loss: 0.3217 - accuracy: 0.8887 - val_loss: 0.2352 - val_accuracy: 0.9400
# Epoch 8/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.2875 - accuracy: 0.9066 - val_loss: 0.1371 - val_accuracy: 0.9600
# Epoch 9/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.2811 - accuracy: 0.9133 - val_loss: 0.1484 - val_accuracy: 0.9600
# Epoch 10/100
# 67/67 [==============================] - 5s 74ms/step - loss: 0.2398 - accuracy: 0.9250 - val_loss: 0.1406 - val_accuracy: 0.9600
# Epoch 11/100
# 67/67 [==============================] - 5s 74ms/step - loss: 0.2286 - accuracy: 0.9269 - val_loss: 0.1475 - val_accuracy: 0.9600
# Epoch 12/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.2111 - accuracy: 0.9344 - val_loss: 0.1160 - val_accuracy: 0.9800
# Epoch 13/100
# 67/67 [==============================] - 5s 74ms/step - loss: 0.1959 - accuracy: 0.9406 - val_loss: 0.1514 - val_accuracy: 0.9600
# Epoch 14/100
# 67/67 [==============================] - 5s 74ms/step - loss: 0.1872 - accuracy: 0.9407 - val_loss: 0.1435 - val_accuracy: 0.9800
# Epoch 15/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.2194 - accuracy: 0.9297 - val_loss: 0.2239 - val_accuracy: 0.9400
# Epoch 16/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1764 - accuracy: 0.9431 - val_loss: 0.1174 - val_accuracy: 0.9800
# Epoch 17/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1657 - accuracy: 0.9470 - val_loss: 0.1137 - val_accuracy: 0.9800
# Epoch 18/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1650 - accuracy: 0.9454 - val_loss: 0.1343 - val_accuracy: 0.9600
# Epoch 19/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1493 - accuracy: 0.9503 - val_loss: 0.2311 - val_accuracy: 0.9400
# Epoch 20/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1491 - accuracy: 0.9514 - val_loss: 0.1369 - val_accuracy: 0.9600
# Epoch 21/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1472 - accuracy: 0.9521 - val_loss: 0.1521 - val_accuracy: 0.9400
# Epoch 22/100
# 67/67 [==============================] - 5s 76ms/step - loss: 0.1353 - accuracy: 0.9549 - val_loss: 0.1415 - val_accuracy: 0.9400
# Epoch 23/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1397 - accuracy: 0.9539 - val_loss: 0.1365 - val_accuracy: 0.9600
# Epoch 24/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1329 - accuracy: 0.9552 - val_loss: 0.1289 - val_accuracy: 0.9600
# Epoch 25/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1316 - accuracy: 0.9562 - val_loss: 0.1439 - val_accuracy: 0.9400
# Epoch 26/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1235 - accuracy: 0.9593 - val_loss: 0.1102 - val_accuracy: 0.9800
# Epoch 27/100
# 67/67 [==============================] - 5s 70ms/step - loss: 0.1211 - accuracy: 0.9593 - val_loss: 0.1854 - val_accuracy: 0.9400
# Epoch 28/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1230 - accuracy: 0.9598 - val_loss: 0.1174 - val_accuracy: 0.9800
# Epoch 29/100
# 67/67 [==============================] - 5s 70ms/step - loss: 0.1153 - accuracy: 0.9618 - val_loss: 0.1195 - val_accuracy: 0.9800
# Epoch 30/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1190 - accuracy: 0.9595 - val_loss: 0.1489 - val_accuracy: 0.9600
# Epoch 31/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1119 - accuracy: 0.9612 - val_loss: 0.1375 - val_accuracy: 0.9600
# Epoch 32/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1604 - accuracy: 0.9494 - val_loss: 0.1257 - val_accuracy: 0.9600
# Epoch 33/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1115 - accuracy: 0.9625 - val_loss: 0.1050 - val_accuracy: 0.9800
# Epoch 34/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1093 - accuracy: 0.9643 - val_loss: 0.1144 - val_accuracy: 0.9800
# Epoch 35/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1028 - accuracy: 0.9642 - val_loss: 0.1002 - val_accuracy: 0.9800
# Epoch 36/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0985 - accuracy: 0.9664 - val_loss: 0.1237 - val_accuracy: 0.9400
# Epoch 37/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1041 - accuracy: 0.9657 - val_loss: 0.1171 - val_accuracy: 0.9800
# Epoch 38/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1081 - accuracy: 0.9620 - val_loss: 0.1150 - val_accuracy: 0.9800
# Epoch 39/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0959 - accuracy: 0.9668 - val_loss: 0.1260 - val_accuracy: 0.9600
# Epoch 40/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0907 - accuracy: 0.9701 - val_loss: 0.1196 - val_accuracy: 0.9800
# Epoch 41/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0900 - accuracy: 0.9697 - val_loss: 0.1025 - val_accuracy: 0.9800
# Epoch 42/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0851 - accuracy: 0.9711 - val_loss: 0.1824 - val_accuracy: 0.9400
# Epoch 43/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0914 - accuracy: 0.9687 - val_loss: 0.1005 - val_accuracy: 0.9800
# Epoch 44/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0854 - accuracy: 0.9705 - val_loss: 0.1131 - val_accuracy: 0.9600
# Epoch 45/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.0861 - accuracy: 0.9716 - val_loss: 0.0968 - val_accuracy: 0.9800
# Epoch 46/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0874 - accuracy: 0.9681 - val_loss: 0.1038 - val_accuracy: 0.9800
# Epoch 47/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.0925 - accuracy: 0.9695 - val_loss: 0.0998 - val_accuracy: 0.9600
# Epoch 48/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0821 - accuracy: 0.9744 - val_loss: 0.1025 - val_accuracy: 0.9800
# Epoch 49/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0788 - accuracy: 0.9726 - val_loss: 0.0847 - val_accuracy: 0.9800
# Epoch 50/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0754 - accuracy: 0.9735 - val_loss: 0.1161 - val_accuracy: 0.9800
# Epoch 51/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0895 - accuracy: 0.9685 - val_loss: 0.0742 - val_accuracy: 0.9800
# Epoch 52/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.0785 - accuracy: 0.9721 - val_loss: 0.0946 - val_accuracy: 0.9800
# Epoch 53/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0734 - accuracy: 0.9729 - val_loss: 0.0744 - val_accuracy: 0.9800
# Epoch 54/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.0922 - accuracy: 0.9681 - val_loss: 0.2372 - val_accuracy: 0.9400
# Epoch 55/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.0801 - accuracy: 0.9723 - val_loss: 0.0715 - val_accuracy: 0.9800
# Epoch 56/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0739 - accuracy: 0.9747 - val_loss: 0.0793 - val_accuracy: 0.9800
# Epoch 57/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0825 - accuracy: 0.9715 - val_loss: 0.1221 - val_accuracy: 0.9600
# Epoch 58/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0687 - accuracy: 0.9765 - val_loss: 0.1050 - val_accuracy: 0.9800
# Epoch 59/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0887 - accuracy: 0.9687 - val_loss: 0.1021 - val_accuracy: 0.9800
# Epoch 60/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0686 - accuracy: 0.9765 - val_loss: 0.0976 - val_accuracy: 0.9800
# Epoch 61/100
# 67/67 [==============================] - 5s 70ms/step - loss: 0.0632 - accuracy: 0.9773 - val_loss: 0.0957 - val_accuracy: 0.9800
# Epoch 62/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0651 - accuracy: 0.9769 - val_loss: 0.0836 - val_accuracy: 0.9800
# Epoch 63/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0704 - accuracy: 0.9759 - val_loss: 0.1163 - val_accuracy: 0.9600
# Epoch 64/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1314 - accuracy: 0.9587 - val_loss: 0.0817 - val_accuracy: 0.9800
# Epoch 65/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0722 - accuracy: 0.9760 - val_loss: 0.0982 - val_accuracy: 0.9800
# 67/67 [==============================] - 1s 12ms/step - loss: 0.1505 - accuracy: 0.9544
# 67/67 [==============================] - 2s 11ms/step
# Epoch 1/100
# 67/67 [==============================] - 13s 85ms/step - loss: 0.7295 - accuracy: 0.7467 - val_loss: 0.2092 - val_accuracy: 1.0000
# Epoch 2/100
# 67/67 [==============================] - 2s 36ms/step - loss: 0.5401 - accuracy: 0.7889 - val_loss: 0.1338 - val_accuracy: 1.0000
# Epoch 3/100
# 67/67 [==============================] - 2s 36ms/step - loss: 0.4614 - accuracy: 0.8331 - val_loss: 0.1235 - val_accuracy: 0.9600
# Epoch 4/100
# 67/67 [==============================] - 2s 37ms/step - loss: 0.4042 - accuracy: 0.8563 - val_loss: 0.1531 - val_accuracy: 0.9600
# Epoch 5/100
# 67/67 [==============================] - 2s 36ms/step - loss: 0.3781 - accuracy: 0.8699 - val_loss: 0.0933 - val_accuracy: 0.9800
# Epoch 6/100
# 67/67 [==============================] - 2s 37ms/step - loss: 0.3559 - accuracy: 0.8805 - val_loss: 0.0944 - val_accuracy: 0.9800
# Epoch 7/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.3254 - accuracy: 0.8873 - val_loss: 0.1280 - val_accuracy: 0.9600
# Epoch 8/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.3068 - accuracy: 0.8967 - val_loss: 0.0880 - val_accuracy: 0.9600
# Epoch 9/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.2721 - accuracy: 0.9145 - val_loss: 0.0727 - val_accuracy: 0.9600
# Epoch 10/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.2531 - accuracy: 0.9203 - val_loss: 0.0427 - val_accuracy: 0.9800
# Epoch 11/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.2352 - accuracy: 0.9253 - val_loss: 0.1193 - val_accuracy: 0.9600
# Epoch 12/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.2203 - accuracy: 0.9289 - val_loss: 0.0681 - val_accuracy: 0.9600
# Epoch 13/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.2190 - accuracy: 0.9295 - val_loss: 0.0787 - val_accuracy: 0.9800
# Epoch 14/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1911 - accuracy: 0.9385 - val_loss: 0.1011 - val_accuracy: 0.9600
# Epoch 15/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1795 - accuracy: 0.9416 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 16/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.1730 - accuracy: 0.9446 - val_loss: 0.1239 - val_accuracy: 0.9600
# Epoch 17/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.1682 - accuracy: 0.9444 - val_loss: 0.1171 - val_accuracy: 0.9600
# Epoch 18/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.1628 - accuracy: 0.9459 - val_loss: 0.0848 - val_accuracy: 0.9800
# Epoch 19/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1545 - accuracy: 0.9465 - val_loss: 0.0329 - val_accuracy: 0.9800
# Epoch 20/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1499 - accuracy: 0.9501 - val_loss: 0.0448 - val_accuracy: 0.9800
# Epoch 21/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.1468 - accuracy: 0.9502 - val_loss: 0.0631 - val_accuracy: 0.9800
# Epoch 22/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1450 - accuracy: 0.9503 - val_loss: 0.1150 - val_accuracy: 0.9800
# Epoch 23/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1371 - accuracy: 0.9535 - val_loss: 0.0764 - val_accuracy: 0.9800
# Epoch 24/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.1388 - accuracy: 0.9513 - val_loss: 0.0963 - val_accuracy: 0.9800
# Epoch 25/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1334 - accuracy: 0.9538 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 26/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1329 - accuracy: 0.9553 - val_loss: 0.0610 - val_accuracy: 0.9800
# Epoch 27/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.1313 - accuracy: 0.9545 - val_loss: 0.0385 - val_accuracy: 0.9800
# Epoch 28/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1249 - accuracy: 0.9573 - val_loss: 0.0691 - val_accuracy: 0.9800
# Epoch 29/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1204 - accuracy: 0.9569 - val_loss: 0.0927 - val_accuracy: 0.9600
# Epoch 30/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.1163 - accuracy: 0.9597 - val_loss: 0.1353 - val_accuracy: 0.9600
# Epoch 31/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.1183 - accuracy: 0.9575 - val_loss: 0.0693 - val_accuracy: 0.9800
# Epoch 32/100
# 67/67 [==============================] - 4s 60ms/step - loss: 0.1182 - accuracy: 0.9582 - val_loss: 0.1173 - val_accuracy: 0.9800
# Epoch 33/100
# 67/67 [==============================] - 4s 61ms/step - loss: 0.1104 - accuracy: 0.9594 - val_loss: 0.1981 - val_accuracy: 0.9600
# Epoch 34/100
# 67/67 [==============================] - 4s 62ms/step - loss: 0.1063 - accuracy: 0.9618 - val_loss: 0.0490 - val_accuracy: 0.9800
# Epoch 35/100
# 67/67 [==============================] - 4s 62ms/step - loss: 0.1072 - accuracy: 0.9617 - val_loss: 0.2029 - val_accuracy: 0.9600
# 67/67 [==============================] - 1s 12ms/step - loss: 0.1772 - accuracy: 0.9464
# 67/67 [==============================] - 2s 12ms/step
# Epoch 1/100
# 67/67 [==============================] - 14s 97ms/step - loss: 0.7330 - accuracy: 0.7464 - val_loss: 0.2760 - val_accuracy: 0.9800
# Epoch 2/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.5716 - accuracy: 0.7818 - val_loss: 0.1439 - val_accuracy: 0.9800
# Epoch 3/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.4689 - accuracy: 0.8297 - val_loss: 0.1467 - val_accuracy: 0.9800
# Epoch 4/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.4027 - accuracy: 0.8574 - val_loss: 0.2106 - val_accuracy: 0.9200
# Epoch 5/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.3660 - accuracy: 0.8729 - val_loss: 0.2148 - val_accuracy: 0.9200
# Epoch 6/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.3395 - accuracy: 0.8831 - val_loss: 0.1392 - val_accuracy: 0.9600
# Epoch 7/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.3136 - accuracy: 0.8913 - val_loss: 0.1521 - val_accuracy: 0.9600
# Epoch 8/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.2883 - accuracy: 0.9014 - val_loss: 0.1675 - val_accuracy: 0.9600
# Epoch 9/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.2684 - accuracy: 0.9128 - val_loss: 0.1318 - val_accuracy: 0.9600
# Epoch 10/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.2518 - accuracy: 0.9195 - val_loss: 0.2101 - val_accuracy: 0.9200
# Epoch 11/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.2273 - accuracy: 0.9319 - val_loss: 0.1224 - val_accuracy: 0.9800
# Epoch 12/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.2243 - accuracy: 0.9295 - val_loss: 0.1733 - val_accuracy: 0.9200
# Epoch 13/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.2010 - accuracy: 0.9377 - val_loss: 0.2328 - val_accuracy: 0.9200
# Epoch 14/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1898 - accuracy: 0.9400 - val_loss: 0.1724 - val_accuracy: 0.9600
# Epoch 15/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1892 - accuracy: 0.9380 - val_loss: 0.1006 - val_accuracy: 0.9800
# Epoch 16/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1744 - accuracy: 0.9437 - val_loss: 0.1077 - val_accuracy: 0.9800
# Epoch 17/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1673 - accuracy: 0.9475 - val_loss: 0.2223 - val_accuracy: 0.9200
# Epoch 18/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1674 - accuracy: 0.9438 - val_loss: 0.1946 - val_accuracy: 0.9200
# Epoch 19/100
# 67/67 [==============================] - 5s 75ms/step - loss: 0.1574 - accuracy: 0.9504 - val_loss: 0.1123 - val_accuracy: 0.9600
# Epoch 20/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1509 - accuracy: 0.9500 - val_loss: 0.0931 - val_accuracy: 0.9800
# Epoch 21/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1877 - accuracy: 0.9385 - val_loss: 0.2645 - val_accuracy: 0.9200
# Epoch 22/100
# 67/67 [==============================] - 5s 73ms/step - loss: 0.1475 - accuracy: 0.9502 - val_loss: 0.1607 - val_accuracy: 0.9400
# Epoch 23/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1439 - accuracy: 0.9502 - val_loss: 0.1694 - val_accuracy: 0.9200
# Epoch 24/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1426 - accuracy: 0.9541 - val_loss: 0.1503 - val_accuracy: 0.9200
# Epoch 25/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1350 - accuracy: 0.9558 - val_loss: 0.2910 - val_accuracy: 0.9200
# Epoch 26/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1327 - accuracy: 0.9555 - val_loss: 0.1452 - val_accuracy: 0.9200
# Epoch 27/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1268 - accuracy: 0.9574 - val_loss: 0.1451 - val_accuracy: 0.9400
# Epoch 28/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1214 - accuracy: 0.9594 - val_loss: 0.2056 - val_accuracy: 0.9200
# Epoch 29/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.1195 - accuracy: 0.9586 - val_loss: 0.1977 - val_accuracy: 0.9400
# Epoch 30/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1194 - accuracy: 0.9597 - val_loss: 0.2274 - val_accuracy: 0.9200
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0988 - accuracy: 0.9657
# 67/67 [==============================] - 2s 14ms/step
# Epoch 1/100
# 67/67 [==============================] - 13s 88ms/step - loss: 0.7133 - accuracy: 0.7523 - val_loss: 0.2721 - val_accuracy: 0.9800
# Epoch 2/100
# 67/67 [==============================] - 3s 42ms/step - loss: 0.5498 - accuracy: 0.7872 - val_loss: 0.1373 - val_accuracy: 0.9800
# Epoch 3/100
# 67/67 [==============================] - 3s 41ms/step - loss: 0.4530 - accuracy: 0.8375 - val_loss: 0.1325 - val_accuracy: 0.9800
# Epoch 4/100
# 67/67 [==============================] - 3s 41ms/step - loss: 0.4007 - accuracy: 0.8595 - val_loss: 0.1415 - val_accuracy: 0.9800
# Epoch 5/100
# 67/67 [==============================] - 3s 41ms/step - loss: 0.3705 - accuracy: 0.8751 - val_loss: 0.1446 - val_accuracy: 0.9800
# Epoch 6/100
# 67/67 [==============================] - 4s 55ms/step - loss: 0.3551 - accuracy: 0.8840 - val_loss: 0.1884 - val_accuracy: 0.9400
# Epoch 7/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.3383 - accuracy: 0.8850 - val_loss: 0.1517 - val_accuracy: 0.9800
# Epoch 8/100
# 67/67 [==============================] - 5s 70ms/step - loss: 0.3075 - accuracy: 0.9004 - val_loss: 0.1157 - val_accuracy: 0.9800
# Epoch 9/100
# 67/67 [==============================] - 5s 78ms/step - loss: 0.2809 - accuracy: 0.9125 - val_loss: 0.1181 - val_accuracy: 0.9800
# Epoch 10/100
# 67/67 [==============================] - 5s 72ms/step - loss: 0.2539 - accuracy: 0.9199 - val_loss: 0.1225 - val_accuracy: 0.9800
# Epoch 11/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.2369 - accuracy: 0.9243 - val_loss: 0.1134 - val_accuracy: 0.9800
# Epoch 12/100
# 67/67 [==============================] - 5s 70ms/step - loss: 0.2123 - accuracy: 0.9320 - val_loss: 0.1069 - val_accuracy: 0.9800
# Epoch 13/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1950 - accuracy: 0.9372 - val_loss: 0.1407 - val_accuracy: 0.9400
# Epoch 14/100
# 67/67 [==============================] - 5s 70ms/step - loss: 0.1906 - accuracy: 0.9396 - val_loss: 0.1141 - val_accuracy: 0.9800
# Epoch 15/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1817 - accuracy: 0.9413 - val_loss: 0.0999 - val_accuracy: 0.9800
# Epoch 16/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1758 - accuracy: 0.9418 - val_loss: 0.1178 - val_accuracy: 0.9800
# Epoch 17/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1672 - accuracy: 0.9458 - val_loss: 0.1038 - val_accuracy: 0.9800
# Epoch 18/100
# 67/67 [==============================] - 5s 70ms/step - loss: 0.1683 - accuracy: 0.9450 - val_loss: 0.2909 - val_accuracy: 0.9400
# Epoch 19/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1610 - accuracy: 0.9467 - val_loss: 0.2427 - val_accuracy: 0.9400
# Epoch 20/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1505 - accuracy: 0.9494 - val_loss: 0.1085 - val_accuracy: 0.9800
# Epoch 21/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1519 - accuracy: 0.9495 - val_loss: 0.1003 - val_accuracy: 0.9800
# Epoch 22/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1418 - accuracy: 0.9529 - val_loss: 0.1304 - val_accuracy: 0.9600
# Epoch 23/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1451 - accuracy: 0.9528 - val_loss: 0.1015 - val_accuracy: 0.9800
# Epoch 24/100
# 67/67 [==============================] - 5s 70ms/step - loss: 0.1370 - accuracy: 0.9539 - val_loss: 0.1580 - val_accuracy: 0.9600
# Epoch 25/100
# 67/67 [==============================] - 5s 71ms/step - loss: 0.1391 - accuracy: 0.9525 - val_loss: 0.2111 - val_accuracy: 0.9400
# 67/67 [==============================] - 1s 13ms/step - loss: 0.1476 - accuracy: 0.9530
# 67/67 [==============================] - 2s 13ms/step
# Epoch 1/100
# 67/67 [==============================] - 14s 103ms/step - loss: 0.7215 - accuracy: 0.7490 - val_loss: 0.2402 - val_accuracy: 0.9800
# Epoch 2/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.5494 - accuracy: 0.7849 - val_loss: 0.1326 - val_accuracy: 0.9800
# Epoch 3/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.4635 - accuracy: 0.8291 - val_loss: 0.1484 - val_accuracy: 0.9800
# Epoch 4/100
# 67/67 [==============================] - 6s 83ms/step - loss: 0.4060 - accuracy: 0.8538 - val_loss: 0.1887 - val_accuracy: 0.9400
# Epoch 5/100
# 67/67 [==============================] - 6s 83ms/step - loss: 0.3717 - accuracy: 0.8734 - val_loss: 0.2805 - val_accuracy: 0.9200
# Epoch 6/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.3448 - accuracy: 0.8861 - val_loss: 0.2273 - val_accuracy: 0.9200
# Epoch 7/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.3101 - accuracy: 0.8943 - val_loss: 0.1422 - val_accuracy: 0.9600
# Epoch 8/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.2795 - accuracy: 0.9056 - val_loss: 0.2936 - val_accuracy: 0.9200
# Epoch 9/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.2717 - accuracy: 0.9154 - val_loss: 0.1222 - val_accuracy: 0.9800
# Epoch 10/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.2416 - accuracy: 0.9204 - val_loss: 0.1291 - val_accuracy: 0.9600
# Epoch 11/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.2234 - accuracy: 0.9300 - val_loss: 0.1556 - val_accuracy: 0.9600
# Epoch 12/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.2072 - accuracy: 0.9355 - val_loss: 0.1606 - val_accuracy: 0.9600
# Epoch 13/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.1996 - accuracy: 0.9360 - val_loss: 0.1837 - val_accuracy: 0.9600
# Epoch 14/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.1900 - accuracy: 0.9399 - val_loss: 0.1194 - val_accuracy: 0.9600
# Epoch 15/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.1824 - accuracy: 0.9412 - val_loss: 0.1462 - val_accuracy: 0.9600
# Epoch 16/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.1785 - accuracy: 0.9430 - val_loss: 0.1119 - val_accuracy: 0.9800
# Epoch 17/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.1900 - accuracy: 0.9383 - val_loss: 0.1187 - val_accuracy: 0.9800
# Epoch 18/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.1778 - accuracy: 0.9435 - val_loss: 0.1125 - val_accuracy: 0.9800
# Epoch 19/100
# 67/67 [==============================] - 6s 83ms/step - loss: 0.1586 - accuracy: 0.9463 - val_loss: 0.2703 - val_accuracy: 0.9200
# Epoch 20/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.1489 - accuracy: 0.9515 - val_loss: 0.2435 - val_accuracy: 0.9200
# Epoch 21/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.1458 - accuracy: 0.9529 - val_loss: 0.2055 - val_accuracy: 0.9200
# Epoch 22/100
# 67/67 [==============================] - 6s 83ms/step - loss: 0.1439 - accuracy: 0.9532 - val_loss: 0.1375 - val_accuracy: 0.9600
# Epoch 23/100
# 67/67 [==============================] - 6s 84ms/step - loss: 0.1373 - accuracy: 0.9558 - val_loss: 0.1059 - val_accuracy: 0.9800
# Epoch 24/100
# 67/67 [==============================] - 6s 85ms/step - loss: 0.1389 - accuracy: 0.9527 - val_loss: 0.2360 - val_accuracy: 0.9200
# Epoch 25/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1339 - accuracy: 0.9554 - val_loss: 0.1871 - val_accuracy: 0.9400
# Epoch 26/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.1331 - accuracy: 0.9536 - val_loss: 0.0929 - val_accuracy: 0.9800
# Epoch 27/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.1406 - accuracy: 0.9529 - val_loss: 0.1865 - val_accuracy: 0.9200
# Epoch 28/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.1249 - accuracy: 0.9574 - val_loss: 0.0936 - val_accuracy: 0.9800
# Epoch 29/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.1223 - accuracy: 0.9592 - val_loss: 0.1164 - val_accuracy: 0.9600
# Epoch 30/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1145 - accuracy: 0.9626 - val_loss: 0.1114 - val_accuracy: 0.9600
# Epoch 31/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.1123 - accuracy: 0.9614 - val_loss: 0.2989 - val_accuracy: 0.9200
# Epoch 32/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1421 - accuracy: 0.9529 - val_loss: 0.0918 - val_accuracy: 0.9800
# Epoch 33/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1287 - accuracy: 0.9556 - val_loss: 0.2009 - val_accuracy: 0.9600
# Epoch 34/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.1127 - accuracy: 0.9614 - val_loss: 0.0834 - val_accuracy: 0.9800
# Epoch 35/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1090 - accuracy: 0.9626 - val_loss: 0.1291 - val_accuracy: 0.9600
# Epoch 36/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.1032 - accuracy: 0.9637 - val_loss: 0.0824 - val_accuracy: 0.9800
# Epoch 37/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1005 - accuracy: 0.9649 - val_loss: 0.1238 - val_accuracy: 0.9600
# Epoch 38/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1015 - accuracy: 0.9648 - val_loss: 0.1231 - val_accuracy: 0.9600
# Epoch 39/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.1074 - accuracy: 0.9627 - val_loss: 0.0824 - val_accuracy: 0.9800
# Epoch 40/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1034 - accuracy: 0.9642 - val_loss: 0.3784 - val_accuracy: 0.9200
# Epoch 41/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.0988 - accuracy: 0.9653 - val_loss: 0.1047 - val_accuracy: 0.9800
# Epoch 42/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0913 - accuracy: 0.9676 - val_loss: 0.0995 - val_accuracy: 0.9800
# Epoch 43/100
# 67/67 [==============================] - 5s 82ms/step - loss: 0.0949 - accuracy: 0.9676 - val_loss: 0.1179 - val_accuracy: 0.9600
# Epoch 44/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1548 - accuracy: 0.9494 - val_loss: 0.1293 - val_accuracy: 0.9600
# Epoch 45/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.1054 - accuracy: 0.9636 - val_loss: 0.1417 - val_accuracy: 0.9600
# Epoch 46/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1057 - accuracy: 0.9625 - val_loss: 0.1070 - val_accuracy: 0.9800
# Epoch 47/100
# 67/67 [==============================] - 6s 82ms/step - loss: 0.1003 - accuracy: 0.9642 - val_loss: 0.1189 - val_accuracy: 0.9800
# Epoch 48/100
# 67/67 [==============================] - 5s 81ms/step - loss: 0.0913 - accuracy: 0.9692 - val_loss: 0.1245 - val_accuracy: 0.9600
# Epoch 49/100
# 67/67 [==============================] - 6s 83ms/step - loss: 0.0863 - accuracy: 0.9692 - val_loss: 0.1021 - val_accuracy: 0.9800
# 67/67 [==============================] - 1s 15ms/step - loss: 0.1478 - accuracy: 0.9563
# 67/67 [==============================] - 2s 15ms/step
# Mean Accuracy: 0.9551312804222107
# Mean Confusion Matrix:
# [[ 864   11  107]
#  [  13 2371  152]
#  [  78  116 6919]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            f       0.93      0.88      0.90       187
#            A       0.95      0.93      0.94       496
#            V       0.96      0.98      0.97      1443
#
#     accuracy                           0.96      2126
#    macro avg       0.95      0.93      0.94      2126
# weighted avg       0.96      0.96      0.96      2126
#
# Sensitivity (f): 0.879837067209776
# Sensitivity (A): 0.9349369085173501
# Sensitivity (V): 0.9727259946576691
#
# Mean Sensitivity: 0.9945526260185951
#
# ==================================================================
#
# Specificity (f): 0.9905689708778112
# Specificity (A): 0.9843113032736257
# Specificity (V): 0.9263786242183059
#
# Mean Specificity: 0.9876714519521039

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.4) # for label size
sns.heatmap(mean_conf_matrix, annot=True, annot_kws={"size": 16}, cmap='Blues', fmt='g') # font size
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion matrix for best fold')
plt.show()
