# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import wfdb
import os
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from keras.layers import LSTM, RepeatVector, TimeDistributed, Dense
from tensorflow.keras.models import Model
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score
import neurokit2 as nk

# %%
data_path = 'Af-Mitdb/'

# %%
# Get the list of all record files in the folder
# List of Patients
data = ['100','101','102','103','104','105','106','107',
           '108','109','111','112','113','114','115','116',
           '117','118','119','121','122','123','124','200',
           '201','202','203','205','207','208','209','210',
           '212','213','214','215','217','219','220','221',
           '222','223','228','230','231','232','233','234',
            '04015', '04043', '04048', '04126', '04746',
            '04908', '04936', '05091', '05121', '05261',
            '06426', '06453', '06995', '07162', '07859',
            '07879', '07910', '08215', '08219', '08378',
            '08405', '08434', '08455']

# %%
# Creating a Empty Dataframe
symbols_df = pd.DataFrame()

# Reading all .atr files 
for pts in data:
    # Generating filepath for all .atr file names
    file = data_path + pts
    # Saving annotation object
    annotation = wfdb.rdann(file, 'atr')
    # Extracting symbols from the object
    sym = annotation.symbol
    # Saving value counts
    values, counts = np.unique(sym, return_counts=True)
    # Writing data points into dataframe
    df_sub = pd.DataFrame({'symbol':values, 'Counts':counts, 'data Number':[pts]*len(counts)})
    # Concatenating all data points  
    symbols_df = pd.concat([symbols_df, df_sub],axis = 0)

# Loop over all records and load the signal and annotations
for record_name in data:
    record_path = os.path.join(data_path, record_name)
    record = wfdb.rdrecord(record_path)
    annotation = wfdb.rdann(record_path, 'atr', shift_samps=True)
    ecg_signal = record.p_signal[:,0]
    ecg_signal = np.nan_to_num(ecg_signal)

    # Get the signal and labels
    sig = ecg_signal
    labels = np.array(annotation.symbol)

plt.figure(figsize=(12, 4))
plt.plot(sig)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('ECG Signal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import resample, butter, filtfilt, find_peaks
import pywt
from scipy import integrate
import cv2

# Normalize the data
sig = (sig - np.mean(sig)) / np.std(sig)

# Resample the data to new_sampling_rate
new_sampling_rate = 250
record = {"fs": 1000}  # Define the sampling rate
sig_resampled = resample(sig, int(len(sig) * (new_sampling_rate / record["fs"])))

# Bandpass filter the data
lowcut = 5.0
highcut = 15.0
sampling_rate = new_sampling_rate

def bandpass_filter(data, lowcut, highcut, sampling_rate, order=4):
    nyq = 0.5 * sampling_rate
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    filtered_data = filtfilt(b, a, data)
    return filtered_data


sig_filtered = bandpass_filter(sig_resampled, lowcut, highcut, sampling_rate, order=4)

# detect R-peaks
r_peaks, _ = find_peaks(sig_filtered, height=0.5, distance=100)

# create array for marking detected peaks
peaks = np.zeros_like(sig_filtered)

# mark R-peaks
peaks[r_peaks] = sig_filtered[r_peaks]

# detect P-peaks
p_peaks, _ = find_peaks(sig_filtered[:r_peaks[0]], height=0.1, distance=50)

p_peak = p_peaks[-1] if len(p_peaks) > 0 else None

# detect Q-peaks
if p_peak is not None:
    q_peaks, _ = find_peaks(-sig_filtered[p_peak:r_peaks[0]], height=-0.2, distance=50)
    q_peak = p_peak + q_peaks[-1] if len(q_peaks) > 0 else None
else:
    q_peak = None

# detect S-peaks
s_peaks, _ = find_peaks(-sig_filtered[r_peaks[0]:r_peaks[1]], height=-0.2, distance=50)
s_peak = r_peaks[0] + s_peaks[0] if len(s_peaks) > 0 else None

# detect T-peaks
t_peaks, _ = find_peaks(sig_filtered[r_peaks[1]:], height=0.1, distance=50)
t_peak = r_peaks[1] + t_peaks[0] if len(t_peaks) > 0 else None


# modify conditional statements
if p_peak is not None and len(p_peaks) > 0:
    q_peaks, _ = find_peaks(-sig_filtered[p_peak:r_peaks[0]], height=-0.2, distance=50)
    q_peak = p_peak + q_peaks[-1]
else:
    q_peak = None

if len(s_peaks) > 0:
    s_peak = r_peaks[0] + s_peaks[0]
else:
    s_peak = None

if len(t_peaks) > 0:
    t_peak = r_peaks[1] + t_peaks[0]
else:
    t_peak = None



def wavelet_denoising(data):
    waveletname = 'db6'
    threshold = 0.04
    level = pywt.dwt_max_level(len(data), waveletname)
    coeff = pywt.wavedec(data, waveletname, level=level)
    sigma = threshold*np.median(np.abs(coeff[-level]))
    uthresh = sigma*np.sqrt(2*np.log(len(data)))
    coeff[1:] = (pywt.threshold(i, value=uthresh, mode='soft') for i in coeff[1:])
    reconstructed_signal = pywt.waverec(coeff, waveletname)
    return reconstructed_signal

sig_denoised = wavelet_denoising(sig_filtered)

# Define signal parameters
fs = 1000  # Sampling frequency
f = 500  # ECG frequency
duration = 10  # Signal duration (in seconds)

# Generate time vector
t = np.arange(0, duration, 1/fs)

# Generate ECG signal
sig = integrate.cumulative_trapezoid(np.sin(2*np.pi*f*t), t, initial=0)


# Print the shape of the signal and labels
print("Signal shape:", sig_denoised.shape)
print("Labels shape:", labels.shape)

# plot ECG signal with R-peaks
plt.figure(figsize=(15, 5))
plt.plot(sig_filtered, label='ECG')
plt.plot(r_peaks, peaks[r_peaks], 'or', markersize=10, label='R-Peaks', linestyle='None')

# plot P, Q, S, T peaks
if p_peak is not None:
  plt.plot(p_peak, sig_filtered[p_peak], 'og', markersize=10, label='P-Peak', linestyle='None')
if q_peak is not None:
  plt.plot(q_peak, sig_filtered[q_peak], 'ob', markersize=10, label='Q-Peak', linestyle='None')
if s_peak is not None:
  plt.plot(s_peak, sig_filtered[s_peak], 'ok', markersize=10, label='S-Peak', linestyle='None')
if t_peak is not None:
  plt.plot(t_peak, sig_filtered[t_peak], 'oy', markersize=10, label='T-Peak', linestyle='None')

plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('ECG with R-peaks, P, Q, S, T peaks')
plt.legend()
plt.show()
# Out:
# Signal shape: (2301440,)
# Labels shape: (4,)

# %%
#show label
wfdb.io.show_ann_labels()
wfdb.io.show_ann_classes()
# Out:
#     label_store symbol                                    description
# 0             0                              Not an actual annotation
# 1             1      N                                    Normal beat
# 2             2      L                  Left bundle branch block beat
# 3             3      R                 Right bundle branch block beat
# 4             4      a                Aberrated atrial premature beat
# 5             5      V              Premature ventricular contraction
# 6             6      F          Fusion of ventricular and normal beat
# 7             7      J              Nodal (junctional) premature beat
# 8             8      A                   Atrial premature contraction
# 9             9      S     Premature or ectopic supraventricular beat
# 10           10      E                        Ventricular escape beat
# 11           11      j                 Nodal (junctional) escape beat
# 12           12      /                                     Paced beat
# 13           13      Q                            Unclassifiable beat
# 14           14      ~                          Signal quality change
# 16           16      |                     Isolated QRS-like artifact
# 18           18      s                                      ST change
# 19           19      T                                  T-wave change
# 20           20      *                                        Systole
# 21           21      D                                       Diastole
# 22           22      "                             Comment annotation
# 23           23      =                         Measurement annotation
# 24           24      p                                    P-wave peak
# 25           25      B              Left or right bundle branch block
# 26           26      ^                      Non-conducted pacer spike
# 27           27      t                                    T-wave peak
# 28           28      +                                  Rhythm change
# 29           29      u                                    U-wave peak
# 30           30      ?                                       Learning
# 31           31      !                       Ventricular flutter wave
# 32           32      [      Start of ventricular flutter/fibrillation
# 33           33      ]        End of ventricular flutter/fibrillation
# 34           34      e                             Atrial escape beat
# 35           35      n                   Supraventricular escape beat
# 36           36      @  Link to external data (aux_note contains URL)
# 37           37      x             Non-conducted P-wave (blocked APB)
# 38           38      f                Fusion of paced and normal beat
# 39           39      (                                 Waveform onset
# 40           40      )                                   Waveform end
# 41           41      r       R-on-T premature ventricular contraction
#      extension                        description  human_reviewed
# atr        atr          Reference ECG annotations            True
# blh        blh         Human reviewed beat labels            True
# blm        blm                Machine beat labels           False
# alh        alh              Human reviewed alarms            True
# alm        alm                     Machine alarms           False
# qrsc      qrsc      Human reviewed QRS detections            True
# qrs        qrs             Machine QRS detections           False
# bph        bph  Human reviewed BP beat detections            True
# bpm        bpm         Machine BP beat detections           False

# %%
# Symbols Dataframe
symbols_df
# Out:
#    symbol  Counts data Number
# 0       +       1         100
# 1       A      33         100
# 2       N    2239         100
# 3       V       1         100
# 0       +       1         101
# ..    ...     ...         ...
# 0       +      79       08219
# 0       +      17       08378
# 0       +       4       08405
# 0       +       7       08434
# 0       +       4       08455
#
# [306 rows x 3 columns]

# %%
# Value Counts of Different symbols in data
symbols_df.groupby('symbol').Counts.sum().sort_values(ascending = False)
# Out:
# symbol
# N    75052
# L     8075
# R     7259
# V     7130
# /     7028
# A     2546
# +     1896
# f      982
# F      803
# ~      616
# !      472
# "      437
# j      229
# x      193
# a      150
# |      132
# E      106
# J       83
# Q       33
# e       16
# [        6
# ]        6
# S        2
# Name: Counts, dtype: int64

# %%
# Normal Beat Symbols
normal = ['N']

# Abnormal Beat Symbols
AF = ['f']
PAC = ['A']
PVC = ['V']

abnormal_category = AF + PAC + PVC

# Classifying abnormal beats into more specific categories
symbols_df['abnormal_category'] = -1
symbols_df.loc[symbols_df.symbol == 'N','abnormal_category'] = "N"
symbols_df.loc[symbols_df.symbol.isin(AF), 'abnormal_category'] = "AF"
symbols_df.loc[symbols_df.symbol.isin(PAC), 'abnormal_category'] = "PAC"
symbols_df.loc[symbols_df.symbol.isin(PVC), 'abnormal_category'] = "PVC"

# Value counts of different categories
symbols_df.groupby('abnormal_category').Counts.sum()
# Out:
# abnormal_category
# -1     27542
# AF       982
# N      75052
# PAC     2546
# PVC     7130
# Name: Counts, dtype: int64

# %%
def load_ecg(file):
    # load the ecg
    record = wfdb.rdrecord(file)
    # load the annotation
    annotation = wfdb.rdann(file, 'atr')

    # extracting the signal
    p_signal = record.p_signal

    # extracting symbols and annotation index
    atr_sym = annotation.symbol
    atr_sample = annotation.sample

    return p_signal, atr_sym, atr_sample

# %%
# Accessing the ecg points for
file = data_path + data[8]

# %%
# Accessing the load ECG function and getting annotation.symbol, annotation.sample, signals
p_signal, atr_sym, atr_sample = load_ecg(file)

# %%
# Analysing annotations value counts for a single record
values, counts = np.unique(sym, return_counts=True)
for v,c in zip(values, counts):
    print(v,c)
# Out:
# + 4

# %%
# get abnormal beat index
ab_index = [b for a,b in zip(atr_sym,atr_sample) if a in abnormal_category][:10]
ab_index
# Out:
# [4105, 10876, 83824, 107330, 180041, 193553, 205731, 221206, 263192, 268697]

# %%
# Generating evenly spaced values
x = np.arange(len(p_signal))

left = ab_index[5]-20000
right = ab_index[5]+20000

plt.figure(figsize=(20,8))
plt.plot(x[left:right],p_signal[left:right,0],'-',label='ecg',)
plt.plot(x[atr_sample],p_signal[atr_sample,0],'go',label ='normal')
plt.plot(x[ab_index],p_signal[ab_index,0],'ro',label='abnormal')

plt.xlim(left,right)
plt.ylim(p_signal[left:right].min()-0.05,p_signal[left:right,0].max()+0.05)
plt.xlabel('time index')
plt.ylabel('ECG signal')
plt.legend(bbox_to_anchor = (1.04,1), loc = 'upper left')
plt.show()

# %%
def make_dataset(record_patients, num_sec, fs, abnormal_category):

    # initialize numpy arrays
    num_cols = 2*num_sec * fs
    X_all = np.zeros((1,num_cols))
    Y_all = np.zeros((1,len(abnormal_category)))
    sym_all = []

    # list to keep track of number of beats across patients
    max_rows = []

    for pt in data:
        file = data_path + pt

        p_signal, atr_sym, atr_sample = load_ecg(file)

        # grab the first signal
        p_signal = p_signal[:,0]

        # make df to exclude the nonbeats
        df_ann = pd.DataFrame({'atr_sym':atr_sym,
                              'atr_sample':atr_sample})
        df_ann = df_ann.loc[df_ann.atr_sym.isin(abnormal_category)]

        num_rows = len(df_ann)

        X = np.zeros((num_rows, num_cols))
        Y = np.zeros((num_rows, len(abnormal_category)))
        sym = []

        # keep track of rows
        max_row = 0

        for atr_sample, atr_sym in zip(df_ann.atr_sample.values,df_ann.atr_sym.values):

            left = max([0,(atr_sample - num_sec*fs) ])
            right = min([len(p_signal),(atr_sample + num_sec*fs) ])
            x = p_signal[left: right]
            if len(x) == num_cols:
                X[max_row,:] = x
                Y[max_row, abnormal_category.index(atr_sym)] = 1
                sym.append(atr_sym)
                max_row += 1
        X = X[:max_row,:]
        Y = Y[:max_row,:]

        sym_all = sym_all+sym
        max_rows.append(X.shape[0])
        X_all = np.append(X_all,X,axis = 0)
        Y_all = np.append(Y_all,Y,axis = 0)

    # drop the first zero row
    X_all = X_all[1:,:]
    Y_all = Y_all[1:,:]

    return X_all, Y_all, sym_all

# %%
import seaborn as sns
# Value counts of different categories
counts_df = symbols_df.groupby('abnormal_category')['Counts'].sum().reset_index()
print(counts_df)

# Visualize the number of subjects in each abnormal_category:
sns.barplot(x='abnormal_category', y='Counts', data=counts_df)
plt.show()
# Out:
#   abnormal_category  Counts
# 0                -1   27542
# 1                AF     982
# 2                 N   75052
# 3               PAC    2546
# 4               PVC    7130

# %%
import numpy as np
from scipy.stats import kurtosis, skew
from scipy.fft import fft

def extract_features(rr_intervals):
    features = {}

    # RR Interval Features
    rr_mean = np.mean(rr_intervals)
    rr_std = np.std(rr_intervals)
    rr_min = np.min(rr_intervals)
    rr_max = np.max(rr_intervals)
    rr_range = rr_max - rr_min
    rr_median = np.median(rr_intervals)
    rr_diff = np.diff(rr_intervals)
    rr_fft = np.abs(fft(rr_intervals))
    rr_skewness = skew(rr_intervals)
    rr_kurtosis = kurtosis(rr_intervals)

    features['RR Mean'] = rr_mean
    features['RR Std'] = rr_std
    features['RR Min'] = rr_min
    features['RR Max'] = rr_max
    features['RR Range'] = rr_range
    features['RR Median'] = rr_median
    features['RR Skewness'] = rr_skewness
    features['RR Kurtosis'] = rr_kurtosis

    features['mean_rr_diff'] = np.mean(rr_diff)
    features['std_rr_diff'] = np.std(rr_diff)
    features['min_rr_diff'] = np.min(rr_diff)
    features['max_rr_diff'] = np.max(rr_diff)
    features['median_rr_diff'] = np.median(rr_diff)
    features['range_rr_diff'] = np.ptp(rr_diff)

    features['RR FFT Mean'] = np.mean(rr_fft)
    features['RR FFT Std'] = np.std(rr_fft)
    features['RR FFT Max'] = np.max(rr_fft)

    rr_variance = np.var(rr_intervals)
    rr_coefficient_of_variation = np.mean(rr_intervals) / np.std(rr_intervals)

    features['RR Variance'] = rr_variance
    features['RR Coefficient of Variation'] = rr_coefficient_of_variation

    # Additional Statistical Features
    features['RR 5th Percentile'] = np.percentile(rr_intervals, 5)
    features['RR 95th Percentile'] = np.percentile(rr_intervals, 95)
    features['RR Interquartile Range'] = np.percentile(rr_intervals, 75) - np.percentile(rr_intervals, 25)

    # Additional Dynamic Features
    rr_diff_mean = np.mean(rr_diff)
    rr_diff_std = np.std(rr_diff)
    rr_diff_min = np.min(rr_diff)
    rr_diff_max = np.max(rr_diff)
    rr_diff_median = np.median(rr_diff)
    rr_diff_range = np.ptp(rr_diff)

    features['mean_rr_diff'] = rr_diff_mean
    features['std_rr_diff'] = rr_diff_std
    features['min_rr_diff'] = rr_diff_min
    features['max_rr_diff'] = rr_diff_max
    features['median_rr_diff'] = rr_diff_median
    features['range_rr_diff'] = rr_diff_range


    return features

# %%
import matplotlib.pyplot as plt

# Set the parameters
num_sec = 3
fs = 360

# Accessing the function and creating a dataset with ECG digital points
X_all, Y_all, sym_all = make_dataset(data, num_sec, fs, abnormal_category)

# Mengambil segmen RR interval
rr_intervals = X_all[:, fs * num_sec:]

features = []
for rr in rr_intervals:
    feature = extract_features(rr)
    features.append(feature)

# Convert the features list to a dataframe
df_features = pd.DataFrame(features)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

r_peaks, _ = find_peaks(sig_denoised[:len(rr_intervals[0])], prominence=0.4)

# Plot the QRS complexes with R, Q, and S peaks
plt.figure(figsize=(10, 5))
plt.plot(sig_denoised[:len(rr_intervals[0])], color='blue', label='RR Interval')
plt.plot(r_peaks, sig_denoised[r_peaks], 'ro', markersize=4, label='R Peaks')

plt.title('RR Interval')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix

# Initialize K-fold cross-validation
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Initialize arrays to store evaluation metrics
accuracies = []
sensitivities = []
specificities = []
classification_reports = []
confusion_matrices = []

# Assuming df_features and Y_all are defined
for train_index, test_index in kf.split(df_features):
    X_train, X_val = df_features.iloc[train_index[:-50]].values, df_features.iloc[train_index[-50:]].values
    Y_train, Y_val = Y_all[train_index[:-50]], Y_all[train_index[-50:]]
    X_test, Y_test = df_features.iloc[test_index].values, Y_all[test_index]

    # Normalization using StandardScaler
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Reshape input data to match the LSTM input shape
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
    
    # Ensure Y_train and Y_test are 1D arrays
    Y_train = np.squeeze(Y_train)
    Y_test = np.squeeze(Y_test)

    # Number of classes for multi-label classification
    num_classes = Y_train.shape[1]

    # Build the RNN model
    model = Sequential()
    model.add(LSTM(units=64, input_shape=(X_train.shape[1], 1), return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64))
    model.add(Dropout(0.2))
    model.add(Dense(units=num_classes, activation='sigmoid'))  # Output layer for multi-label classification
    
    # Early stopping and learning rate reduction
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_split=0.2, callbacks=[early_stopping])

    # Evaluate the model
    y_pred_probs = model.predict(X_test)
    y_pred = (y_pred_probs > 0.5).astype(int)  # Convert probabilities to binary predictions
    
    # Calculate TP and FN for each class
    true_positives = np.sum((Y_test == 1) & (y_pred == 1), axis=0)
    false_negatives = np.sum((Y_test == 1) & (y_pred == 0), axis=0)
    
    # Calculate sensitivity for each class and append to the list
    sensitivity = true_positives / (true_positives + false_negatives)
    sensitivities.append(sensitivity)
    
    # Calculate TN and FP for each class
    true_negatives = np.sum((Y_test == 0) & (y_pred == 0), axis=0)
    false_positives = np.sum((Y_test == 0) & (y_pred == 1), axis=0)
    
    # Calculate specificity for each class and append to the list
    specificity = true_negatives / (true_negatives + false_positives)
    specificities.append(specificity)
    
    # Calculate confusion matrix for each class
    conf_matrix = np.array([[true_negatives, false_positives], [false_negatives, true_positives]])
    confusion_matrices.append(conf_matrix)
    
    
    # Calculate overall accuracy
    accuracy = accuracy_score(Y_test, y_pred) * 100

    # Generate classification report
    class_names = [f'Class {i}' for i in range(num_classes)]  # Adjust class names as needed
    class_report = classification_report(Y_test, y_pred, target_names=class_names, labels=range(num_classes), zero_division=1)

    # Append metrics to arrays
    accuracies.append(accuracy)
    classification_reports.append(class_report)

    # Print metrics
    print(f'Accuracy: {accuracy:.2f}%')
    print(f'Sensitivity (True Positive Rate): {sensitivity}')
    print(f'Specificity (True Negative Rate): {specificity}')
    print('Confusion Matrix:')
    print(conf_matrix)
    print('Classification Report:')
    print(class_report)

# Calculate mean sensitivity in percentages
mean_sensitivity = np.mean(sensitivities, axis=0) * 100

# Calculate mean specificity in percentages
mean_specificity = np.mean(specificities, axis=0) * 100

# Calculate mean accuracy
mean_accuracy = np.mean(accuracies)

# Print mean values
print(f'Mean Accuracy: {mean_accuracy:.2f}%')

# Print mean sensitivity in percentages
print('Mean Sensitivity:')
print(mean_sensitivity)

# Print mean specificity in percentages
print('Mean Specificity:')
print(mean_specificity)

# Calculate mean confusion matrix
mean_conf_matrix = np.mean(confusion_matrices, axis=0)

# Print mean confusion matrix
print('Mean Confusion Matrix:')
print(mean_conf_matrix)
# Out:
# Epoch 1/100
# 106/106 [==============================] - 15s 93ms/step - loss: 0.4549 - accuracy: 0.7440 - val_loss: 0.5885 - val_accuracy: 0.3749
# Epoch 2/100
# 106/106 [==============================] - 9s 85ms/step - loss: 0.3372 - accuracy: 0.7999 - val_loss: 0.5856 - val_accuracy: 0.3856
# Epoch 3/100
# 106/106 [==============================] - 9s 86ms/step - loss: 0.2819 - accuracy: 0.8449 - val_loss: 0.5399 - val_accuracy: 0.3986
# Epoch 4/100
# 106/106 [==============================] - 13s 126ms/step - loss: 0.2575 - accuracy: 0.8656 - val_loss: 0.5655 - val_accuracy: 0.5186
# Epoch 5/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.2515 - accuracy: 0.8711 - val_loss: 0.5810 - val_accuracy: 0.5701
# Epoch 6/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.2237 - accuracy: 0.8833 - val_loss: 0.5201 - val_accuracy: 0.6008
# Epoch 7/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.2124 - accuracy: 0.8847 - val_loss: 0.3873 - val_accuracy: 0.7363
# Epoch 8/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.2005 - accuracy: 0.8969 - val_loss: 0.6198 - val_accuracy: 0.5996
# Epoch 9/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1855 - accuracy: 0.9104 - val_loss: 0.3186 - val_accuracy: 0.7776
# Epoch 10/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1755 - accuracy: 0.9119 - val_loss: 0.3122 - val_accuracy: 0.8084
# Epoch 11/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1629 - accuracy: 0.9230 - val_loss: 0.2632 - val_accuracy: 0.8267
# Epoch 12/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1533 - accuracy: 0.9253 - val_loss: 0.2205 - val_accuracy: 0.8557
# Epoch 13/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.1564 - accuracy: 0.9247 - val_loss: 0.1535 - val_accuracy: 0.9279
# Epoch 14/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1465 - accuracy: 0.9264 - val_loss: 0.1639 - val_accuracy: 0.8924
# Epoch 15/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1416 - accuracy: 0.9290 - val_loss: 0.1962 - val_accuracy: 0.8882
# Epoch 16/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1347 - accuracy: 0.9304 - val_loss: 0.1115 - val_accuracy: 0.9586
# Epoch 17/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1329 - accuracy: 0.9336 - val_loss: 0.0855 - val_accuracy: 0.9580
# Epoch 18/100
# 106/106 [==============================] - 15s 144ms/step - loss: 0.1317 - accuracy: 0.9352 - val_loss: 0.0456 - val_accuracy: 0.9858
# Epoch 19/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1256 - accuracy: 0.9369 - val_loss: 0.0577 - val_accuracy: 0.9781
# Epoch 20/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1245 - accuracy: 0.9373 - val_loss: 0.2015 - val_accuracy: 0.8770
# Epoch 21/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.1255 - accuracy: 0.9352 - val_loss: 0.2011 - val_accuracy: 0.8664
# Epoch 22/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.1198 - accuracy: 0.9395 - val_loss: 0.1750 - val_accuracy: 0.9190
# Epoch 23/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1160 - accuracy: 0.9403 - val_loss: 0.0579 - val_accuracy: 0.9811
# Epoch 24/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.1129 - accuracy: 0.9419 - val_loss: 0.0505 - val_accuracy: 0.9840
# Epoch 25/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.1083 - accuracy: 0.9435 - val_loss: 0.1536 - val_accuracy: 0.9172
# Epoch 26/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.1126 - accuracy: 0.9423 - val_loss: 0.1573 - val_accuracy: 0.9249
# Epoch 27/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1029 - accuracy: 0.9472 - val_loss: 0.1021 - val_accuracy: 0.9373
# Epoch 28/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0976 - accuracy: 0.9490 - val_loss: 0.1715 - val_accuracy: 0.8995
# 67/67 [==============================] - 3s 21ms/step
# Accuracy: 94.55%
# Sensitivity (True Positive Rate): [0.84931507 0.93518519 0.97076023]
# Specificity (True Negative Rate): [0.99371069 0.97920605 0.914361  ]
# Confusion Matrix:
# [[[1896 1554  694]
#   [  12   33   65]]
#
#  [[  33   35   40]
#   [ 186  505 1328]]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.94      0.85      0.89       219
#      Class 1       0.94      0.94      0.94       540
#      Class 2       0.95      0.97      0.96      1368
#
#    micro avg       0.95      0.95      0.95      2127
#    macro avg       0.94      0.92      0.93      2127
# weighted avg       0.95      0.95      0.95      2127
#  samples avg       0.95      0.95      0.95      2127
#
# Epoch 1/100
# 106/106 [==============================] - 16s 93ms/step - loss: 0.4579 - accuracy: 0.7284 - val_loss: 0.4960 - val_accuracy: 0.3844
# Epoch 2/100
# 106/106 [==============================] - 11s 105ms/step - loss: 0.3362 - accuracy: 0.7969 - val_loss: 0.5182 - val_accuracy: 0.4619
# Epoch 3/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.2829 - accuracy: 0.8381 - val_loss: 0.5740 - val_accuracy: 0.4678
# Epoch 4/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.2622 - accuracy: 0.8535 - val_loss: 0.5942 - val_accuracy: 0.4755
# Epoch 5/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.2466 - accuracy: 0.8684 - val_loss: 0.5014 - val_accuracy: 0.6334
# Epoch 6/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.2302 - accuracy: 0.8786 - val_loss: 0.8396 - val_accuracy: 0.4772
# Epoch 7/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.2093 - accuracy: 0.8946 - val_loss: 0.3154 - val_accuracy: 0.7895
# Epoch 8/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1969 - accuracy: 0.8990 - val_loss: 0.4641 - val_accuracy: 0.6878
# Epoch 9/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.1789 - accuracy: 0.9095 - val_loss: 0.2514 - val_accuracy: 0.8232
# Epoch 10/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1629 - accuracy: 0.9199 - val_loss: 0.2169 - val_accuracy: 0.8510
# Epoch 11/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1611 - accuracy: 0.9208 - val_loss: 0.5587 - val_accuracy: 0.5529
# Epoch 12/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.1537 - accuracy: 0.9219 - val_loss: 0.1916 - val_accuracy: 0.8770
# Epoch 13/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1437 - accuracy: 0.9301 - val_loss: 0.0868 - val_accuracy: 0.9622
# Epoch 14/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.1421 - accuracy: 0.9283 - val_loss: 0.2159 - val_accuracy: 0.8628
# Epoch 15/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1360 - accuracy: 0.9307 - val_loss: 0.0464 - val_accuracy: 0.9905
# Epoch 16/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.1300 - accuracy: 0.9345 - val_loss: 0.0579 - val_accuracy: 0.9852
# Epoch 17/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1245 - accuracy: 0.9379 - val_loss: 0.0773 - val_accuracy: 0.9681
# Epoch 18/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1220 - accuracy: 0.9381 - val_loss: 0.0837 - val_accuracy: 0.9622
# Epoch 19/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.1162 - accuracy: 0.9429 - val_loss: 0.0529 - val_accuracy: 0.9876
# Epoch 20/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.1098 - accuracy: 0.9454 - val_loss: 0.0493 - val_accuracy: 0.9823
# Epoch 21/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.1071 - accuracy: 0.9478 - val_loss: 0.1277 - val_accuracy: 0.9172
# Epoch 22/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1103 - accuracy: 0.9459 - val_loss: 0.0547 - val_accuracy: 0.9769
# Epoch 23/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.1087 - accuracy: 0.9459 - val_loss: 0.0348 - val_accuracy: 0.9905
# Epoch 24/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1006 - accuracy: 0.9486 - val_loss: 0.0345 - val_accuracy: 0.9888
# Epoch 25/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1057 - accuracy: 0.9454 - val_loss: 0.0342 - val_accuracy: 0.9917
# Epoch 26/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0985 - accuracy: 0.9487 - val_loss: 0.0344 - val_accuracy: 0.9899
# Epoch 27/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0990 - accuracy: 0.9481 - val_loss: 0.0611 - val_accuracy: 0.9817
# Epoch 28/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0929 - accuracy: 0.9522 - val_loss: 0.0541 - val_accuracy: 0.9829
# Epoch 29/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0928 - accuracy: 0.9521 - val_loss: 0.1112 - val_accuracy: 0.9326
# Epoch 30/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0865 - accuracy: 0.9542 - val_loss: 0.0474 - val_accuracy: 0.9858
# Epoch 31/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0898 - accuracy: 0.9530 - val_loss: 0.0628 - val_accuracy: 0.9829
# Epoch 32/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0839 - accuracy: 0.9567 - val_loss: 0.0473 - val_accuracy: 0.9840
# Epoch 33/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.0832 - accuracy: 0.9545 - val_loss: 0.0550 - val_accuracy: 0.9840
# Epoch 34/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0841 - accuracy: 0.9548 - val_loss: 0.1031 - val_accuracy: 0.9545
# Epoch 35/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0837 - accuracy: 0.9552 - val_loss: 0.0541 - val_accuracy: 0.9758
# 67/67 [==============================] - 3s 21ms/step
# Accuracy: 95.01%
# Sensitivity (True Positive Rate): [0.86294416 0.92246521 0.97475456]
# Specificity (True Negative Rate): [0.99377916 0.97905114 0.92428571]
# Confusion Matrix:
# [[[1917 1589  647]
#   [  12   34   53]]
#
#  [[  27   39   36]
#   [ 170  464 1390]]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.93      0.86      0.90       197
#      Class 1       0.93      0.92      0.93       503
#      Class 2       0.96      0.97      0.97      1426
#
#    micro avg       0.95      0.95      0.95      2126
#    macro avg       0.94      0.92      0.93      2126
# weighted avg       0.95      0.95      0.95      2126
#  samples avg       0.95      0.95      0.95      2126
#
# Epoch 1/100
# 106/106 [==============================] - 18s 96ms/step - loss: 0.4599 - accuracy: 0.7342 - val_loss: 0.5782 - val_accuracy: 0.3684
# Epoch 2/100
# 106/106 [==============================] - 10s 98ms/step - loss: 0.3316 - accuracy: 0.8054 - val_loss: 0.4651 - val_accuracy: 0.3868
# Epoch 3/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.2845 - accuracy: 0.8412 - val_loss: 0.4757 - val_accuracy: 0.6174
# Epoch 4/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.2709 - accuracy: 0.8542 - val_loss: 0.4612 - val_accuracy: 0.6056
# Epoch 5/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.2542 - accuracy: 0.8622 - val_loss: 0.6360 - val_accuracy: 0.4057
# Epoch 6/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.2383 - accuracy: 0.8733 - val_loss: 0.3971 - val_accuracy: 0.7564
# Epoch 7/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.2245 - accuracy: 0.8831 - val_loss: 0.5255 - val_accuracy: 0.5920
# Epoch 8/100
# 106/106 [==============================] - 15s 144ms/step - loss: 0.2170 - accuracy: 0.8891 - val_loss: 0.4742 - val_accuracy: 0.6115
# Epoch 9/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1942 - accuracy: 0.9032 - val_loss: 0.4888 - val_accuracy: 0.6600
# Epoch 10/100
# 106/106 [==============================] - 15s 144ms/step - loss: 0.1767 - accuracy: 0.9141 - val_loss: 0.2170 - val_accuracy: 0.8433
# Epoch 11/100
# 106/106 [==============================] - 16s 146ms/step - loss: 0.1719 - accuracy: 0.9177 - val_loss: 0.1120 - val_accuracy: 0.9302
# Epoch 12/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1600 - accuracy: 0.9237 - val_loss: 0.0955 - val_accuracy: 0.9551
# Epoch 13/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.1508 - accuracy: 0.9292 - val_loss: 0.1011 - val_accuracy: 0.9503
# Epoch 14/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1443 - accuracy: 0.9301 - val_loss: 0.1438 - val_accuracy: 0.9042
# Epoch 15/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.1414 - accuracy: 0.9304 - val_loss: 0.0459 - val_accuracy: 0.9846
# Epoch 16/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1325 - accuracy: 0.9323 - val_loss: 0.0767 - val_accuracy: 0.9598
# Epoch 17/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.1261 - accuracy: 0.9386 - val_loss: 0.0868 - val_accuracy: 0.9574
# Epoch 18/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.1250 - accuracy: 0.9355 - val_loss: 0.1178 - val_accuracy: 0.9468
# Epoch 19/100
# 106/106 [==============================] - 15s 144ms/step - loss: 0.1210 - accuracy: 0.9410 - val_loss: 0.0516 - val_accuracy: 0.9805
# Epoch 20/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1172 - accuracy: 0.9416 - val_loss: 0.0866 - val_accuracy: 0.9604
# Epoch 21/100
# 106/106 [==============================] - 11s 104ms/step - loss: 0.1121 - accuracy: 0.9420 - val_loss: 0.0441 - val_accuracy: 0.9834
# Epoch 22/100
# 106/106 [==============================] - 9s 86ms/step - loss: 0.1081 - accuracy: 0.9434 - val_loss: 0.1663 - val_accuracy: 0.9007
# Epoch 23/100
# 106/106 [==============================] - 15s 143ms/step - loss: 0.1080 - accuracy: 0.9438 - val_loss: 0.0434 - val_accuracy: 0.9823
# Epoch 24/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.1000 - accuracy: 0.9481 - val_loss: 0.0322 - val_accuracy: 0.9905
# Epoch 25/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.1030 - accuracy: 0.9460 - val_loss: 0.0378 - val_accuracy: 0.9882
# Epoch 26/100
# 106/106 [==============================] - 16s 146ms/step - loss: 0.0952 - accuracy: 0.9502 - val_loss: 0.0427 - val_accuracy: 0.9876
# Epoch 27/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0948 - accuracy: 0.9487 - val_loss: 0.1092 - val_accuracy: 0.9462
# Epoch 28/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0914 - accuracy: 0.9505 - val_loss: 0.0278 - val_accuracy: 0.9911
# Epoch 29/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0906 - accuracy: 0.9533 - val_loss: 0.0382 - val_accuracy: 0.9846
# Epoch 30/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.0891 - accuracy: 0.9517 - val_loss: 0.0374 - val_accuracy: 0.9846
# Epoch 31/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0853 - accuracy: 0.9531 - val_loss: 0.0579 - val_accuracy: 0.9704
# Epoch 32/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.0846 - accuracy: 0.9561 - val_loss: 0.0489 - val_accuracy: 0.9805
# Epoch 33/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0774 - accuracy: 0.9588 - val_loss: 0.0283 - val_accuracy: 0.9899
# Epoch 34/100
# 106/106 [==============================] - 15s 145ms/step - loss: 0.0788 - accuracy: 0.9564 - val_loss: 0.0385 - val_accuracy: 0.9811
# Epoch 35/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0759 - accuracy: 0.9585 - val_loss: 0.0394 - val_accuracy: 0.9805
# Epoch 36/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0715 - accuracy: 0.9629 - val_loss: 0.0224 - val_accuracy: 0.9923
# Epoch 37/100
# 106/106 [==============================] - 15s 146ms/step - loss: 0.0779 - accuracy: 0.9552 - val_loss: 0.0385 - val_accuracy: 0.9840
# Epoch 38/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0719 - accuracy: 0.9607 - val_loss: 0.0349 - val_accuracy: 0.9846
# Epoch 39/100
# 106/106 [==============================] - 16s 148ms/step - loss: 0.0675 - accuracy: 0.9630 - val_loss: 0.0355 - val_accuracy: 0.9840
# Epoch 40/100
# 106/106 [==============================] - 16s 146ms/step - loss: 0.0672 - accuracy: 0.9653 - val_loss: 0.0283 - val_accuracy: 0.9894
# Epoch 41/100
# 106/106 [==============================] - 10s 92ms/step - loss: 0.0665 - accuracy: 0.9641 - val_loss: 0.0426 - val_accuracy: 0.9805
# Epoch 42/100
# 106/106 [==============================] - 9s 82ms/step - loss: 0.0654 - accuracy: 0.9647 - val_loss: 0.0392 - val_accuracy: 0.9811
# Epoch 43/100
# 106/106 [==============================] - 15s 142ms/step - loss: 0.0628 - accuracy: 0.9663 - val_loss: 0.0376 - val_accuracy: 0.9864
# Epoch 44/100
# 106/106 [==============================] - 15s 143ms/step - loss: 0.0598 - accuracy: 0.9664 - val_loss: 0.0351 - val_accuracy: 0.9846
# Epoch 45/100
# 106/106 [==============================] - 15s 142ms/step - loss: 0.0595 - accuracy: 0.9673 - val_loss: 0.0348 - val_accuracy: 0.9805
# Epoch 46/100
# 106/106 [==============================] - 15s 142ms/step - loss: 0.0581 - accuracy: 0.9673 - val_loss: 0.1084 - val_accuracy: 0.9438
# 67/67 [==============================] - 3s 22ms/step
# Accuracy: 95.20%
# Sensitivity (True Positive Rate): [0.85416667 0.95219124 0.96927374]
# Specificity (True Negative Rate): [0.99379524 0.97660099 0.93948127]
# Confusion Matrix:
# [[[1922 1586  652]
#   [  12   38   42]]
#
#  [[  28   24   44]
#   [ 164  478 1388]]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.93      0.85      0.89       192
#      Class 1       0.93      0.95      0.94       502
#      Class 2       0.97      0.97      0.97      1432
#
#    micro avg       0.96      0.95      0.96      2126
#    macro avg       0.94      0.93      0.93      2126
# weighted avg       0.96      0.95      0.96      2126
#  samples avg       0.96      0.95      0.95      2126
#
# Epoch 1/100
# 106/106 [==============================] - 23s 152ms/step - loss: 0.4635 - accuracy: 0.7330 - val_loss: 0.6296 - val_accuracy: 0.3536
# Epoch 2/100
# 106/106 [==============================] - 13s 123ms/step - loss: 0.3375 - accuracy: 0.7972 - val_loss: 0.6275 - val_accuracy: 0.3590
# Epoch 3/100
# 106/106 [==============================] - 8s 79ms/step - loss: 0.2755 - accuracy: 0.8470 - val_loss: 0.5358 - val_accuracy: 0.4051
# Epoch 4/100
# 106/106 [==============================] - 10s 99ms/step - loss: 0.2611 - accuracy: 0.8578 - val_loss: 0.6769 - val_accuracy: 0.3767
# Epoch 5/100
# 106/106 [==============================] - 15s 138ms/step - loss: 0.2441 - accuracy: 0.8721 - val_loss: 0.7325 - val_accuracy: 0.3767
# Epoch 6/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.2328 - accuracy: 0.8819 - val_loss: 0.5292 - val_accuracy: 0.6209
# Epoch 7/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.2175 - accuracy: 0.8904 - val_loss: 0.3397 - val_accuracy: 0.7516
# Epoch 8/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.2008 - accuracy: 0.8986 - val_loss: 0.2718 - val_accuracy: 0.8108
# Epoch 9/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.1982 - accuracy: 0.8981 - val_loss: 0.1269 - val_accuracy: 0.9355
# Epoch 10/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.1795 - accuracy: 0.9111 - val_loss: 0.1704 - val_accuracy: 0.8918
# Epoch 11/100
# 106/106 [==============================] - 14s 135ms/step - loss: 0.1745 - accuracy: 0.9145 - val_loss: 0.2810 - val_accuracy: 0.8060
# Epoch 12/100
# 106/106 [==============================] - 14s 135ms/step - loss: 0.1685 - accuracy: 0.9182 - val_loss: 0.3570 - val_accuracy: 0.7652
# Epoch 13/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.1532 - accuracy: 0.9289 - val_loss: 0.0588 - val_accuracy: 0.9769
# Epoch 14/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.1472 - accuracy: 0.9268 - val_loss: 0.1034 - val_accuracy: 0.9497
# Epoch 15/100
# 106/106 [==============================] - 12s 117ms/step - loss: 0.1418 - accuracy: 0.9302 - val_loss: 0.1332 - val_accuracy: 0.9279
# Epoch 16/100
# 106/106 [==============================] - 8s 79ms/step - loss: 0.1399 - accuracy: 0.9315 - val_loss: 0.0617 - val_accuracy: 0.9834
# Epoch 17/100
# 106/106 [==============================] - 11s 107ms/step - loss: 0.1300 - accuracy: 0.9366 - val_loss: 0.1262 - val_accuracy: 0.9415
# Epoch 18/100
# 106/106 [==============================] - 14s 135ms/step - loss: 0.1269 - accuracy: 0.9367 - val_loss: 0.0450 - val_accuracy: 0.9876
# Epoch 19/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.1182 - accuracy: 0.9415 - val_loss: 0.0458 - val_accuracy: 0.9870
# Epoch 20/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.1215 - accuracy: 0.9386 - val_loss: 0.0653 - val_accuracy: 0.9805
# Epoch 21/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.1114 - accuracy: 0.9423 - val_loss: 0.0424 - val_accuracy: 0.9888
# Epoch 22/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.1133 - accuracy: 0.9425 - val_loss: 0.0655 - val_accuracy: 0.9823
# Epoch 23/100
# 106/106 [==============================] - 14s 137ms/step - loss: 0.1052 - accuracy: 0.9453 - val_loss: 0.0752 - val_accuracy: 0.9681
# Epoch 24/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.1045 - accuracy: 0.9472 - val_loss: 0.0738 - val_accuracy: 0.9840
# Epoch 25/100
# 106/106 [==============================] - 15s 140ms/step - loss: 0.1021 - accuracy: 0.9452 - val_loss: 0.0483 - val_accuracy: 0.9817
# Epoch 26/100
# 106/106 [==============================] - 15s 141ms/step - loss: 0.0972 - accuracy: 0.9491 - val_loss: 0.0550 - val_accuracy: 0.9852
# Epoch 27/100
# 106/106 [==============================] - 15s 140ms/step - loss: 0.0946 - accuracy: 0.9509 - val_loss: 0.0399 - val_accuracy: 0.9905
# Epoch 28/100
# 106/106 [==============================] - 15s 139ms/step - loss: 0.0929 - accuracy: 0.9500 - val_loss: 0.0567 - val_accuracy: 0.9775
# Epoch 29/100
# 106/106 [==============================] - 13s 123ms/step - loss: 0.0914 - accuracy: 0.9528 - val_loss: 0.0532 - val_accuracy: 0.9811
# Epoch 30/100
# 106/106 [==============================] - 8s 79ms/step - loss: 0.0910 - accuracy: 0.9536 - val_loss: 0.0757 - val_accuracy: 0.9746
# Epoch 31/100
# 106/106 [==============================] - 11s 100ms/step - loss: 0.0840 - accuracy: 0.9540 - val_loss: 0.0678 - val_accuracy: 0.9734
# Epoch 32/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.0807 - accuracy: 0.9562 - val_loss: 0.0365 - val_accuracy: 0.9864
# Epoch 33/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.0782 - accuracy: 0.9595 - val_loss: 0.0489 - val_accuracy: 0.9834
# Epoch 34/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.0823 - accuracy: 0.9552 - val_loss: 0.0324 - val_accuracy: 0.9905
# Epoch 35/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.0803 - accuracy: 0.9571 - val_loss: 0.0367 - val_accuracy: 0.9864
# Epoch 36/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.0726 - accuracy: 0.9617 - val_loss: 0.0498 - val_accuracy: 0.9846
# Epoch 37/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.0773 - accuracy: 0.9586 - val_loss: 0.0534 - val_accuracy: 0.9805
# Epoch 38/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.0768 - accuracy: 0.9593 - val_loss: 0.0498 - val_accuracy: 0.9811
# Epoch 39/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.0687 - accuracy: 0.9656 - val_loss: 0.1126 - val_accuracy: 0.9426
# Epoch 40/100
# 106/106 [==============================] - 14s 136ms/step - loss: 0.0636 - accuracy: 0.9664 - val_loss: 0.0562 - val_accuracy: 0.9728
# Epoch 41/100
# 106/106 [==============================] - 14s 137ms/step - loss: 0.0670 - accuracy: 0.9622 - val_loss: 0.0324 - val_accuracy: 0.9888
# Epoch 42/100
# 106/106 [==============================] - 12s 111ms/step - loss: 0.0684 - accuracy: 0.9632 - val_loss: 0.0357 - val_accuracy: 0.9864
# Epoch 43/100
# 106/106 [==============================] - 8s 79ms/step - loss: 0.0635 - accuracy: 0.9666 - val_loss: 0.0423 - val_accuracy: 0.9811
# Epoch 44/100
# 106/106 [==============================] - 12s 110ms/step - loss: 0.0641 - accuracy: 0.9635 - val_loss: 0.0389 - val_accuracy: 0.9793
# 67/67 [==============================] - 3s 21ms/step
# Accuracy: 94.87%
# Sensitivity (True Positive Rate): [0.86631016 0.91858038 0.97260274]
# Specificity (True Negative Rate): [0.99535843 0.98299939 0.91741742]
# Confusion Matrix:
# [[[1930 1619  611]
#   [   9   28   55]]
#
#  [[  25   39   40]
#   [ 162  440 1420]]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.95      0.87      0.91       187
#      Class 1       0.94      0.92      0.93       479
#      Class 2       0.96      0.97      0.97      1460
#
#    micro avg       0.96      0.95      0.95      2126
#    macro avg       0.95      0.92      0.93      2126
# weighted avg       0.96      0.95      0.95      2126
#  samples avg       0.96      0.95      0.95      2126
#
# Epoch 1/100
# 106/106 [==============================] - 25s 166ms/step - loss: 0.4569 - accuracy: 0.7363 - val_loss: 0.5381 - val_accuracy: 0.3607
# Epoch 2/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.3316 - accuracy: 0.8040 - val_loss: 0.6549 - val_accuracy: 0.3625
# Epoch 3/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.2842 - accuracy: 0.8391 - val_loss: 0.6484 - val_accuracy: 0.3666
# Epoch 4/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.2622 - accuracy: 0.8579 - val_loss: 0.4736 - val_accuracy: 0.5322
# Epoch 5/100
# 106/106 [==============================] - 16s 155ms/step - loss: 0.2466 - accuracy: 0.8684 - val_loss: 0.5811 - val_accuracy: 0.4418
# Epoch 6/100
# 106/106 [==============================] - 16s 155ms/step - loss: 0.2257 - accuracy: 0.8838 - val_loss: 0.5109 - val_accuracy: 0.6127
# Epoch 7/100
# 106/106 [==============================] - 11s 106ms/step - loss: 0.2106 - accuracy: 0.8937 - val_loss: 0.3210 - val_accuracy: 0.7558
# Epoch 8/100
# 106/106 [==============================] - 9s 88ms/step - loss: 0.1969 - accuracy: 0.9023 - val_loss: 0.3256 - val_accuracy: 0.7664
# Epoch 9/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.1882 - accuracy: 0.9055 - val_loss: 0.3401 - val_accuracy: 0.7398
# Epoch 10/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.1745 - accuracy: 0.9153 - val_loss: 0.2114 - val_accuracy: 0.8652
# Epoch 11/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.1648 - accuracy: 0.9218 - val_loss: 0.0658 - val_accuracy: 0.9799
# Epoch 12/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.1588 - accuracy: 0.9261 - val_loss: 0.0586 - val_accuracy: 0.9840
# Epoch 13/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.1481 - accuracy: 0.9287 - val_loss: 0.2339 - val_accuracy: 0.8669
# Epoch 14/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.1416 - accuracy: 0.9315 - val_loss: 0.0744 - val_accuracy: 0.9722
# Epoch 15/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.1358 - accuracy: 0.9355 - val_loss: 0.0859 - val_accuracy: 0.9681
# Epoch 16/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.1303 - accuracy: 0.9386 - val_loss: 0.0584 - val_accuracy: 0.9781
# Epoch 17/100
# 106/106 [==============================] - 11s 104ms/step - loss: 0.1293 - accuracy: 0.9386 - val_loss: 0.0859 - val_accuracy: 0.9539
# Epoch 18/100
# 106/106 [==============================] - 9s 89ms/step - loss: 0.1227 - accuracy: 0.9397 - val_loss: 0.0653 - val_accuracy: 0.9846
# Epoch 19/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.1166 - accuracy: 0.9449 - val_loss: 0.0706 - val_accuracy: 0.9811
# Epoch 20/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.1179 - accuracy: 0.9416 - val_loss: 0.0442 - val_accuracy: 0.9899
# Epoch 21/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.1147 - accuracy: 0.9409 - val_loss: 0.1284 - val_accuracy: 0.9355
# Epoch 22/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.1086 - accuracy: 0.9477 - val_loss: 0.0417 - val_accuracy: 0.9888
# Epoch 23/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.1074 - accuracy: 0.9459 - val_loss: 0.1052 - val_accuracy: 0.9420
# Epoch 24/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.1055 - accuracy: 0.9474 - val_loss: 0.0322 - val_accuracy: 0.9911
# Epoch 25/100
# 106/106 [==============================] - 16s 149ms/step - loss: 0.1007 - accuracy: 0.9481 - val_loss: 0.1030 - val_accuracy: 0.9509
# Epoch 26/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0983 - accuracy: 0.9486 - val_loss: 0.0492 - val_accuracy: 0.9894
# Epoch 27/100
# 106/106 [==============================] - 11s 99ms/step - loss: 0.0902 - accuracy: 0.9537 - val_loss: 0.0314 - val_accuracy: 0.9911
# Epoch 28/100
# 106/106 [==============================] - 10s 92ms/step - loss: 0.0901 - accuracy: 0.9552 - val_loss: 0.0293 - val_accuracy: 0.9917
# Epoch 29/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0877 - accuracy: 0.9554 - val_loss: 0.0294 - val_accuracy: 0.9911
# Epoch 30/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0896 - accuracy: 0.9522 - val_loss: 0.1281 - val_accuracy: 0.9314
# Epoch 31/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0820 - accuracy: 0.9576 - val_loss: 0.0369 - val_accuracy: 0.9888
# Epoch 32/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0786 - accuracy: 0.9582 - val_loss: 0.1749 - val_accuracy: 0.8805
# Epoch 33/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0890 - accuracy: 0.9511 - val_loss: 0.0358 - val_accuracy: 0.9894
# Epoch 34/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0758 - accuracy: 0.9595 - val_loss: 0.0246 - val_accuracy: 0.9911
# Epoch 35/100
# 106/106 [==============================] - 16s 150ms/step - loss: 0.0770 - accuracy: 0.9577 - val_loss: 0.0360 - val_accuracy: 0.9894
# Epoch 36/100
# 106/106 [==============================] - 16s 147ms/step - loss: 0.0732 - accuracy: 0.9626 - val_loss: 0.0330 - val_accuracy: 0.9899
# Epoch 37/100
# 106/106 [==============================] - 9s 88ms/step - loss: 0.0695 - accuracy: 0.9624 - val_loss: 0.0557 - val_accuracy: 0.9687
# Epoch 38/100
# 106/106 [==============================] - 12s 109ms/step - loss: 0.0721 - accuracy: 0.9601 - val_loss: 0.0284 - val_accuracy: 0.9917
# Epoch 39/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0700 - accuracy: 0.9610 - val_loss: 0.0287 - val_accuracy: 0.9894
# Epoch 40/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0652 - accuracy: 0.9645 - val_loss: 0.0755 - val_accuracy: 0.9627
# Epoch 41/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0682 - accuracy: 0.9630 - val_loss: 0.0366 - val_accuracy: 0.9876
# Epoch 42/100
# 106/106 [==============================] - 16s 151ms/step - loss: 0.0611 - accuracy: 0.9672 - val_loss: 0.0312 - val_accuracy: 0.9882
# Epoch 43/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0609 - accuracy: 0.9669 - val_loss: 0.0225 - val_accuracy: 0.9905
# Epoch 44/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0586 - accuracy: 0.9687 - val_loss: 0.0442 - val_accuracy: 0.9846
# Epoch 45/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0605 - accuracy: 0.9661 - val_loss: 0.0490 - val_accuracy: 0.9805
# Epoch 46/100
# 106/106 [==============================] - 13s 124ms/step - loss: 0.0634 - accuracy: 0.9661 - val_loss: 0.0365 - val_accuracy: 0.9894
# Epoch 47/100
# 106/106 [==============================] - 9s 88ms/step - loss: 0.0565 - accuracy: 0.9672 - val_loss: 0.0624 - val_accuracy: 0.9687
# Epoch 48/100
# 106/106 [==============================] - 14s 131ms/step - loss: 0.0535 - accuracy: 0.9698 - val_loss: 0.0261 - val_accuracy: 0.9882
# Epoch 49/100
# 106/106 [==============================] - 16s 154ms/step - loss: 0.0614 - accuracy: 0.9681 - val_loss: 0.0390 - val_accuracy: 0.9852
# Epoch 50/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0519 - accuracy: 0.9701 - val_loss: 0.0423 - val_accuracy: 0.9834
# Epoch 51/100
# 106/106 [==============================] - 16s 153ms/step - loss: 0.0587 - accuracy: 0.9658 - val_loss: 0.0335 - val_accuracy: 0.9882
# Epoch 52/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0574 - accuracy: 0.9676 - val_loss: 0.0307 - val_accuracy: 0.9882
# Epoch 53/100
# 106/106 [==============================] - 16s 152ms/step - loss: 0.0541 - accuracy: 0.9694 - val_loss: 0.0955 - val_accuracy: 0.9509
# 67/67 [==============================] - 3s 22ms/step
# Accuracy: 95.72%
# Sensitivity (True Positive Rate): [0.85026738 0.94335938 0.98037842]
# Specificity (True Negative Rate): [0.99226405 0.98698885 0.92703863]
# Confusion Matrix:
# [[[1924 1593  648]
#   [  15   21   51]]
#
#  [[  28   29   28]
#   [ 159  483 1399]]]
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.91      0.85      0.88       187
#      Class 1       0.96      0.94      0.95       512
#      Class 2       0.96      0.98      0.97      1427
#
#    micro avg       0.96      0.96      0.96      2126
#    macro avg       0.95      0.92      0.93      2126
# weighted avg       0.96      0.96      0.96      2126
#  samples avg       0.96      0.96      0.96      2126
#
# Mean Accuracy: 95.07%
# Mean Sensitivity:
# [85.66006875 93.4356276  97.35539382]
# Mean Specificity:
# [99.37815162 98.09692829 92.45168055]
# Mean Confusion Matrix:
# [[[1917.8 1588.2  650.4]
#   [  12.    30.8   53.2]]
#
#  [[  28.2   33.2   37.6]
#   [ 168.2  474.  1385. ]]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize an empty list to store confusion matrix plots
confusion_matrix_plots = []

# Generate confusion matrix plot for each class
for class_idx in range(num_classes):
    class_conf_matrix = conf_matrix[:, :, class_idx]  # Get the class-specific confusion matrix
    plt.figure(figsize=(6, 4))
    sns.heatmap(class_conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix - Class {class_idx}')
    plt.show()
    confusion_matrix_plots.append(plt)
