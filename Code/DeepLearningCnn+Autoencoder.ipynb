# %%
import os
import numpy as np
import pandas as pd
import wfdb
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D
from tensorflow.keras.models import Model

# Define data_path and data
data_path = 'Af-Mitdb/'
data = ['100','101','102','103','104','105','106','107',
        '108','109','111','112','113','114','115','116',
        '117','118','119','121','122','123','124','200',
        '201','202','203','205','207','208','209','210',
        '212','213','214','215','217','219','220','221',
        '222','223','228','230','231','232','233','234',
        '04015', '04043', '04048', '04126', '04746',
        '04908', '04936', '05091', '05121', '05261',
        '06426', '06453', '06995', '07162', '07859',
        '07879', '07910', '08215', '08219', '08378',
        '08405', '08434', '08455']

# Function to load and preprocess EKG data
def load_preprocess_data(data_path, record_name):
    record_path = os.path.join(data_path, record_name)
    record = wfdb.rdrecord(record_path)
    annotation = wfdb.rdann(record_path, 'atr', shift_samps=True)
    ecg_signal = record.p_signal[:, 0]
    ecg_signal = np.nan_to_num(ecg_signal)

    # Standardize the signal
    scaler = StandardScaler()
    ecg_signal = scaler.fit_transform(ecg_signal.reshape(-1, 1)).flatten()

    # Pad or truncate signal to a fixed length
    target_length = 1000  # You can adjust this length as needed
    if len(ecg_signal) < target_length:
        pad_length = target_length - len(ecg_signal)
        ecg_signal = np.pad(ecg_signal, (0, pad_length), 'constant')
    elif len(ecg_signal) > target_length:
        ecg_signal = ecg_signal[:target_length]

    return ecg_signal

# Create an empty list to store processed ECG data for all records
all_ecg_data = []

# Loop through all records in the 'data' list
for record_name in data:
    ecg_data = load_preprocess_data(data_path, record_name)
    all_ecg_data.append(ecg_data)

# 'all_ecg_data' now contains the preprocessed ECG data for all records in 'data'

# Define the target length for the EKG signal
target_length = 100

# Input layer
input_layer = Input(shape=(target_length, 1))

# Encoder
encoded = Conv1D(32, 3, activation='relu', padding='same')(input_layer)
encoded = MaxPooling1D(2, padding='same')(encoded)
encoded = Conv1D(16, 3, activation='relu', padding='same')(encoded)
encoded = MaxPooling1D(2, padding='same')(encoded)

# Decoder
decoded = Conv1D(16, 3, activation='relu', padding='same')(encoded)
decoded = UpSampling1D(2)(decoded)
decoded = Conv1D(32, 3, activation='relu', padding='same')(decoded)
decoded = UpSampling1D(2)(decoded)
decoded_output = Conv1D(1, 3, activation='linear', padding='same')(decoded)

# Create the CAE model
autoencoder = Model(inputs=input_layer, outputs=decoded_output)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Train the Convolutional Autoencoder (you can adjust the number of epochs and batch size)
num_epochs = 100
batch_size = 32

# Convert all_ecg_data to a NumPy array
all_ecg_data = np.array(all_ecg_data)

# Training on all records
history = autoencoder.fit(all_ecg_data.reshape(-1, target_length, 1),
                          all_ecg_data.reshape(-1, target_length, 1),
                          epochs=num_epochs,
                          batch_size=batch_size,
                          shuffle=True,
                          validation_split=0.2)

# Calculate SNR
def calculate_snr(original_signal, denoised_signal):
    signal_power = np.sum(original_signal**2)
    noise_power = np.sum((original_signal - denoised_signal)**2)
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

# Predict using the trained model
denoised_data = autoencoder.predict(ecg_data.reshape(-1, target_length, 1))

# Plot the original and denoised signal
plt.figure(figsize=(12, 4))
plt.subplot(2, 1, 1)
plt.plot(ecg_data)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('Original ECG Signal')

plt.subplot(2, 1, 2)
plt.plot(denoised_data.flatten())
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('Denoised ECG Signal')
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 18/18 [==============================] - 15s 21ms/step - loss: 0.6180 - val_loss: 0.4311
# Epoch 2/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1615 - val_loss: 0.3443
# Epoch 3/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0695 - val_loss: 0.2350
# Epoch 4/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0366 - val_loss: 0.2215
# Epoch 5/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0265 - val_loss: 0.2091
# Epoch 6/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0202 - val_loss: 0.2026
# Epoch 7/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0159 - val_loss: 0.1966
# Epoch 8/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0131 - val_loss: 0.1937
# Epoch 9/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0112 - val_loss: 0.1919
# Epoch 10/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0097 - val_loss: 0.1908
# Epoch 11/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0086 - val_loss: 0.1896
# Epoch 12/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0077 - val_loss: 0.1889
# Epoch 13/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.1887
# Epoch 14/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.1880
# Epoch 15/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0060 - val_loss: 0.1871
# Epoch 16/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.1870
# Epoch 17/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0053 - val_loss: 0.1869
# Epoch 18/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.1864
# Epoch 19/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 0.1860
# Epoch 20/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0045 - val_loss: 0.1861
# Epoch 21/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.1859
# Epoch 22/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0041 - val_loss: 0.1862
# Epoch 23/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.1865
# Epoch 24/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0038 - val_loss: 0.1866
# Epoch 25/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 0.1875
# Epoch 26/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.1879
# Epoch 27/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 0.1869
# Epoch 28/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0034 - val_loss: 0.1877
# Epoch 29/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 0.1884
# Epoch 30/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 0.1890
# Epoch 31/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 0.1879
# Epoch 32/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 0.1893
# Epoch 33/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.1888
# Epoch 34/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0029 - val_loss: 0.1903
# Epoch 35/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.1894
# Epoch 36/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 0.1900
# Epoch 37/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 0.1899
# Epoch 38/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0026 - val_loss: 0.1902
# Epoch 39/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 0.1904
# Epoch 40/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.1906
# Epoch 41/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.1903
# Epoch 42/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.1922
# Epoch 43/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.1910
# Epoch 44/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.1895
# Epoch 45/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.1922
# Epoch 46/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.1914
# Epoch 47/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.1892
# Epoch 48/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.1915
# Epoch 49/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.1890
# Epoch 50/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.1894
# Epoch 51/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.1895
# Epoch 52/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.1898
# Epoch 53/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.1895
# Epoch 54/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.1891
# Epoch 55/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.1898
# Epoch 56/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 0.1897
# Epoch 57/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.1902
# Epoch 58/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.1891
# Epoch 59/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.1880
# Epoch 60/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.1884
# Epoch 61/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.1879
# Epoch 62/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.1885
# Epoch 63/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.1886
# Epoch 64/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.1876
# Epoch 65/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.1873
# Epoch 66/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.1870
# Epoch 67/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.1867
# Epoch 68/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.1877
# Epoch 69/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.1869
# Epoch 70/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.1868
# Epoch 71/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.1865
# Epoch 72/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.1870
# Epoch 73/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.1872
# Epoch 74/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.1890
# Epoch 75/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.1858
# Epoch 76/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.1864
# Epoch 77/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.1858
# Epoch 78/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.1859
# Epoch 79/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.1861
# Epoch 80/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.1867
# Epoch 81/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.1866
# Epoch 82/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.1874
# Epoch 83/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.1867
# Epoch 84/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.1860
# Epoch 85/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.1887
# Epoch 86/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.1877
# Epoch 87/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.1869
# Epoch 88/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 0.1861
# Epoch 89/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 0.1859
# Epoch 90/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.1861
# Epoch 91/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.1859
# Epoch 92/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.1869
# Epoch 93/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.1867
# Epoch 94/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.1876
# Epoch 95/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.1868
# Epoch 96/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.1872
# Epoch 97/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.1862
# Epoch 98/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.1860
# Epoch 99/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.1867
# Epoch 100/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.1862
# 1/1 [==============================] - 0s 107ms/step

# %%
# Creating a Empty Dataframe
symbols_df = pd.DataFrame()

# Reading all .atr files 
for pts in data:
    # Generating filepath for all .atr file names
    file = data_path + pts
    # Saving annotation object
    annotation = wfdb.rdann(file, 'atr')
    # Extracting symbols from the object
    sym = annotation.symbol
    # Saving value counts
    values, counts = np.unique(sym, return_counts=True)
    # Writing data points into dataframe
    df_sub = pd.DataFrame({'symbol':values, 'Counts':counts, 'data Number':[pts]*len(counts)})
    # Concatenating all data points  
    symbols_df = pd.concat([symbols_df, df_sub],axis = 0)

# Loop over all records and load the signal and annotations
for record_name in data:
    record_path = os.path.join(data_path, record_name)
    record = wfdb.rdrecord(record_path)
    annotation = wfdb.rdann(record_path, 'atr', shift_samps=True)
    ecg_signal = record.p_signal[:,0]
    ecg_signal = np.nan_to_num(ecg_signal)

    # Get the signal and labels
    sig = ecg_signal
    labels = np.array(annotation.symbol)

plt.figure(figsize=(12, 4))
plt.plot(sig)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('ECG Signal')
plt.show()

# %%
symbols_df
# Out:
#    symbol  Counts data Number
# 0       +       1         100
# 1       A      33         100
# 2       N    2239         100
# 3       V       1         100
# 0       +       1         101
# ..    ...     ...         ...
# 0       +      79       08219
# 0       +      17       08378
# 0       +       4       08405
# 0       +       7       08434
# 0       +       4       08455
#
# [306 rows x 3 columns]

# %%
# Value Counts of Different symbols in data
symbols_df.groupby('symbol').Counts.sum().sort_values(ascending = False)
# Out:
# symbol
# N    75052
# L     8075
# R     7259
# V     7130
# /     7028
# A     2546
# +     1896
# f      982
# F      803
# ~      616
# !      472
# "      437
# j      229
# x      193
# a      150
# |      132
# E      106
# J       83
# Q       33
# e       16
# [        6
# ]        6
# S        2
# Name: Counts, dtype: int64

# %%
# Normal Beat Symbols
normal = ['N']

# Abnormal Beat Symbols
AF = ['f']
PAC = ['A']
PVC = ['V']

abnormal_category = AF + PAC + PVC + normal

# Classifying abnormal beats into more specific categories
symbols_df.loc[symbols_df.symbol == 'N','abnormal_category'] = "N"
symbols_df.loc[symbols_df.symbol.isin(AF), 'abnormal_category'] = "AF"
symbols_df.loc[symbols_df.symbol.isin(PAC), 'abnormal_category'] = "PAC"
symbols_df.loc[symbols_df.symbol.isin(PVC), 'abnormal_category'] = "PVC"

# Value counts of different categories
symbols_df.groupby('abnormal_category').Counts.sum()
# Out:
# abnormal_category
# AF       982
# N      75052
# PAC     2546
# PVC     7130
# Name: Counts, dtype: int64

# %%
def load_ecg(file):
    # load the ecg
    record = wfdb.rdrecord(file)
    # load the annotation
    annotation = wfdb.rdann(file, 'atr')

    # extracting the signal
    p_signal = record.p_signal

    # extracting symbols and annotation index
    atr_sym = annotation.symbol
    atr_sample = annotation.sample

    return p_signal, atr_sym, atr_sample

# %%
# Accessing the ecg points for
file = data_path + data[8]

# %%
# Accessing the load ECG function and getting annotation.symbol, annotation.sample, signals
p_signal, atr_sym, atr_sample = load_ecg(file)

# %%
# Analysing annotations value counts for a single record
values, counts = np.unique(sym, return_counts=True)
for v,c in zip(values, counts):
    print(v,c)
# Out:
# + 4

# %%
# get abnormal beat index
ab_index = [b for a,b in zip(atr_sym,atr_sample) if a in abnormal_category][:10]
ab_index
# Out:
# [88, 442, 789, 1155, 1493, 1821, 2157, 2517, 2889, 3238]

# %%
# Generating evenly spaced values
# x = np.arange(len(p_signal))

# left = ab_index[5]-20000
# right = ab_index[5]+20000

# plt.figure(figsize=(20,8))
# plt.plot(x[left:right],p_signal[left:right,0],'-',label='ecg',)
# plt.plot(x[atr_sample],p_signal[atr_sample,0],'go',label ='normal')
# plt.plot(x[ab_index],p_signal[ab_index,0],'ro',label='abnormal')

# plt.xlim(left,right)
# plt.ylim(p_signal[left:right].min()-0.05,p_signal[left:right,0].max()+0.05)
# plt.xlabel('time index')
# plt.ylabel('ECG signal')
# plt.legend(bbox_to_anchor = (1.04,1), loc = 'upper left')
# plt.show()

# %%
def make_dataset(record_patients, num_sec, fs, abnormal_category):

    # initialize numpy arrays
    num_cols = 2*num_sec * fs
    X_all = np.zeros((1,num_cols))
    Y_all = np.zeros((1,len(abnormal_category)))
    sym_all = []

    # list to keep track of number of beats across patients
    max_rows = []

    for pt in data:
        file = data_path + pt

        p_signal, atr_sym, atr_sample = load_ecg(file)

        # grab the first signal
        p_signal = p_signal[:,0]

        # make df to exclude the nonbeats
        df_ann = pd.DataFrame({'atr_sym':atr_sym,
                              'atr_sample':atr_sample})
        df_ann = df_ann.loc[df_ann.atr_sym.isin(abnormal_category)]

        num_rows = len(df_ann)

        X = np.zeros((num_rows, num_cols))
        Y = np.zeros((num_rows, len(abnormal_category)))
        sym = []

        # keep track of rows
        max_row = 0

        for atr_sample, atr_sym in zip(df_ann.atr_sample.values,df_ann.atr_sym.values):

            left = max([0,(atr_sample - num_sec*fs) ])
            right = min([len(p_signal),(atr_sample + num_sec*fs) ])
            x = p_signal[left: right]
            if len(x) == num_cols:
                X[max_row,:] = x
                Y[max_row, abnormal_category.index(atr_sym)] = 1
                sym.append(atr_sym)
                max_row += 1
        X = X[:max_row,:]
        Y = Y[:max_row,:]

        sym_all = sym_all+sym
        max_rows.append(X.shape[0])
        X_all = np.append(X_all,X,axis = 0)
        Y_all = np.append(Y_all,Y,axis = 0)

    # drop the first zero row
    X_all = X_all[1:,:]
    Y_all = Y_all[1:,:]

    return X_all, Y_all, sym_all

# %%
import seaborn as sns
# Value counts of different categories
counts_df = symbols_df.groupby('abnormal_category')['Counts'].sum().reset_index()
print(counts_df)

# Visualize the number of subjects in each abnormal_category:
sns.barplot(x='abnormal_category', y='Counts', data=counts_df)
plt.show()
# Out:
#   abnormal_category  Counts
# 0                AF     982
# 1                 N   75052
# 2               PAC    2546
# 3               PVC    7130

# %%
import numpy as np
from scipy.stats import kurtosis, skew
from scipy.fft import fft

def extract_features(rr_intervals):
    features = {}

    # RR Interval Features
    rr_mean = np.mean(rr_intervals)
    rr_std = np.std(rr_intervals)
    rr_min = np.min(rr_intervals)
    rr_max = np.max(rr_intervals)
    rr_range = rr_max - rr_min
    rr_median = np.median(rr_intervals)
    rr_diff = np.diff(rr_intervals)
    rr_fft = np.abs(fft(rr_intervals))
    rr_skewness = skew(rr_intervals)
    rr_kurtosis = kurtosis(rr_intervals)

    features['RR Mean'] = rr_mean
    features['RR Std'] = rr_std
    features['RR Min'] = rr_min
    features['RR Max'] = rr_max
    features['RR Range'] = rr_range
    features['RR Median'] = rr_median
    features['RR Skewness'] = rr_skewness
    features['RR Kurtosis'] = rr_kurtosis

    features['mean_rr_diff'] = np.mean(rr_diff)
    features['std_rr_diff'] = np.std(rr_diff)
    features['min_rr_diff'] = np.min(rr_diff)
    features['max_rr_diff'] = np.max(rr_diff)
    features['median_rr_diff'] = np.median(rr_diff)
    features['range_rr_diff'] = np.ptp(rr_diff)

    features['RR FFT Mean'] = np.mean(rr_fft)
    features['RR FFT Std'] = np.std(rr_fft)
    features['RR FFT Max'] = np.max(rr_fft)

    rr_variance = np.var(rr_intervals)
    rr_coefficient_of_variation = np.mean(rr_intervals) / np.std(rr_intervals)

    features['RR Variance'] = rr_variance
    features['RR Coefficient of Variation'] = rr_coefficient_of_variation

    # Additional Statistical Features
    features['RR 5th Percentile'] = np.percentile(rr_intervals, 5)
    features['RR 95th Percentile'] = np.percentile(rr_intervals, 95)
    features['RR Interquartile Range'] = np.percentile(rr_intervals, 75) - np.percentile(rr_intervals, 25)

    # Additional Dynamic Features
    rr_diff_mean = np.mean(rr_diff)
    rr_diff_std = np.std(rr_diff)
    rr_diff_min = np.min(rr_diff)
    rr_diff_max = np.max(rr_diff)
    rr_diff_median = np.median(rr_diff)
    rr_diff_range = np.ptp(rr_diff)

    features['mean_rr_diff'] = rr_diff_mean
    features['std_rr_diff'] = rr_diff_std
    features['min_rr_diff'] = rr_diff_min
    features['max_rr_diff'] = rr_diff_max
    features['median_rr_diff'] = rr_diff_median
    features['range_rr_diff'] = rr_diff_range


    return features

# %%
import matplotlib.pyplot as plt

# Set the parameters
num_sec = 3
fs = 360

# Accessing the function and creating a dataset with ECG digital points
X_all, Y_all, sym_all = make_dataset(data, num_sec, fs, abnormal_category)

# Mengambil segmen RR interval
rr_intervals = X_all[:, fs * num_sec:]

features = []
for rr in rr_intervals:
    feature = extract_features(rr)
    features.append(feature)

# Convert the features list to a dataframe
df_features = pd.DataFrame(features)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Assuming denoised_data is a 2D array or list of lists, convert it to 1-D
denoised_data = np.array(denoised_data).flatten()

r_peaks, _ = find_peaks(denoised_data[:len(rr_intervals[0])], prominence=0.4)

# Plot the QRS complexes with R, Q, and S peaks
plt.figure(figsize=(10, 5))
plt.plot(denoised_data[:len(rr_intervals[0])], color='blue', label='RR Interval')
plt.plot(r_peaks, denoised_data[r_peaks], 'ro', markersize=4, label='R Peaks')

plt.title('RR Interval')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
import numpy as np
from keras.utils import to_categorical
import pandas as pd
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.preprocessing import LabelEncoder, Normalizer
from sklearn.metrics import classification_report
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from tensorflow.keras.optimizers import RMSprop

# Jumlah lipatan pada K-Fold
num_folds = 5

# Inisialisasi array untuk menyimpan hasil evaluasi
accuracies = []
conf_matrices = []

# Inisialisasi K-Fold Cross Validation
kfold = KFold(n_splits=num_folds, shuffle=True)

for train_index, test_index in kfold.split(df_features):
    X_train, X_val = df_features.iloc[train_index[:-50]], df_features.iloc[train_index[-50:]]
    Y_train, Y_val = Y_all[train_index[:-50]], Y_all[train_index[-50:]]
    X_test, Y_test = df_features.iloc[test_index], Y_all[test_index]

    # Standarisasi fitur input
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    # Reshape fitur input untuk CNN
    X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
    X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)
    X_test_reshaped = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

    # Build the CNN model
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)),
        MaxPooling1D(pool_size=2),
        Conv1D(filters=128, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        Conv1D(filters=256, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(4, activation='softmax')
    ])

    # Menentukan EarlyStopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    # Mengompilasi dan melatih model
    model.compile(loss='categorical_crossentropy', optimizer='RMSprop', metrics=['accuracy'])
    model.fit(X_train_reshaped, Y_train, epochs=100, batch_size=128, validation_data=(X_val_reshaped, Y_val), callbacks=[early_stopping])

    # Evaluasi model pada data pengujian
    loss, accuracy = model.evaluate(X_test_reshaped, Y_test)
    accuracies.append(accuracy)

    # Prediksi kelas pada data pengujian
    Y_pred = model.predict(X_test_reshaped)
    Y_pred_labels = np.argmax(Y_pred, axis=1)
    Y_true_labels = np.argmax(Y_test, axis=1)

    # Matriks konfusi
    conf_matrix = confusion_matrix(Y_true_labels, Y_pred_labels, labels=np.arange(len(abnormal_category)))
    conf_matrices.append(conf_matrix)

# Rata-rata akurasi dan matriks konfusi pada semua lipatan
mean_accuracy = np.mean(accuracies)
mean_conf_matrix = np.sum(conf_matrices, axis=0)

print("Mean Accuracy:", mean_accuracy)
print("Mean Confusion Matrix:")
print(mean_conf_matrix)

# Classification report
print("Classification Report:")
print(classification_report(Y_true_labels, Y_pred_labels, labels=np.arange(len(abnormal_category)), target_names=abnormal_category))

# Menghitung sensitivity untuk setiap kelas abnormal
sensitivities = []
for i in range(len(abnormal_category)):
    true_positives = mean_conf_matrix[i, i]
    false_negatives = np.sum(mean_conf_matrix[i, :]) - true_positives
    sensitivity = true_positives / (true_positives + false_negatives)
    sensitivities.append(sensitivity)

# Menampilkan sensitivities
for i in range(len(abnormal_category)):
    print(f"Sensitivity ({abnormal_category[i]}): {sensitivities[i]}")

print('')

sensitivities = []
for conf_matrix in conf_matrices:
    tp = conf_matrix[1, 1]  # True positives
    fn = conf_matrix[1, 0]  # False negatives
    sensitivity = tp / (tp + fn)
    sensitivities.append(sensitivity)

mean_sensitivity = np.mean(sensitivities)
print("Mean Sensitivity:", mean_sensitivity)

print('')
print('==================================================================')
print('')

# Menghitung specificities untuk setiap kelas abnormal
specificities = []
for i in range(len(abnormal_category)):
    true_negatives = np.sum(mean_conf_matrix) - np.sum(mean_conf_matrix[i, :]) - np.sum(mean_conf_matrix[:, i]) + mean_conf_matrix[i, i]
    false_positives = np.sum(mean_conf_matrix[:, i]) - mean_conf_matrix[i, i]
    specificity = true_negatives / (true_negatives + false_positives)
    specificities.append(specificity)

# Menampilkan specificities
for i in range(len(abnormal_category)):
    print(f"Specificity ({abnormal_category[i]}): {specificities[i]}")

print('')

specificities = []
for conf_matrix in conf_matrices:
    tn = conf_matrix[0, 0]  # True negatives
    fp = conf_matrix[0, 1]  # False positives
    specificity = tn / (tn + fp)
    specificities.append(specificity)

mean_specificity = np.mean(specificities)
print("Mean Specificity:", mean_specificity)
# Out:
# Epoch 1/100
# 534/534 [==============================] - 5s 8ms/step - loss: 0.2735 - accuracy: 0.9141 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 2/100
# 534/534 [==============================] - 5s 9ms/step - loss: 0.1782 - accuracy: 0.9413 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 3/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1576 - accuracy: 0.9483 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 4/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1480 - accuracy: 0.9518 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 5/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1408 - accuracy: 0.9540 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 6/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1347 - accuracy: 0.9556 - val_loss: 6.3330e-04 - val_accuracy: 1.0000
# Epoch 7/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1296 - accuracy: 0.9567 - val_loss: 3.6077e-04 - val_accuracy: 1.0000
# Epoch 8/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1259 - accuracy: 0.9573 - val_loss: 4.0415e-04 - val_accuracy: 1.0000
# Epoch 9/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1226 - accuracy: 0.9596 - val_loss: 9.4624e-05 - val_accuracy: 1.0000
# Epoch 10/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1201 - accuracy: 0.9606 - val_loss: 3.3572e-04 - val_accuracy: 1.0000
# Epoch 11/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1179 - accuracy: 0.9604 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 12/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1166 - accuracy: 0.9616 - val_loss: 7.8689e-04 - val_accuracy: 1.0000
# Epoch 13/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1154 - accuracy: 0.9618 - val_loss: 9.2344e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1137 - accuracy: 0.9616 - val_loss: 2.2272e-05 - val_accuracy: 1.0000
# Epoch 15/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1129 - accuracy: 0.9622 - val_loss: 2.3243e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1121 - accuracy: 0.9620 - val_loss: 8.2898e-04 - val_accuracy: 1.0000
# Epoch 17/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1089 - accuracy: 0.9629 - val_loss: 3.7838e-04 - val_accuracy: 1.0000
# Epoch 18/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1089 - accuracy: 0.9633 - val_loss: 1.5135e-04 - val_accuracy: 1.0000
# Epoch 19/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1073 - accuracy: 0.9638 - val_loss: 2.2707e-05 - val_accuracy: 1.0000
# Epoch 20/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1081 - accuracy: 0.9636 - val_loss: 1.0869e-05 - val_accuracy: 1.0000
# Epoch 21/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1089 - accuracy: 0.9637 - val_loss: 6.1375e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1078 - accuracy: 0.9642 - val_loss: 8.1522e-04 - val_accuracy: 1.0000
# Epoch 23/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1072 - accuracy: 0.9640 - val_loss: 1.0745e-05 - val_accuracy: 1.0000
# Epoch 24/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1074 - accuracy: 0.9643 - val_loss: 6.1426e-05 - val_accuracy: 1.0000
# Epoch 25/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1070 - accuracy: 0.9654 - val_loss: 1.6515e-04 - val_accuracy: 1.0000
# Epoch 26/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1061 - accuracy: 0.9645 - val_loss: 6.4333e-04 - val_accuracy: 1.0000
# Epoch 27/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1067 - accuracy: 0.9640 - val_loss: 2.6159e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1066 - accuracy: 0.9648 - val_loss: 5.5926e-06 - val_accuracy: 1.0000
# Epoch 29/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1064 - accuracy: 0.9644 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 30/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1055 - accuracy: 0.9650 - val_loss: 1.0632e-05 - val_accuracy: 1.0000
# Epoch 31/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1063 - accuracy: 0.9642 - val_loss: 6.0093e-04 - val_accuracy: 1.0000
# Epoch 32/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1059 - accuracy: 0.9653 - val_loss: 2.5777e-05 - val_accuracy: 1.0000
# Epoch 33/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1042 - accuracy: 0.9652 - val_loss: 2.1472e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1045 - accuracy: 0.9651 - val_loss: 3.0576e-05 - val_accuracy: 1.0000
# Epoch 35/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1050 - accuracy: 0.9651 - val_loss: 5.2666e-05 - val_accuracy: 1.0000
# Epoch 36/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1036 - accuracy: 0.9655 - val_loss: 3.9075e-06 - val_accuracy: 1.0000
# Epoch 37/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1042 - accuracy: 0.9650 - val_loss: 1.5549e-04 - val_accuracy: 1.0000
# Epoch 38/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1043 - accuracy: 0.9657 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 39/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1046 - accuracy: 0.9652 - val_loss: 4.8160e-07 - val_accuracy: 1.0000
# Epoch 40/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1027 - accuracy: 0.9661 - val_loss: 1.5673e-04 - val_accuracy: 1.0000
# Epoch 41/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1041 - accuracy: 0.9664 - val_loss: 2.9220e-04 - val_accuracy: 1.0000
# Epoch 42/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1027 - accuracy: 0.9658 - val_loss: 6.7544e-04 - val_accuracy: 1.0000
# Epoch 43/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1020 - accuracy: 0.9662 - val_loss: 6.6361e-04 - val_accuracy: 1.0000
# Epoch 44/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.0998 - accuracy: 0.9662 - val_loss: 5.7708e-05 - val_accuracy: 1.0000
# Epoch 45/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1019 - accuracy: 0.9656 - val_loss: 8.9056e-05 - val_accuracy: 1.0000
# Epoch 46/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1014 - accuracy: 0.9666 - val_loss: 2.1679e-05 - val_accuracy: 1.0000
# Epoch 47/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1012 - accuracy: 0.9665 - val_loss: 2.5327e-05 - val_accuracy: 1.0000
# Epoch 48/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.0991 - accuracy: 0.9667 - val_loss: 8.2486e-06 - val_accuracy: 1.0000
# Epoch 49/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1010 - accuracy: 0.9667 - val_loss: 2.8232e-04 - val_accuracy: 1.0000
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1457 - accuracy: 0.9609
# 534/534 [==============================] - 1s 2ms/step
# Epoch 1/100
# 534/534 [==============================] - 8s 12ms/step - loss: 0.2743 - accuracy: 0.9144 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 2/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1756 - accuracy: 0.9427 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 3/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1560 - accuracy: 0.9492 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 4/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1446 - accuracy: 0.9525 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 5/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1367 - accuracy: 0.9550 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 6/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1319 - accuracy: 0.9561 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 7/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1272 - accuracy: 0.9577 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 8/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1234 - accuracy: 0.9590 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 9/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1196 - accuracy: 0.9602 - val_loss: 1.5692e-04 - val_accuracy: 1.0000
# Epoch 10/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1182 - accuracy: 0.9607 - val_loss: 4.8705e-04 - val_accuracy: 1.0000
# Epoch 11/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1151 - accuracy: 0.9614 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 12/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1133 - accuracy: 0.9621 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 13/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1120 - accuracy: 0.9623 - val_loss: 8.0384e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1102 - accuracy: 0.9634 - val_loss: 4.7889e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1079 - accuracy: 0.9643 - val_loss: 3.4325e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1081 - accuracy: 0.9635 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 17/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1076 - accuracy: 0.9644 - val_loss: 4.1539e-04 - val_accuracy: 1.0000
# Epoch 18/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1073 - accuracy: 0.9642 - val_loss: 3.3105e-04 - val_accuracy: 1.0000
# Epoch 19/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1061 - accuracy: 0.9646 - val_loss: 0.0012 - val_accuracy: 1.0000
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1590 - accuracy: 0.9546
# 534/534 [==============================] - 1s 2ms/step
# Epoch 1/100
# 534/534 [==============================] - 8s 12ms/step - loss: 0.2694 - accuracy: 0.9151 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 2/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1785 - accuracy: 0.9422 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 3/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1587 - accuracy: 0.9489 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 4/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1476 - accuracy: 0.9513 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 5/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1395 - accuracy: 0.9540 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 6/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1342 - accuracy: 0.9561 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 7/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1305 - accuracy: 0.9572 - val_loss: 4.0232e-04 - val_accuracy: 1.0000
# Epoch 8/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1264 - accuracy: 0.9581 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 9/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1236 - accuracy: 0.9589 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 10/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1209 - accuracy: 0.9593 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 11/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1188 - accuracy: 0.9609 - val_loss: 6.7538e-04 - val_accuracy: 1.0000
# Epoch 12/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1152 - accuracy: 0.9611 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 13/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1154 - accuracy: 0.9620 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 14/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1139 - accuracy: 0.9621 - val_loss: 5.2297e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1137 - accuracy: 0.9628 - val_loss: 2.9786e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1121 - accuracy: 0.9623 - val_loss: 1.6156e-04 - val_accuracy: 1.0000
# Epoch 17/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1118 - accuracy: 0.9628 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 18/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1101 - accuracy: 0.9636 - val_loss: 8.0855e-05 - val_accuracy: 1.0000
# Epoch 19/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1103 - accuracy: 0.9630 - val_loss: 5.6474e-04 - val_accuracy: 1.0000
# Epoch 20/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1103 - accuracy: 0.9645 - val_loss: 1.6292e-04 - val_accuracy: 1.0000
# Epoch 21/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1084 - accuracy: 0.9647 - val_loss: 7.8783e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 534/534 [==============================] - 6s 11ms/step - loss: 0.1078 - accuracy: 0.9643 - val_loss: 9.3688e-05 - val_accuracy: 1.0000
# Epoch 23/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1075 - accuracy: 0.9644 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 24/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1078 - accuracy: 0.9646 - val_loss: 6.4061e-06 - val_accuracy: 1.0000
# Epoch 25/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1087 - accuracy: 0.9642 - val_loss: 4.7445e-05 - val_accuracy: 1.0000
# Epoch 26/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1065 - accuracy: 0.9648 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 27/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1065 - accuracy: 0.9646 - val_loss: 8.0878e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1067 - accuracy: 0.9651 - val_loss: 1.7113e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1069 - accuracy: 0.9645 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 30/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1076 - accuracy: 0.9651 - val_loss: 6.8327e-04 - val_accuracy: 1.0000
# Epoch 31/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1070 - accuracy: 0.9652 - val_loss: 8.4379e-05 - val_accuracy: 1.0000
# Epoch 32/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1062 - accuracy: 0.9648 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 33/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1085 - accuracy: 0.9644 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 34/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1052 - accuracy: 0.9656 - val_loss: 7.0328e-06 - val_accuracy: 1.0000
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1626 - accuracy: 0.9555
# 534/534 [==============================] - 1s 2ms/step
# Epoch 1/100
# 534/534 [==============================] - 8s 12ms/step - loss: 0.2761 - accuracy: 0.9127 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 2/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1814 - accuracy: 0.9411 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 3/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1595 - accuracy: 0.9476 - val_loss: 9.8471e-04 - val_accuracy: 1.0000
# Epoch 4/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1480 - accuracy: 0.9512 - val_loss: 9.2394e-04 - val_accuracy: 1.0000
# Epoch 5/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1411 - accuracy: 0.9534 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 6/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1343 - accuracy: 0.9556 - val_loss: 3.2839e-04 - val_accuracy: 1.0000
# Epoch 7/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1307 - accuracy: 0.9566 - val_loss: 8.3571e-04 - val_accuracy: 1.0000
# Epoch 8/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1275 - accuracy: 0.9577 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 9/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1236 - accuracy: 0.9589 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 10/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1209 - accuracy: 0.9590 - val_loss: 3.2654e-04 - val_accuracy: 1.0000
# Epoch 11/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1188 - accuracy: 0.9605 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 12/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1173 - accuracy: 0.9614 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 13/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1148 - accuracy: 0.9620 - val_loss: 9.2985e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1131 - accuracy: 0.9618 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 15/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1123 - accuracy: 0.9626 - val_loss: 9.0959e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1108 - accuracy: 0.9634 - val_loss: 2.5693e-04 - val_accuracy: 1.0000
# Epoch 17/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1103 - accuracy: 0.9630 - val_loss: 4.2781e-04 - val_accuracy: 1.0000
# Epoch 18/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1095 - accuracy: 0.9637 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 19/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1092 - accuracy: 0.9640 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 20/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1068 - accuracy: 0.9644 - val_loss: 4.1957e-04 - val_accuracy: 1.0000
# Epoch 21/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1078 - accuracy: 0.9649 - val_loss: 2.2079e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1080 - accuracy: 0.9647 - val_loss: 4.3338e-04 - val_accuracy: 1.0000
# Epoch 23/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1058 - accuracy: 0.9650 - val_loss: 5.6014e-05 - val_accuracy: 1.0000
# Epoch 24/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1078 - accuracy: 0.9650 - val_loss: 2.2956e-04 - val_accuracy: 1.0000
# Epoch 25/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1058 - accuracy: 0.9648 - val_loss: 8.1939e-04 - val_accuracy: 1.0000
# Epoch 26/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1062 - accuracy: 0.9649 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 27/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1048 - accuracy: 0.9652 - val_loss: 1.0207e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1044 - accuracy: 0.9647 - val_loss: 5.7048e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1038 - accuracy: 0.9651 - val_loss: 2.4116e-05 - val_accuracy: 1.0000
# Epoch 30/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1055 - accuracy: 0.9654 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 31/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1061 - accuracy: 0.9651 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 32/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1057 - accuracy: 0.9654 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 33/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1057 - accuracy: 0.9650 - val_loss: 7.7024e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1049 - accuracy: 0.9659 - val_loss: 7.3324e-05 - val_accuracy: 1.0000
# Epoch 35/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1037 - accuracy: 0.9657 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 36/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1040 - accuracy: 0.9654 - val_loss: 6.3949e-04 - val_accuracy: 1.0000
# Epoch 37/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1032 - accuracy: 0.9663 - val_loss: 1.1316e-04 - val_accuracy: 1.0000
# Epoch 38/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1031 - accuracy: 0.9657 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 39/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1030 - accuracy: 0.9662 - val_loss: 8.6398e-04 - val_accuracy: 1.0000
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1456 - accuracy: 0.9575
# 534/534 [==============================] - 1s 2ms/step
# Epoch 1/100
# 534/534 [==============================] - 8s 12ms/step - loss: 0.2769 - accuracy: 0.9120 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 2/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1810 - accuracy: 0.9409 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 3/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1619 - accuracy: 0.9468 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 4/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1501 - accuracy: 0.9502 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 5/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1436 - accuracy: 0.9523 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 6/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1373 - accuracy: 0.9550 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 7/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1328 - accuracy: 0.9562 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 8/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1293 - accuracy: 0.9575 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 9/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1262 - accuracy: 0.9588 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 10/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1237 - accuracy: 0.9587 - val_loss: 8.0507e-04 - val_accuracy: 1.0000
# Epoch 11/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1209 - accuracy: 0.9596 - val_loss: 8.7744e-05 - val_accuracy: 1.0000
# Epoch 12/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1200 - accuracy: 0.9609 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 13/100
# 534/534 [==============================] - 7s 12ms/step - loss: 0.1173 - accuracy: 0.9612 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 14/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1159 - accuracy: 0.9611 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 15/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1163 - accuracy: 0.9616 - val_loss: 5.0192e-05 - val_accuracy: 1.0000
# Epoch 16/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1153 - accuracy: 0.9627 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 17/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1139 - accuracy: 0.9628 - val_loss: 2.8481e-04 - val_accuracy: 1.0000
# Epoch 18/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1135 - accuracy: 0.9624 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 19/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1131 - accuracy: 0.9627 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 20/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1122 - accuracy: 0.9629 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 21/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1112 - accuracy: 0.9631 - val_loss: 8.8576e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1106 - accuracy: 0.9633 - val_loss: 5.4471e-04 - val_accuracy: 1.0000
# Epoch 23/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1099 - accuracy: 0.9635 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 24/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1104 - accuracy: 0.9637 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 25/100
# 534/534 [==============================] - 6s 12ms/step - loss: 0.1097 - accuracy: 0.9635 - val_loss: 0.0011 - val_accuracy: 1.0000
# 534/534 [==============================] - 1s 3ms/step - loss: 0.1257 - accuracy: 0.9630
# 534/534 [==============================] - 1s 2ms/step
# Mean Accuracy: 0.9582913517951965
# Mean Confusion Matrix:
# [[  851     0    38    93]
#  [    0  1721    19   796]
#  [   32    11  5635  1435]
#  [  129    76   934 73656]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            f       0.85      0.90      0.87       185
#            A       0.98      0.67      0.80       472
#            V       0.90      0.78      0.83      1405
#            N       0.97      0.99      0.98     15023
#
#     accuracy                           0.96     17085
#    macro avg       0.92      0.83      0.87     17085
# weighted avg       0.96      0.96      0.96     17085
#
# Sensitivity (f): 0.8665987780040734
# Sensitivity (A): 0.6786277602523659
# Sensitivity (V): 0.7922114438352312
# Sensitivity (N): 0.9847717093388596
#
# Mean Sensitivity: 1.0
#
# ==================================================================
#
# Specificity (f): 0.9980934110179527
# Specificity (A): 0.9989504162142598
# Specificity (V): 0.9873456514244123
# Specificity (N): 0.7813940363089079
#
# Mean Specificity: 1.0
